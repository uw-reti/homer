# %% [markdown]
# # HOMER DATA PROCESSING SCRIPT
# The goal of this script is to take the output file of HOMER Pro Batch Runs (.xlsx file containing one optimal case/sheet) and produce a condensed data set + plots.
#
# General flow:
# 1) Run HOMER study via batch process. Select "export results" and name the file.
#
#
# 2) Import file to this script.
#
#
# 3) Use Pandas to pull .xlsx data into a more usable format.
#
#
# 4) Use collected data to build plots.
#
# Goals:
#
#
# Have this script take a large HOMER study (>100 cases) and build one easily accessible database.
#
#
# Potentially couple this script with a HOMER input reading script to do cartography w/HOMER geography + results.

# %%
# Block of dependencies and working directory
import matplotlib.pyplot as plt
import conda
import numpy
import pandas as pd
import os 
directory = 'd:/repo/homer/ClimateStudies/OutputProcessing/Data' #home PC
#directory = 'c:/repo/homer/ClimateStudies/OutputProcessing/Data' #laptop

# %% [markdown]
# ## Following this guide for xlsx reading
# https://stackoverflow.com/questions/26521266/using-pandas-to-pd-read-excel-for-multiple-worksheets-of-the-same-workbook

# %%
#output = pd.read_excel('RevisedCase1.xlsx',sheet_name=None)#brings out all of the xlsx data as a dictionary
#output_keys = output.keys()  #grabs dictionary keys 
#type(output_keys)
#print(output_keys)
#data = output[output_keys]
#data["Cost/NPC\n($)"]

# %%
# reads, maps all sheets 
files = os.listdir(directory)
output_df = {} #creates empty dictionary
names = [] #creates empty list for future name storage
for file in files:
    if file.endswith('.xlsx'):
        xls = pd.ExcelFile(directory + '/' + file) #reads file
        names = names + xls.sheet_names
        for sheet_name in xls.sheet_names: #pulls individual sheets
            output_df[sheet_name] = xls.parse(sheet_name) #puts each sheet into a dictionary w/key "sheet_name"
#display(output_df[sheet_name])

# %%
#pulling interesting data points from each 
opt_out = pd.DataFrame(columns=['Architecture/PV\n(kW)', 'Architecture/G1500', 'Architecture/GenLarge\n(kW)', 'Architecture/1kWh LI',
                                                 'Cost/COE\n($)'])
n = len(names)
for i in range(n):
    name = names[i] # Grabs Sheet Name
    Location = name[5:-3]
    case_num = name[:5] # Grabs Case Number 
    KCC = name[-3:]     #grabs KCC from last 3 values
    #display(KCC[-2:])
    if KCC[-2:].casefold() == ('Af'.casefold()):
            KCC = 'Af'
    elif KCC[-2:].casefold() == 'Am'.casefold():
            KCC = 'Am'
    KCC = KCC.lower()
    filtered_out = output_df[name].filter(['Architecture/PV\n(kW)', 'Architecture/G1500', 'Architecture/GenLarge\n(kW)', 'Architecture/1kWh LI',
                                                 'Cost/COE\n($)']) #Filtering objects of interest
    filtered_out['CaseName'] = Location #adding actual case name to series
    filtered_out['CaseNum'] = case_num # adding case num to series
    filtered_out['KCC'] = KCC
    framed = filtered_out.iloc[[0]] #making the actual df
    framed.set_index(['CaseNum','CaseName'], inplace=True, drop=True) #building df w/ casename and num
    opt_out = pd.concat([framed,opt_out]) #concating all DFs together
opt_out = opt_out[ ['KCC'] + [ col for col in opt_out.columns if col != 'KCC' ] ] #sorting df to have KCC first
opt_out = opt_out.sort_index()
opt_out.to_excel("LocationalVarianceTrimmed.xlsx")
#display(opt_out)
#display()

# %%
#for index = opt_out.ind
#display(pd.MultiIndex.get_level_values(opt_out('CaseNum')))
Case1 = opt_out.loc[("Case1",slice(None))]
Case2 = opt_out.loc[("Case2",slice(None))]
Case3 = opt_out.loc[("Case3",slice(None))]
Case4 = opt_out.loc[("Case4",slice(None))]
display(Case1)
#Case1.plot(y='Cost/COE\n($)', use_index=True)
# Out:
#            KCC  Architecture/PV\n(kW)  Architecture/G1500  \
# CaseName
# Anchorage  dfc           62704.406458                27.0
# Ashland    dfb           40033.750925                19.0
# AtlantaGA  cfa           93091.971417                 3.0
# BangorME   dfb           61149.251524                22.0
# BendOre    bsk           36672.913375                23.0
# ...        ...                    ...                 ...
# TexasOil   bsh           27987.646325                 7.0
# UPMich     dfb           44257.381936                14.0
# VegasNV    bwh           40352.228180                11.0
# WadenaMN   dfa           23330.246432                11.0
# YumaAZ     bwh           43612.826966                 7.0
#
#            Architecture/GenLarge\n(kW) Architecture/1kWh LI  Cost/COE\n($)  \
# CaseName
# Anchorage                          NaN               249345       0.439344
# Ashland                            NaN                83153       0.207777
# AtlantaGA                          NaN               121562       0.252569
# BangorME                           NaN               138129       0.302428
# BendOre                            NaN                97456       0.233693
# ...                                ...                  ...            ...
# TexasOil                           NaN                70819       0.134756
# UPMich                             NaN                74609       0.185149
# VegasNV                            NaN                75666       0.170116
# WadenaMN                           NaN                80647       0.154412
# YumaAZ                             NaN                79707       0.163222
#
#            KCC
# CaseName
# Anchorage  dfc
# Ashland    dfb
# AtlantaGA  cfa
# BangorME   dfb
# BendOre    bsk
# ...        ...
# TexasOil   bsh
# UPMich     dfb
# VegasNV    bwh
# WadenaMN   dfa
# YumaAZ     bwh
#
# [62 rows x 7 columns]

# %%
fig = plt.figure()
fig, ax=plt.subplots(figsize=(24,12))
ax.scatter(Case1.index.values,Case1['Cost/COE\n($)'])
ax.scatter(Case1.index.values,Case2['Cost/COE\n($)'])
ax.scatter(Case1.index.values,Case3['Cost/COE\n($)'])
ax.scatter(Case1.index.values,Case4['Cost/COE\n($)'])
ax.legend(['Case1', 'Case2', 'Case3', 'Case4'], fontsize='large')
plt.xticks(rotation=90);
ax.grid(True)

# %%
#fig = plt.figure()
#fig, ax=plt.subplots(figsize=(24,12))
#ax.bar(Case1.index.values-0.5,Case4['Architecture/GenLarge\n(kW)']/1000)
#ax.bar(Case1.index.values,Case3['Architecture/GenLarge\n(kW)']/1000,bottom=Case4['Architecture/GenLarge\n(kW)']/1000)
#ax.bar(Case1.index.values+0.5,Case2['Architecture/GenLarge\n(kW)']/1000,bottom=Case4['Architecture/GenLarge\n(kW)']/1000+Case3['Architecture/GenLarge\n(kW)']/1000)
#ax.legend(['Case1', 'Case2', 'Case3', 'Case4'], fontsize='large')
#plt.xticks(rotation=90);
#plt.xlabel('Location')
#plt.ylabel('Installed Capacity (MW)')
#ax.grid(True)
width=0.2
display(n)
x=numpy.arange(n)
plt.bar(x-0.2, Case4['Architecture/GenLarge\n(kW)']/1000, width, color='cyan')
plt.bar(x, Case3['Architecture/GenLarge\n(kW)']/1000, width, color='orange')
plt.bar(x+0.2, Case2['Architecture/GenLarge\n(kW)']/1000, width, color='green')
plt.xticks(x, [Case1.index.values])
plt.show()
# Out:
# 248
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8520/3080247008.py in <module>
#      12 display(n)
#      13 x=numpy.arange(n)
# ---> 14 plt.bar(x-0.2, Case4['Architecture/GenLarge\n(kW)']/1000, width, color='cyan')
#      15 plt.bar(x, Case3['Architecture/GenLarge\n(kW)']/1000, width, color='orange')
#      16 plt.bar(x+0.2, Case2['Architecture/GenLarge\n(kW)']/1000, width, color='green')
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2485         x, height, width=0.8, bottom=None, *, align='center',
#    2486         data=None, **kwargs):
# -> 2487     return gca().bar(
#    2488         x, height, width=width, bottom=bottom, align=align,
#    2489         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\AppData\Roaming\Python\Python39\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2428                 yerr = self._convert_dx(yerr, y0, y, self.convert_yunits)
#    2429
# -> 2430         x, height, width, y, linewidth = np.broadcast_arrays(
#    2431             # Make args iterable too.
#    2432             np.atleast_1d(x), height, width, y, linewidth)
#
# <__array_function__ internals> in broadcast_arrays(*args, **kwargs)
#
# ~\AppData\Roaming\Python\Python39\site-packages\numpy\lib\stride_tricks.py in broadcast_arrays(subok, *args)
#     256     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     257
# --> 258     shape = _broadcast_shape(*args)
#     259
#     260     if all(array.shape == shape for array in args):
#
# ~\AppData\Roaming\Python\Python39\site-packages\numpy\lib\stride_tricks.py in _broadcast_shape(*args)
#     187     # use the old-iterator because np.nditer does not handle size 0 arrays
#     188     # consistently
# --> 189     b = np.broadcast(*args[:32])
#     190     # unfortunately, it cannot handle 32 or more arguments directly
#     191     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape

# %%
tag = 'iaf'
display(tag[-2:])
if tag[-2:].casefold == 'af'.casefold:
    tag=af
# Out:
# 'af'
