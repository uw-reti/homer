# %% [markdown]
# # Zip folder unpacking script
# This script will do the following operations in order:
# Scan a folder
# create new calculation folder
# Loop the following actions for each homer script
#
#
#     Unseal homer template file (.homer -> .zip)
#
#
#     Unpack zip file (.zip -> normal directory)
#
#
#     Open 'problem' file
#
#
#     ####### NOT FOR THIS SCRIPT modify 'problem' file
#
#
#     Repack zip file (normal directory -> .zip)
#
#
#     Reseal homer file (.zip -> .homer)
#         ->[FOR THIS STEP TO FUNCTION PROPERLY, THE JUPYTER NOTEBOOK MUST BE EXECUTED ONE DIRECTORY HIGHER]
#
#
#     store updated input file in calculation folder
#
#
#     end

# %%
# Script initialization, make sure to set working directory
import os
import numpy as np 
import zipfile
import shutil
import zlib
import pathlib 
import subprocess
from lxml import etree, objectify
folder = 'd:/repo/homer/ClimateStudies/ProductionCases/Case2 5'

# %%
# Unsealing HOMER template files (.homer -> .zip)
files = [f for f in os.listdir(folder) if f.endswith('.homer')]
n_files = np.size(files)
display(files)
for i in range(len(files)):
    file = files[i]
    base = os.path.splitext(file)[0]
    os.rename(file, base + '.zip')
# Out:
# ['Case255AnchorageDfc.homer',
#  'Case255AshlandDfb.homer',
#  'Case255AtlantaGACfa.homer',
#  'Case255AZYumaBwh.homer',
#  'Case255BangorMEDfb.homer',
#  'Case255BendOreBsk.homer',
#  'Case255BentonCountyOregonCsb.homer',
#  'Case255BirminghamALCfa.homer',
#  'Case255BismarckNDDfb.homer',
#  'Case255BlaineCountyMontanaBSk.homer',
#  'Case255BoiseIDBSk.homer',
#  'Case255BrewsterMADfb.homer',
#  'Case255BurlingtonVTDfa.homer',
#  'Case255ButtonwillowBwk.homer',
#  'Case255CarsonCityNVBsk.homer',
#  'Case255CheyenneWYBsk.homer',
#  'Case255ChicagoDfa.homer',
#  'Case255CoalvilleUTDfb.homer',
#  'Case255ColumbiaMOCfa.homer',
#  'Case255ColumbusOHDfa.homer',
#  'Case255CrestedButteCODfc.homer',
#  'Case255DesMoinesIADfa.homer',
#  'Case255DetroitMIDfa.homer',
#  'Case255EielsonAFBDfC.homer',
#  'Case255EvergladesAM.homer',
#  'Case255FlagstaffDsb.homer',
#  'Case255GreatFallsMTBsk.homer',
#  'Case255HiloAf.homer',
#  'Case255IdahoFallsDfb.homer',
#  'Case255JacksonMSCfa.homer',
#  'Case255KauaiCfb.homer',
#  'Case255KootenaiCountyIDDsb.homer',
#  'Case255LancasterPADfa.homer',
#  'Case255LaredoTXBSh.homer',
#  'Case255LincolnNEDfa.homer',
#  'Case255LittleRockARCfa.homer',
#  'Case255LongviewCsb.homer',
#  'Case255LosAlamosNMDfb.homer',
#  'Case255MarlintonWVCfb.homer',
#  'Case255MedfordORCsa.homer',
#  'Case255MemphisTNCfa.homer',
#  'Case255MiamiAf.homer',
#  'Case255MobileALCfa.homer',
#  'Case255MoscowIDCsb.homer',
#  'Case255NeahBayCfb.homer',
#  'Case255NOLACfa.homer',
#  'Case255OKCityCfa.homer',
#  'Case255ORNLCfa.homer',
#  'Case255PhoenixAZBwh.homer',
#  'Case255PrescottAZCsa.homer',
#  'Case255PuebloBsk.homer',
#  'Case255RaleighNCCfa.homer',
#  'Case255RapidCitySDBsk.homer',
#  'Case255ReddingCACsa.homer',
#  'Case255RichmondVACfa.homer',
#  'Case255SacramentoCsa.homer',
#  'Case255SouthBendINDfa.homer',
#  'Case255SyracuseDfb.homer',
#  'Case255TexasOilBSh.homer',
#  'Case255UPMichDfb.homer',
#  'Case255VegasNVBwh.homer',
#  'Case255WadenaMNDfa.homer']

# %%
# Unpack zip file (.zip -> normal directory)
files = [f for f in os.listdir(folder) if f.endswith('.zip')]
n_files = np.size(files)
for i in range(len(files)):
    file = files[i]
    base = os.path.splitext(file)[0]
    with zipfile.ZipFile(file, 'r') as zip_ref:
        zip_ref.extractall(base + 'TEMP')
    os.remove(file)
# Opening each individiual 'problem' file after extraction

# %%
# (Within normal directory) Edit the .xml files for each HOMER problem.
files = [f for f in os.listdir(folder) if f.endswith('TEMP')]
display(files)
# paths to change as key, new value as value
new_data = {'/HomerProblem/FuelResources/Fuel/Name': 'CCM FUEL',
            '/HomerProblem/FuelResources/Fuel/FuelCostSensitivity/decimal': '0.00',
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/Initial': '12000000',
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/Quantity': '1000' ,
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/CapitalCostDetail/CostCalculatorItem/UnitCost': '12000' ,
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/Replacement': '3550000',
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/ReplacementCostDetail/CostCalculatorItem/Quantity': '1000' ,
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/ReplacementCostDetail/CostCalculatorItem/UnitCost': '3550000' ,
            '/HomerProblem/Generators/Generator/LifetimeSensitivity/decimal': '131490' ,
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/Operating': '24.01',
            '/HomerProblem/SimulationParameters/Economics/ProjectLifetimeSensitivity/decimal': '60',
            '/HomerProblem/SimulationParameters/SystemControl/Optimizer/FocusFactor': '2'}
   
for i in range(len(files)):
    file = files[i]
    problems = etree.parse(file + '/problem')
    #os.remove(file + '/calculated-problem') #deletes old homer savestate
    for path, value in new_data.items():
       # if 'CapacityOptimization' in path:#not necessary currently, but can be used to differentiate values later
       #     problems.xpath(path)[0].text = value
       #     newfile = etree.tostring(problems,encoding='utf-8',method='xml', xml_declaration='<?xml version="1.0" encoding="utf-8"?>')
       #     newfile = str(newfile,'utf-8')#otherwise use utf-8
       # else: 
            #print(path, ' => ', problems.xpath(path)[0].text)
        problems.xpath(path)[0].text = value
        newfile = etree.tostring(problems,encoding='US-ASCII',method='xml', xml_declaration='<?xml version="1.0" encoding="utf-8"?>')
        newfile = str(newfile,'US-ASCII')#otherwise use utf-8
    with open(file + '/problem','w') as f:
    #   # newfile = etree.tostring(new)
         f.write(newfile)
        
        
        
    #display(problem)
       # problem.xpath(j)[0].text = value[j]
# Out:
# ['Case255AnchorageDfcTEMP',
#  'Case255AshlandDfbTEMP',
#  'Case255AtlantaGACfaTEMP',
#  'Case255AZYumaBwhTEMP',
#  'Case255BangorMEDfbTEMP',
#  'Case255BendOreBskTEMP',
#  'Case255BentonCountyOregonCsbTEMP',
#  'Case255BirminghamALCfaTEMP',
#  'Case255BismarckNDDfbTEMP',
#  'Case255BlaineCountyMontanaBSkTEMP',
#  'Case255BoiseIDBSkTEMP',
#  'Case255BrewsterMADfbTEMP',
#  'Case255BurlingtonVTDfaTEMP',
#  'Case255ButtonwillowBwkTEMP',
#  'Case255CarsonCityNVBskTEMP',
#  'Case255CheyenneWYBskTEMP',
#  'Case255ChicagoDfaTEMP',
#  'Case255CoalvilleUTDfbTEMP',
#  'Case255ColumbiaMOCfaTEMP',
#  'Case255ColumbusOHDfaTEMP',
#  'Case255CrestedButteCODfcTEMP',
#  'Case255DesMoinesIADfaTEMP',
#  'Case255DetroitMIDfaTEMP',
#  'Case255EielsonAFBDfCTEMP',
#  'Case255EvergladesAMTEMP',
#  'Case255FlagstaffDsbTEMP',
#  'Case255GreatFallsMTBskTEMP',
#  'Case255HiloAfTEMP',
#  'Case255IdahoFallsDfbTEMP',
#  'Case255JacksonMSCfaTEMP',
#  'Case255KauaiCfbTEMP',
#  'Case255KootenaiCountyIDDsbTEMP',
#  'Case255LancasterPADfaTEMP',
#  'Case255LaredoTXBShTEMP',
#  'Case255LincolnNEDfaTEMP',
#  'Case255LittleRockARCfaTEMP',
#  'Case255LongviewCsbTEMP',
#  'Case255LosAlamosNMDfbTEMP',
#  'Case255MarlintonWVCfbTEMP',
#  'Case255MedfordORCsaTEMP',
#  'Case255MemphisTNCfaTEMP',
#  'Case255MiamiAfTEMP',
#  'Case255MobileALCfaTEMP',
#  'Case255MoscowIDCsbTEMP',
#  'Case255NeahBayCfbTEMP',
#  'Case255NOLACfaTEMP',
#  'Case255OKCityCfaTEMP',
#  'Case255ORNLCfaTEMP',
#  'Case255PhoenixAZBwhTEMP',
#  'Case255PrescottAZCsaTEMP',
#  'Case255PuebloBskTEMP',
#  'Case255RaleighNCCfaTEMP',
#  'Case255RapidCitySDBskTEMP',
#  'Case255ReddingCACsaTEMP',
#  'Case255RichmondVACfaTEMP',
#  'Case255SacramentoCsaTEMP',
#  'Case255SouthBendINDfaTEMP',
#  'Case255SyracuseDfbTEMP',
#  'Case255TexasOilBShTEMP',
#  'Case255UPMichDfbTEMP',
#  'Case255VegasNVBwhTEMP',
#  'Case255WadenaMNDfaTEMP']

# %%
#Repack zip file (normal directory -> .zip)
## THIS STEP CURRENTLY BREAKS THE HOMER FILE
## Try using zipcode compression 
files = [f for f in os.listdir(folder) if f.endswith('TEMP')]
display(files)
for i in range(len(files)):
    file = files[i]
    directory = pathlib.Path(file)
    basefile = file.replace('TEMP','')
    basefile = basefile.replace('Case255','Case25')
    subprocess.run(["powershell.exe", "Compress-Archive -Path " + file + "\* -DestinationPath " + basefile + " -Force"])
    shutil.rmtree(file) #deletes old temp folders
# Out:
# ['Case255AnchorageDfcTEMP',
#  'Case255AshlandDfbTEMP',
#  'Case255AtlantaGACfaTEMP',
#  'Case255AZYumaBwhTEMP',
#  'Case255BangorMEDfbTEMP',
#  'Case255BendOreBskTEMP',
#  'Case255BentonCountyOregonCsbTEMP',
#  'Case255BirminghamALCfaTEMP',
#  'Case255BismarckNDDfbTEMP',
#  'Case255BlaineCountyMontanaBSkTEMP',
#  'Case255BoiseIDBSkTEMP',
#  'Case255BrewsterMADfbTEMP',
#  'Case255BurlingtonVTDfaTEMP',
#  'Case255ButtonwillowBwkTEMP',
#  'Case255CarsonCityNVBskTEMP',
#  'Case255CheyenneWYBskTEMP',
#  'Case255ChicagoDfaTEMP',
#  'Case255CoalvilleUTDfbTEMP',
#  'Case255ColumbiaMOCfaTEMP',
#  'Case255ColumbusOHDfaTEMP',
#  'Case255CrestedButteCODfcTEMP',
#  'Case255DesMoinesIADfaTEMP',
#  'Case255DetroitMIDfaTEMP',
#  'Case255EielsonAFBDfCTEMP',
#  'Case255EvergladesAMTEMP',
#  'Case255FlagstaffDsbTEMP',
#  'Case255GreatFallsMTBskTEMP',
#  'Case255HiloAfTEMP',
#  'Case255IdahoFallsDfbTEMP',
#  'Case255JacksonMSCfaTEMP',
#  'Case255KauaiCfbTEMP',
#  'Case255KootenaiCountyIDDsbTEMP',
#  'Case255LancasterPADfaTEMP',
#  'Case255LaredoTXBShTEMP',
#  'Case255LincolnNEDfaTEMP',
#  'Case255LittleRockARCfaTEMP',
#  'Case255LongviewCsbTEMP',
#  'Case255LosAlamosNMDfbTEMP',
#  'Case255MarlintonWVCfbTEMP',
#  'Case255MedfordORCsaTEMP',
#  'Case255MemphisTNCfaTEMP',
#  'Case255MiamiAfTEMP',
#  'Case255MobileALCfaTEMP',
#  'Case255MoscowIDCsbTEMP',
#  'Case255NeahBayCfbTEMP',
#  'Case255NOLACfaTEMP',
#  'Case255OKCityCfaTEMP',
#  'Case255ORNLCfaTEMP',
#  'Case255PhoenixAZBwhTEMP',
#  'Case255PrescottAZCsaTEMP',
#  'Case255PuebloBskTEMP',
#  'Case255RaleighNCCfaTEMP',
#  'Case255RapidCitySDBskTEMP',
#  'Case255ReddingCACsaTEMP',
#  'Case255RichmondVACfaTEMP',
#  'Case255SacramentoCsaTEMP',
#  'Case255SouthBendINDfaTEMP',
#  'Case255SyracuseDfbTEMP',
#  'Case255TexasOilBShTEMP',
#  'Case255UPMichDfbTEMP',
#  'Case255VegasNVBwhTEMP',
#  'Case255WadenaMNDfaTEMP']

# %%
# Reseal homer file (.zip -> .homer)
files = [f for f in os.listdir(folder) if f.endswith('.zip')]
n_files = np.size(files)
type(files)
for i in range(len(files)):
    file = files[i]
    base = os.path.splitext(file)[0]
    os.rename(file, base + '.homer')
