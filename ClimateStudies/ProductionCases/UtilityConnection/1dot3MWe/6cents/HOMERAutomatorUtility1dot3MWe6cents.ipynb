# %% [markdown]
# # Zip folder unpacking script
# This script will do the following operations in order:
# Scan a folder
# create new calculation folder
# Loop the following actions for each homer script
#
#
#     Unseal homer template file (.homer -> .zip)
#
#
#     Unpack zip file (.zip -> normal directory)
#
#
#     Open 'problem' file
#
#
#     ####### NOT FOR THIS SCRIPT modify 'problem' file
#
#
#     Repack zip file (normal directory -> .zip)
#
#
#     Reseal homer file (.zip -> .homer)
#         ->[FOR THIS STEP TO FUNCTION PROPERLY, THE JUPYTER NOTEBOOK MUST BE EXECUTED ONE DIRECTORY HIGHER]
#
#
#     store updated input file in calculation folder
#
#
#     end

# %%
# Script initialization, make sure to set working directory
import os
import numpy as np 
import zipfile
import shutil
import zlib
import pathlib 
import subprocess
from lxml import etree, objectify
folder = 'd:/repo/homer/ClimateStudies/ProductionCases/UtilityConnection/1dot3MWe/6centsCopy'

# %%
# Unsealing HOMER template files (.homer -> .zip)
files = [f for f in os.listdir(folder) if f.endswith('.homer')]
n_files = np.size(files)
display(files)
for i in range(len(files)):
    file = files[i]
    base = os.path.splitext(file)[0]
    os.rename(file, base + '.zip')
# Out:
# ['Utility1dot3MWe6CentsCopyAnchorageDfc.homer',
#  'Utility1dot3MWe6CentsCopyAshlandDfb.homer',
#  'Utility1dot3MWe6CentsCopyAtlantaGACfa.homer',
#  'Utility1dot3MWe6CentsCopyBangorMEDfb.homer',
#  'Utility1dot3MWe6CentsCopyBendOreBsk.homer',
#  'Utility1dot3MWe6CentsCopyBentonCountyOregonCsb.homer',
#  'Utility1dot3MWe6CentsCopyBirminghamALCfa.homer',
#  'Utility1dot3MWe6CentsCopyBismarckNDDfb.homer',
#  'Utility1dot3MWe6CentsCopyBlaineCountyMontanaBSk.homer',
#  'Utility1dot3MWe6CentsCopyBoiseIDBSk.homer',
#  'Utility1dot3MWe6CentsCopyBrewsterMADfb.homer',
#  'Utility1dot3MWe6CentsCopyBurlingtonVTDfa.homer',
#  'Utility1dot3MWe6CentsCopyButtonwillowBwk.homer',
#  'Utility1dot3MWe6CentsCopyCarsonCityNVBsk.homer',
#  'Utility1dot3MWe6CentsCopyCheyenneWYBsk.homer',
#  'Utility1dot3MWe6CentsCopyChicagoDfa.homer',
#  'Utility1dot3MWe6CentsCopyCoalvilleUTDfb.homer',
#  'Utility1dot3MWe6CentsCopyColumbiaMOCfa.homer',
#  'Utility1dot3MWe6CentsCopyColumbusOHDfa.homer',
#  'Utility1dot3MWe6CentsCopyCrestedButteCODfc.homer',
#  'Utility1dot3MWe6CentsCopyDesMoinesIADfa.homer',
#  'Utility1dot3MWe6CentsCopyDetroitMIDfa.homer',
#  'Utility1dot3MWe6CentsCopyEielsonAFBDfC.homer',
#  'Utility1dot3MWe6CentsCopyEvergladesAM.homer',
#  'Utility1dot3MWe6CentsCopyFlagstaffDsb.homer',
#  'Utility1dot3MWe6CentsCopyGreatFallsMTBsk.homer',
#  'Utility1dot3MWe6CentsCopyHiloAf.homer',
#  'Utility1dot3MWe6CentsCopyIdahoFallsDfb.homer',
#  'Utility1dot3MWe6CentsCopyJacksonMSCfa.homer',
#  'Utility1dot3MWe6CentsCopyKauaiCfb.homer',
#  'Utility1dot3MWe6CentsCopyKootenaiCountyIDDsb.homer',
#  'Utility1dot3MWe6CentsCopyLancasterPADfa.homer',
#  'Utility1dot3MWe6CentsCopyLaredoTXBSh.homer',
#  'Utility1dot3MWe6CentsCopyLincolnNEDfa.homer',
#  'Utility1dot3MWe6CentsCopyLittleRockARCfa.homer',
#  'Utility1dot3MWe6CentsCopyLongviewCsb.homer',
#  'Utility1dot3MWe6CentsCopyLosAlamosNMDfb.homer',
#  'Utility1dot3MWe6CentsCopyMarlintonWVCfb.homer',
#  'Utility1dot3MWe6CentsCopyMedfordORCsa.homer',
#  'Utility1dot3MWe6CentsCopyMemphisTNCfa.homer',
#  'Utility1dot3MWe6CentsCopyMiamiAf.homer',
#  'Utility1dot3MWe6CentsCopyMobileALCfa.homer',
#  'Utility1dot3MWe6CentsCopyMoscowIDCsb.homer',
#  'Utility1dot3MWe6CentsCopyNeahBayCfb.homer',
#  'Utility1dot3MWe6CentsCopyNOLACfa.homer',
#  'Utility1dot3MWe6CentsCopyOKCityCfa.homer',
#  'Utility1dot3MWe6CentsCopyORNLCfa.homer',
#  'Utility1dot3MWe6CentsCopyPhoenixAZBwh.homer',
#  'Utility1dot3MWe6CentsCopyPrescottAZCsa.homer',
#  'Utility1dot3MWe6CentsCopyPuebloBsk.homer',
#  'Utility1dot3MWe6CentsCopyRaleighNCCfa.homer',
#  'Utility1dot3MWe6CentsCopyRapidCitySDBsk.homer',
#  'Utility1dot3MWe6CentsCopyReddingCACsa.homer',
#  'Utility1dot3MWe6CentsCopyRichmondVACfa.homer',
#  'Utility1dot3MWe6CentsCopySacramentoCsa.homer',
#  'Utility1dot3MWe6CentsCopySouthBendINDfa.homer',
#  'Utility1dot3MWe6CentsCopySyracuseDfb.homer',
#  'Utility1dot3MWe6CentsCopyTexasOilBSh.homer',
#  'Utility1dot3MWe6CentsCopyUPMichDfb.homer',
#  'Utility1dot3MWe6CentsCopyVegasNVBwh.homer',
#  'Utility1dot3MWe6CentsCopyWadenaMNDfa.homer',
#  'Utility1dot3MWe6CentsCopyYumaAZBwh.homer']

# %%
# Unpack zip file (.zip -> normal directory)
files = [f for f in os.listdir(folder) if f.endswith('.zip')]
n_files = np.size(files)
for i in range(len(files)):
    file = files[i]
    base = os.path.splitext(file)[0]
    with zipfile.ZipFile(file, 'r') as zip_ref:
        zip_ref.extractall(base + 'TEMP')
    os.remove(file)
# Opening each individiual 'problem' file after extraction

# %%
# (Within normal directory) Edit the .xml files for each HOMER problem.
files = [f for f in os.listdir(folder) if f.endswith('TEMP')]
display(files)
# paths to change as key, new value as value
new_data = {'/HomerProblem/SimulationParameters/Economics/ProjectLifetimeSensitivity/decimal': '60',
            '/HomerProblem/SimulationParameters/SystemControl/Optimizer/FocusFactor': '2',
            '/HomerProblem/Grid/ConnectionRates/GridConnectionRate/SellbackRateSensitivity/decimal': '0.00',
            '/HomerProblem/Grid/ConnectionRates/GridConnectionRate/GridPowerPriceSensitivity/decimal': '0.06',
            '/HomerProblem/Grid/PurchaseCapacityOptimization/decimal': '1300',
            '/HomerProblem/Grid/SaleCapacitySensitivity/decimal': '0',
            '/HomerProblem/Grid/MaxNetGridPurchasesSensitivity/decimal': '0'}
   
for i in range(len(files)):
    file = files[i]
    problems = etree.parse(file + '/problem')
    #os.remove(file + '/calculated-problem') #deletes old homer savestate
    for path, value in new_data.items():
       # if 'CapacityOptimization' in path:#not necessary currently, but can be used to differentiate values later
       #     problems.xpath(path)[0].text = value
       #     newfile = etree.tostring(problems,encoding='utf-8',method='xml', xml_declaration='<?xml version="1.0" encoding="utf-8"?>')
       #     newfile = str(newfile,'utf-8')#otherwise use utf-8
       # else: 
            #print(path, ' => ', problems.xpath(path)[0].text)
        problems.xpath(path)[0].text = value
        newfile = etree.tostring(problems,encoding='US-ASCII',method='xml', xml_declaration='<?xml version="1.0" encoding="utf-8"?>')
        newfile = str(newfile,'US-ASCII')#otherwise use utf-8
    with open(file + '/problem','w') as f:
    #   # newfile = etree.tostring(new)
         f.write(newfile)
        
        
        
    #display(problem)
       # problem.xpath(j)[0].text = value[j]
# Out:
# ['Utility1dot3MWe6CentsCopyAnchorageDfcTEMP',
#  'Utility1dot3MWe6CentsCopyAshlandDfbTEMP',
#  'Utility1dot3MWe6CentsCopyAtlantaGACfaTEMP',
#  'Utility1dot3MWe6CentsCopyBangorMEDfbTEMP',
#  'Utility1dot3MWe6CentsCopyBendOreBskTEMP',
#  'Utility1dot3MWe6CentsCopyBentonCountyOregonCsbTEMP',
#  'Utility1dot3MWe6CentsCopyBirminghamALCfaTEMP',
#  'Utility1dot3MWe6CentsCopyBismarckNDDfbTEMP',
#  'Utility1dot3MWe6CentsCopyBlaineCountyMontanaBSkTEMP',
#  'Utility1dot3MWe6CentsCopyBoiseIDBSkTEMP',
#  'Utility1dot3MWe6CentsCopyBrewsterMADfbTEMP',
#  'Utility1dot3MWe6CentsCopyBurlingtonVTDfaTEMP',
#  'Utility1dot3MWe6CentsCopyButtonwillowBwkTEMP',
#  'Utility1dot3MWe6CentsCopyCarsonCityNVBskTEMP',
#  'Utility1dot3MWe6CentsCopyCheyenneWYBskTEMP',
#  'Utility1dot3MWe6CentsCopyChicagoDfaTEMP',
#  'Utility1dot3MWe6CentsCopyCoalvilleUTDfbTEMP',
#  'Utility1dot3MWe6CentsCopyColumbiaMOCfaTEMP',
#  'Utility1dot3MWe6CentsCopyColumbusOHDfaTEMP',
#  'Utility1dot3MWe6CentsCopyCrestedButteCODfcTEMP',
#  'Utility1dot3MWe6CentsCopyDesMoinesIADfaTEMP',
#  'Utility1dot3MWe6CentsCopyDetroitMIDfaTEMP',
#  'Utility1dot3MWe6CentsCopyEielsonAFBDfCTEMP',
#  'Utility1dot3MWe6CentsCopyEvergladesAMTEMP',
#  'Utility1dot3MWe6CentsCopyFlagstaffDsbTEMP',
#  'Utility1dot3MWe6CentsCopyGreatFallsMTBskTEMP',
#  'Utility1dot3MWe6CentsCopyHiloAfTEMP',
#  'Utility1dot3MWe6CentsCopyIdahoFallsDfbTEMP',
#  'Utility1dot3MWe6CentsCopyJacksonMSCfaTEMP',
#  'Utility1dot3MWe6CentsCopyKauaiCfbTEMP',
#  'Utility1dot3MWe6CentsCopyKootenaiCountyIDDsbTEMP',
#  'Utility1dot3MWe6CentsCopyLancasterPADfaTEMP',
#  'Utility1dot3MWe6CentsCopyLaredoTXBShTEMP',
#  'Utility1dot3MWe6CentsCopyLincolnNEDfaTEMP',
#  'Utility1dot3MWe6CentsCopyLittleRockARCfaTEMP',
#  'Utility1dot3MWe6CentsCopyLongviewCsbTEMP',
#  'Utility1dot3MWe6CentsCopyLosAlamosNMDfbTEMP',
#  'Utility1dot3MWe6CentsCopyMarlintonWVCfbTEMP',
#  'Utility1dot3MWe6CentsCopyMedfordORCsaTEMP',
#  'Utility1dot3MWe6CentsCopyMemphisTNCfaTEMP',
#  'Utility1dot3MWe6CentsCopyMiamiAfTEMP',
#  'Utility1dot3MWe6CentsCopyMobileALCfaTEMP',
#  'Utility1dot3MWe6CentsCopyMoscowIDCsbTEMP',
#  'Utility1dot3MWe6CentsCopyNeahBayCfbTEMP',
#  'Utility1dot3MWe6CentsCopyNOLACfaTEMP',
#  'Utility1dot3MWe6CentsCopyOKCityCfaTEMP',
#  'Utility1dot3MWe6CentsCopyORNLCfaTEMP',
#  'Utility1dot3MWe6CentsCopyPhoenixAZBwhTEMP',
#  'Utility1dot3MWe6CentsCopyPrescottAZCsaTEMP',
#  'Utility1dot3MWe6CentsCopyPuebloBskTEMP',
#  'Utility1dot3MWe6CentsCopyRaleighNCCfaTEMP',
#  'Utility1dot3MWe6CentsCopyRapidCitySDBskTEMP',
#  'Utility1dot3MWe6CentsCopyReddingCACsaTEMP',
#  'Utility1dot3MWe6CentsCopyRichmondVACfaTEMP',
#  'Utility1dot3MWe6CentsCopySacramentoCsaTEMP',
#  'Utility1dot3MWe6CentsCopySouthBendINDfaTEMP',
#  'Utility1dot3MWe6CentsCopySyracuseDfbTEMP',
#  'Utility1dot3MWe6CentsCopyTexasOilBShTEMP',
#  'Utility1dot3MWe6CentsCopyUPMichDfbTEMP',
#  'Utility1dot3MWe6CentsCopyVegasNVBwhTEMP',
#  'Utility1dot3MWe6CentsCopyWadenaMNDfaTEMP',
#  'Utility1dot3MWe6CentsCopyYumaAZBwhTEMP']

# %%
#Repack zip file (normal directory -> .zip)
## THIS STEP CURRENTLY BREAKS THE HOMER FILE
## Try using zipcode compression 
files = [f for f in os.listdir(folder) if f.endswith('TEMP')]
display(files)
for i in range(len(files)):
    file = files[i]
    directory = pathlib.Path(file)
    basefile = file.replace('TEMP','')
    basefile = basefile.replace('Utility1dot3MWe6CentsCopy','Utility1dot3MWe6Cents')
    subprocess.run(["powershell.exe", "Compress-Archive -Path " + file + "\* -DestinationPath " + basefile + " -Force"])
    shutil.rmtree(file) #deletes old temp folders
# Out:
# ['Utility1dot3MWe6CentsCopyAnchorageDfcTEMP',
#  'Utility1dot3MWe6CentsCopyAshlandDfbTEMP',
#  'Utility1dot3MWe6CentsCopyAtlantaGACfaTEMP',
#  'Utility1dot3MWe6CentsCopyBangorMEDfbTEMP',
#  'Utility1dot3MWe6CentsCopyBendOreBskTEMP',
#  'Utility1dot3MWe6CentsCopyBentonCountyOregonCsbTEMP',
#  'Utility1dot3MWe6CentsCopyBirminghamALCfaTEMP',
#  'Utility1dot3MWe6CentsCopyBismarckNDDfbTEMP',
#  'Utility1dot3MWe6CentsCopyBlaineCountyMontanaBSkTEMP',
#  'Utility1dot3MWe6CentsCopyBoiseIDBSkTEMP',
#  'Utility1dot3MWe6CentsCopyBrewsterMADfbTEMP',
#  'Utility1dot3MWe6CentsCopyBurlingtonVTDfaTEMP',
#  'Utility1dot3MWe6CentsCopyButtonwillowBwkTEMP',
#  'Utility1dot3MWe6CentsCopyCarsonCityNVBskTEMP',
#  'Utility1dot3MWe6CentsCopyCheyenneWYBskTEMP',
#  'Utility1dot3MWe6CentsCopyChicagoDfaTEMP',
#  'Utility1dot3MWe6CentsCopyCoalvilleUTDfbTEMP',
#  'Utility1dot3MWe6CentsCopyColumbiaMOCfaTEMP',
#  'Utility1dot3MWe6CentsCopyColumbusOHDfaTEMP',
#  'Utility1dot3MWe6CentsCopyCrestedButteCODfcTEMP',
#  'Utility1dot3MWe6CentsCopyDesMoinesIADfaTEMP',
#  'Utility1dot3MWe6CentsCopyDetroitMIDfaTEMP',
#  'Utility1dot3MWe6CentsCopyEielsonAFBDfCTEMP',
#  'Utility1dot3MWe6CentsCopyEvergladesAMTEMP',
#  'Utility1dot3MWe6CentsCopyFlagstaffDsbTEMP',
#  'Utility1dot3MWe6CentsCopyGreatFallsMTBskTEMP',
#  'Utility1dot3MWe6CentsCopyHiloAfTEMP',
#  'Utility1dot3MWe6CentsCopyIdahoFallsDfbTEMP',
#  'Utility1dot3MWe6CentsCopyJacksonMSCfaTEMP',
#  'Utility1dot3MWe6CentsCopyKauaiCfbTEMP',
#  'Utility1dot3MWe6CentsCopyKootenaiCountyIDDsbTEMP',
#  'Utility1dot3MWe6CentsCopyLancasterPADfaTEMP',
#  'Utility1dot3MWe6CentsCopyLaredoTXBShTEMP',
#  'Utility1dot3MWe6CentsCopyLincolnNEDfaTEMP',
#  'Utility1dot3MWe6CentsCopyLittleRockARCfaTEMP',
#  'Utility1dot3MWe6CentsCopyLongviewCsbTEMP',
#  'Utility1dot3MWe6CentsCopyLosAlamosNMDfbTEMP',
#  'Utility1dot3MWe6CentsCopyMarlintonWVCfbTEMP',
#  'Utility1dot3MWe6CentsCopyMedfordORCsaTEMP',
#  'Utility1dot3MWe6CentsCopyMemphisTNCfaTEMP',
#  'Utility1dot3MWe6CentsCopyMiamiAfTEMP',
#  'Utility1dot3MWe6CentsCopyMobileALCfaTEMP',
#  'Utility1dot3MWe6CentsCopyMoscowIDCsbTEMP',
#  'Utility1dot3MWe6CentsCopyNeahBayCfbTEMP',
#  'Utility1dot3MWe6CentsCopyNOLACfaTEMP',
#  'Utility1dot3MWe6CentsCopyOKCityCfaTEMP',
#  'Utility1dot3MWe6CentsCopyORNLCfaTEMP',
#  'Utility1dot3MWe6CentsCopyPhoenixAZBwhTEMP',
#  'Utility1dot3MWe6CentsCopyPrescottAZCsaTEMP',
#  'Utility1dot3MWe6CentsCopyPuebloBskTEMP',
#  'Utility1dot3MWe6CentsCopyRaleighNCCfaTEMP',
#  'Utility1dot3MWe6CentsCopyRapidCitySDBskTEMP',
#  'Utility1dot3MWe6CentsCopyReddingCACsaTEMP',
#  'Utility1dot3MWe6CentsCopyRichmondVACfaTEMP',
#  'Utility1dot3MWe6CentsCopySacramentoCsaTEMP',
#  'Utility1dot3MWe6CentsCopySouthBendINDfaTEMP',
#  'Utility1dot3MWe6CentsCopySyracuseDfbTEMP',
#  'Utility1dot3MWe6CentsCopyTexasOilBShTEMP',
#  'Utility1dot3MWe6CentsCopyUPMichDfbTEMP',
#  'Utility1dot3MWe6CentsCopyVegasNVBwhTEMP',
#  'Utility1dot3MWe6CentsCopyWadenaMNDfaTEMP',
#  'Utility1dot3MWe6CentsCopyYumaAZBwhTEMP']

# %%
# Reseal homer file (.zip -> .homer)
files = [f for f in os.listdir(folder) if f.endswith('.zip')]
n_files = np.size(files)
type(files)
for i in range(len(files)):
    file = files[i]
    base = os.path.splitext(file)[0]
    os.rename(file, base + '.homer')
