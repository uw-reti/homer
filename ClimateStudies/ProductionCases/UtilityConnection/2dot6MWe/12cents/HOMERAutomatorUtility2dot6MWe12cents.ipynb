# %% [markdown]
# # Zip folder unpacking script
# This script will do the following operations in order:
# Scan a folder
# create new calculation folder
# Loop the following actions for each homer script
#
#
#     Unseal homer template file (.homer -> .zip)
#
#
#     Unpack zip file (.zip -> normal directory)
#
#
#     Open 'problem' file
#
#
#     ####### NOT FOR THIS SCRIPT modify 'problem' file
#
#
#     Repack zip file (normal directory -> .zip)
#
#
#     Reseal homer file (.zip -> .homer)
#         ->[FOR THIS STEP TO FUNCTION PROPERLY, THE JUPYTER NOTEBOOK MUST BE EXECUTED ONE DIRECTORY HIGHER]
#
#
#     store updated input file in calculation folder
#
#
#     end

# %%
# Script initialization, make sure to set working directory
import os
import numpy as np 
import zipfile
import shutil
import zlib
import pathlib 
import subprocess
from lxml import etree, objectify
folder = 'd:/repo/homer/ClimateStudies/ProductionCases/UtilityConnection/2dot6MWe/12cents'

# %%
# Unsealing HOMER template files (.homer -> .zip)
files = [f for f in os.listdir(folder) if f.endswith('.homer')]
n_files = np.size(files)
display(files)
for i in range(len(files)):
    file = files[i]
    base = os.path.splitext(file)[0]
    os.rename(file, base + '.zip')
# Out:
# ['Utility1dot3MWe12CentsAnchorageDfc.homer',
#  'Utility1dot3MWe12CentsAshlandDfb.homer',
#  'Utility1dot3MWe12CentsAtlantaGACfa.homer',
#  'Utility1dot3MWe12CentsBangorMEDfb.homer',
#  'Utility1dot3MWe12CentsBendOreBsk.homer',
#  'Utility1dot3MWe12CentsBentonCountyOregonCsb.homer',
#  'Utility1dot3MWe12CentsBirminghamALCfa.homer',
#  'Utility1dot3MWe12CentsBismarckNDDfb.homer',
#  'Utility1dot3MWe12CentsBlaineCountyMontanaBSk.homer',
#  'Utility1dot3MWe12CentsBoiseIDBSk.homer',
#  'Utility1dot3MWe12CentsBrewsterMADfb.homer',
#  'Utility1dot3MWe12CentsBurlingtonVTDfa.homer',
#  'Utility1dot3MWe12CentsButtonwillowBwk.homer',
#  'Utility1dot3MWe12CentsCarsonCityNVBsk.homer',
#  'Utility1dot3MWe12CentsCheyenneWYBsk.homer',
#  'Utility1dot3MWe12CentsChicagoDfa.homer',
#  'Utility1dot3MWe12CentsCoalvilleUTDfb.homer',
#  'Utility1dot3MWe12CentsColumbiaMOCfa.homer',
#  'Utility1dot3MWe12CentsColumbusOHDfa.homer',
#  'Utility1dot3MWe12CentsCrestedButteCODfc.homer',
#  'Utility1dot3MWe12CentsDesMoinesIADfa.homer',
#  'Utility1dot3MWe12CentsDetroitMIDfa.homer',
#  'Utility1dot3MWe12CentsEielsonAFBDfC.homer',
#  'Utility1dot3MWe12CentsEvergladesAM.homer',
#  'Utility1dot3MWe12CentsFlagstaffDsb.homer',
#  'Utility1dot3MWe12CentsGreatFallsMTBsk.homer',
#  'Utility1dot3MWe12CentsHiloAf.homer',
#  'Utility1dot3MWe12CentsIdahoFallsDfb.homer',
#  'Utility1dot3MWe12CentsJacksonMSCfa.homer',
#  'Utility1dot3MWe12CentsKauaiCfb.homer',
#  'Utility1dot3MWe12CentsKootenaiCountyIDDsb.homer',
#  'Utility1dot3MWe12CentsLancasterPADfa.homer',
#  'Utility1dot3MWe12CentsLaredoTXBSh.homer',
#  'Utility1dot3MWe12CentsLincolnNEDfa.homer',
#  'Utility1dot3MWe12CentsLittleRockARCfa.homer',
#  'Utility1dot3MWe12CentsLongviewCsb.homer',
#  'Utility1dot3MWe12CentsLosAlamosNMDfb.homer',
#  'Utility1dot3MWe12CentsMarlintonWVCfb.homer',
#  'Utility1dot3MWe12CentsMedfordORCsa.homer',
#  'Utility1dot3MWe12CentsMemphisTNCfa.homer',
#  'Utility1dot3MWe12CentsMiamiAf.homer',
#  'Utility1dot3MWe12CentsMobileALCfa.homer',
#  'Utility1dot3MWe12CentsMoscowIDCsb.homer',
#  'Utility1dot3MWe12CentsNeahBayCfb.homer',
#  'Utility1dot3MWe12CentsNOLACfa.homer',
#  'Utility1dot3MWe12CentsOKCityCfa.homer',
#  'Utility1dot3MWe12CentsORNLCfa.homer',
#  'Utility1dot3MWe12CentsPhoenixAZBwh.homer',
#  'Utility1dot3MWe12CentsPrescottAZCsa.homer',
#  'Utility1dot3MWe12CentsPuebloBsk.homer',
#  'Utility1dot3MWe12CentsRaleighNCCfa.homer',
#  'Utility1dot3MWe12CentsRapidCitySDBsk.homer',
#  'Utility1dot3MWe12CentsReddingCACsa.homer',
#  'Utility1dot3MWe12CentsRichmondVACfa.homer',
#  'Utility1dot3MWe12CentsSacramentoCsa.homer',
#  'Utility1dot3MWe12CentsSouthBendINDfa.homer',
#  'Utility1dot3MWe12CentsSyracuseDfb.homer',
#  'Utility1dot3MWe12CentsTexasOilBSh.homer',
#  'Utility1dot3MWe12CentsUPMichDfb.homer',
#  'Utility1dot3MWe12CentsVegasNVBwh.homer',
#  'Utility1dot3MWe12CentsWadenaMNDfa.homer',
#  'Utility1dot3MWe12CentsYumaAZBwh.homer']

# %%
# Unpack zip file (.zip -> normal directory)
files = [f for f in os.listdir(folder) if f.endswith('.zip')]
n_files = np.size(files)
for i in range(len(files)):
    file = files[i]
    base = os.path.splitext(file)[0]
    with zipfile.ZipFile(file, 'r') as zip_ref:
        zip_ref.extractall(base + 'TEMP')
    os.remove(file)
# Opening each individiual 'problem' file after extraction

# %%
# (Within normal directory) Edit the .xml files for each HOMER problem.
files = [f for f in os.listdir(folder) if f.endswith('TEMP')]
display(files)
# paths to change as key, new value as value
new_data = {'/HomerProblem/SimulationParameters/Economics/ProjectLifetimeSensitivity/decimal': '60',
            '/HomerProblem/SimulationParameters/SystemControl/Optimizer/FocusFactor': '2',
            '/HomerProblem/Grid/ConnectionRates/GridConnectionRate/SellbackRateSensitivity/decimal': '0.00',
            '/HomerProblem/Grid/ConnectionRates/GridConnectionRate/GridPowerPriceSensitivity/decimal': '0.12',
            '/HomerProblem/Grid/PurchaseCapacityOptimization/decimal': '2600',
            '/HomerProblem/Grid/SaleCapacitySensitivity/decimal': '0',
            '/HomerProblem/Grid/MaxNetGridPurchasesSensitivity/decimal': '0'}
   
for i in range(len(files)):
    file = files[i]
    problems = etree.parse(file + '/problem')
    #os.remove(file + '/calculated-problem') #deletes old homer savestate
    for path, value in new_data.items():
       # if 'CapacityOptimization' in path:#not necessary currently, but can be used to differentiate values later
       #     problems.xpath(path)[0].text = value
       #     newfile = etree.tostring(problems,encoding='utf-8',method='xml', xml_declaration='<?xml version="1.0" encoding="utf-8"?>')
       #     newfile = str(newfile,'utf-8')#otherwise use utf-8
       # else: 
            #print(path, ' => ', problems.xpath(path)[0].text)
        problems.xpath(path)[0].text = value
        newfile = etree.tostring(problems,encoding='US-ASCII',method='xml', xml_declaration='<?xml version="1.0" encoding="utf-8"?>')
        newfile = str(newfile,'US-ASCII')#otherwise use utf-8
    with open(file + '/problem','w') as f:
    #   # newfile = etree.tostring(new)
         f.write(newfile)
        
        
        
    #display(problem)
       # problem.xpath(j)[0].text = value[j]
# Out:
# ['Utility1dot3MWe12CentsAnchorageDfcTEMP',
#  'Utility1dot3MWe12CentsAshlandDfbTEMP',
#  'Utility1dot3MWe12CentsAtlantaGACfaTEMP',
#  'Utility1dot3MWe12CentsBangorMEDfbTEMP',
#  'Utility1dot3MWe12CentsBendOreBskTEMP',
#  'Utility1dot3MWe12CentsBentonCountyOregonCsbTEMP',
#  'Utility1dot3MWe12CentsBirminghamALCfaTEMP',
#  'Utility1dot3MWe12CentsBismarckNDDfbTEMP',
#  'Utility1dot3MWe12CentsBlaineCountyMontanaBSkTEMP',
#  'Utility1dot3MWe12CentsBoiseIDBSkTEMP',
#  'Utility1dot3MWe12CentsBrewsterMADfbTEMP',
#  'Utility1dot3MWe12CentsBurlingtonVTDfaTEMP',
#  'Utility1dot3MWe12CentsButtonwillowBwkTEMP',
#  'Utility1dot3MWe12CentsCarsonCityNVBskTEMP',
#  'Utility1dot3MWe12CentsCheyenneWYBskTEMP',
#  'Utility1dot3MWe12CentsChicagoDfaTEMP',
#  'Utility1dot3MWe12CentsCoalvilleUTDfbTEMP',
#  'Utility1dot3MWe12CentsColumbiaMOCfaTEMP',
#  'Utility1dot3MWe12CentsColumbusOHDfaTEMP',
#  'Utility1dot3MWe12CentsCrestedButteCODfcTEMP',
#  'Utility1dot3MWe12CentsDesMoinesIADfaTEMP',
#  'Utility1dot3MWe12CentsDetroitMIDfaTEMP',
#  'Utility1dot3MWe12CentsEielsonAFBDfCTEMP',
#  'Utility1dot3MWe12CentsEvergladesAMTEMP',
#  'Utility1dot3MWe12CentsFlagstaffDsbTEMP',
#  'Utility1dot3MWe12CentsGreatFallsMTBskTEMP',
#  'Utility1dot3MWe12CentsHiloAfTEMP',
#  'Utility1dot3MWe12CentsIdahoFallsDfbTEMP',
#  'Utility1dot3MWe12CentsJacksonMSCfaTEMP',
#  'Utility1dot3MWe12CentsKauaiCfbTEMP',
#  'Utility1dot3MWe12CentsKootenaiCountyIDDsbTEMP',
#  'Utility1dot3MWe12CentsLancasterPADfaTEMP',
#  'Utility1dot3MWe12CentsLaredoTXBShTEMP',
#  'Utility1dot3MWe12CentsLincolnNEDfaTEMP',
#  'Utility1dot3MWe12CentsLittleRockARCfaTEMP',
#  'Utility1dot3MWe12CentsLongviewCsbTEMP',
#  'Utility1dot3MWe12CentsLosAlamosNMDfbTEMP',
#  'Utility1dot3MWe12CentsMarlintonWVCfbTEMP',
#  'Utility1dot3MWe12CentsMedfordORCsaTEMP',
#  'Utility1dot3MWe12CentsMemphisTNCfaTEMP',
#  'Utility1dot3MWe12CentsMiamiAfTEMP',
#  'Utility1dot3MWe12CentsMobileALCfaTEMP',
#  'Utility1dot3MWe12CentsMoscowIDCsbTEMP',
#  'Utility1dot3MWe12CentsNeahBayCfbTEMP',
#  'Utility1dot3MWe12CentsNOLACfaTEMP',
#  'Utility1dot3MWe12CentsOKCityCfaTEMP',
#  'Utility1dot3MWe12CentsORNLCfaTEMP',
#  'Utility1dot3MWe12CentsPhoenixAZBwhTEMP',
#  'Utility1dot3MWe12CentsPrescottAZCsaTEMP',
#  'Utility1dot3MWe12CentsPuebloBskTEMP',
#  'Utility1dot3MWe12CentsRaleighNCCfaTEMP',
#  'Utility1dot3MWe12CentsRapidCitySDBskTEMP',
#  'Utility1dot3MWe12CentsReddingCACsaTEMP',
#  'Utility1dot3MWe12CentsRichmondVACfaTEMP',
#  'Utility1dot3MWe12CentsSacramentoCsaTEMP',
#  'Utility1dot3MWe12CentsSouthBendINDfaTEMP',
#  'Utility1dot3MWe12CentsSyracuseDfbTEMP',
#  'Utility1dot3MWe12CentsTexasOilBShTEMP',
#  'Utility1dot3MWe12CentsUPMichDfbTEMP',
#  'Utility1dot3MWe12CentsVegasNVBwhTEMP',
#  'Utility1dot3MWe12CentsWadenaMNDfaTEMP',
#  'Utility1dot3MWe12CentsYumaAZBwhTEMP']

# %%
#Repack zip file (normal directory -> .zip)
## THIS STEP CURRENTLY BREAKS THE HOMER FILE
## Try using zipcode compression 
files = [f for f in os.listdir(folder) if f.endswith('TEMP')]
display(files)
for i in range(len(files)):
    file = files[i]
    directory = pathlib.Path(file)
    basefile = file.replace('TEMP','')
    basefile = basefile.replace('Utility1dot3MWe12Cents','Utility2dot6MWe12Cents')
    subprocess.run(["powershell.exe", "Compress-Archive -Path " + file + "\* -DestinationPath " + basefile + " -Force"])
    shutil.rmtree(file) #deletes old temp folders
# Out:
# ['Utility1dot3MWe12CentsAnchorageDfcTEMP',
#  'Utility1dot3MWe12CentsAshlandDfbTEMP',
#  'Utility1dot3MWe12CentsAtlantaGACfaTEMP',
#  'Utility1dot3MWe12CentsBangorMEDfbTEMP',
#  'Utility1dot3MWe12CentsBendOreBskTEMP',
#  'Utility1dot3MWe12CentsBentonCountyOregonCsbTEMP',
#  'Utility1dot3MWe12CentsBirminghamALCfaTEMP',
#  'Utility1dot3MWe12CentsBismarckNDDfbTEMP',
#  'Utility1dot3MWe12CentsBlaineCountyMontanaBSkTEMP',
#  'Utility1dot3MWe12CentsBoiseIDBSkTEMP',
#  'Utility1dot3MWe12CentsBrewsterMADfbTEMP',
#  'Utility1dot3MWe12CentsBurlingtonVTDfaTEMP',
#  'Utility1dot3MWe12CentsButtonwillowBwkTEMP',
#  'Utility1dot3MWe12CentsCarsonCityNVBskTEMP',
#  'Utility1dot3MWe12CentsCheyenneWYBskTEMP',
#  'Utility1dot3MWe12CentsChicagoDfaTEMP',
#  'Utility1dot3MWe12CentsCoalvilleUTDfbTEMP',
#  'Utility1dot3MWe12CentsColumbiaMOCfaTEMP',
#  'Utility1dot3MWe12CentsColumbusOHDfaTEMP',
#  'Utility1dot3MWe12CentsCrestedButteCODfcTEMP',
#  'Utility1dot3MWe12CentsDesMoinesIADfaTEMP',
#  'Utility1dot3MWe12CentsDetroitMIDfaTEMP',
#  'Utility1dot3MWe12CentsEielsonAFBDfCTEMP',
#  'Utility1dot3MWe12CentsEvergladesAMTEMP',
#  'Utility1dot3MWe12CentsFlagstaffDsbTEMP',
#  'Utility1dot3MWe12CentsGreatFallsMTBskTEMP',
#  'Utility1dot3MWe12CentsHiloAfTEMP',
#  'Utility1dot3MWe12CentsIdahoFallsDfbTEMP',
#  'Utility1dot3MWe12CentsJacksonMSCfaTEMP',
#  'Utility1dot3MWe12CentsKauaiCfbTEMP',
#  'Utility1dot3MWe12CentsKootenaiCountyIDDsbTEMP',
#  'Utility1dot3MWe12CentsLancasterPADfaTEMP',
#  'Utility1dot3MWe12CentsLaredoTXBShTEMP',
#  'Utility1dot3MWe12CentsLincolnNEDfaTEMP',
#  'Utility1dot3MWe12CentsLittleRockARCfaTEMP',
#  'Utility1dot3MWe12CentsLongviewCsbTEMP',
#  'Utility1dot3MWe12CentsLosAlamosNMDfbTEMP',
#  'Utility1dot3MWe12CentsMarlintonWVCfbTEMP',
#  'Utility1dot3MWe12CentsMedfordORCsaTEMP',
#  'Utility1dot3MWe12CentsMemphisTNCfaTEMP',
#  'Utility1dot3MWe12CentsMiamiAfTEMP',
#  'Utility1dot3MWe12CentsMobileALCfaTEMP',
#  'Utility1dot3MWe12CentsMoscowIDCsbTEMP',
#  'Utility1dot3MWe12CentsNeahBayCfbTEMP',
#  'Utility1dot3MWe12CentsNOLACfaTEMP',
#  'Utility1dot3MWe12CentsOKCityCfaTEMP',
#  'Utility1dot3MWe12CentsORNLCfaTEMP',
#  'Utility1dot3MWe12CentsPhoenixAZBwhTEMP',
#  'Utility1dot3MWe12CentsPrescottAZCsaTEMP',
#  'Utility1dot3MWe12CentsPuebloBskTEMP',
#  'Utility1dot3MWe12CentsRaleighNCCfaTEMP',
#  'Utility1dot3MWe12CentsRapidCitySDBskTEMP',
#  'Utility1dot3MWe12CentsReddingCACsaTEMP',
#  'Utility1dot3MWe12CentsRichmondVACfaTEMP',
#  'Utility1dot3MWe12CentsSacramentoCsaTEMP',
#  'Utility1dot3MWe12CentsSouthBendINDfaTEMP',
#  'Utility1dot3MWe12CentsSyracuseDfbTEMP',
#  'Utility1dot3MWe12CentsTexasOilBShTEMP',
#  'Utility1dot3MWe12CentsUPMichDfbTEMP',
#  'Utility1dot3MWe12CentsVegasNVBwhTEMP',
#  'Utility1dot3MWe12CentsWadenaMNDfaTEMP',
#  'Utility1dot3MWe12CentsYumaAZBwhTEMP']

# %%
# Reseal homer file (.zip -> .homer)
files = [f for f in os.listdir(folder) if f.endswith('.zip')]
n_files = np.size(files)
type(files)
for i in range(len(files)):
    file = files[i]
    base = os.path.splitext(file)[0]
    os.rename(file, base + '.homer')
