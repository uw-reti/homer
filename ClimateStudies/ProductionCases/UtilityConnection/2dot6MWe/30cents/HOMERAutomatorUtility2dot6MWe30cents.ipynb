# %% [markdown]
# # Zip folder unpacking script
# This script will do the following operations in order:
# Scan a folder
# create new calculation folder
# Loop the following actions for each homer script
#
#
#     Unseal homer template file (.homer -> .zip)
#
#
#     Unpack zip file (.zip -> normal directory)
#
#
#     Open 'problem' file
#
#
#     ####### NOT FOR THIS SCRIPT modify 'problem' file
#
#
#     Repack zip file (normal directory -> .zip)
#
#
#     Reseal homer file (.zip -> .homer)
#         ->[FOR THIS STEP TO FUNCTION PROPERLY, THE JUPYTER NOTEBOOK MUST BE EXECUTED ONE DIRECTORY HIGHER]
#
#
#     store updated input file in calculation folder
#
#
#     end

# %%
# Script initialization, make sure to set working directory
import os
import numpy as np 
import zipfile
import shutil
import zlib
import pathlib 
import subprocess
from lxml import etree, objectify
folder = 'd:/repo/homer/ClimateStudies/ProductionCases/UtilityConnection/2dot6MWe/30cents'

# %%
# Unsealing HOMER template files (.homer -> .zip)
files = [f for f in os.listdir(folder) if f.endswith('.homer')]
n_files = np.size(files)
display(files)
for i in range(len(files)):
    file = files[i]
    base = os.path.splitext(file)[0]
    os.rename(file, base + '.zip')
# Out:
# ['Utility1dot3MWe30CentsAnchorageDfc.homer',
#  'Utility1dot3MWe30CentsAshlandDfb.homer',
#  'Utility1dot3MWe30CentsAtlantaGACfa.homer',
#  'Utility1dot3MWe30CentsBangorMEDfb.homer',
#  'Utility1dot3MWe30CentsBendOreBsk.homer',
#  'Utility1dot3MWe30CentsBentonCountyOregonCsb.homer',
#  'Utility1dot3MWe30CentsBirminghamALCfa.homer',
#  'Utility1dot3MWe30CentsBismarckNDDfb.homer',
#  'Utility1dot3MWe30CentsBlaineCountyMontanaBSk.homer',
#  'Utility1dot3MWe30CentsBoiseIDBSk.homer',
#  'Utility1dot3MWe30CentsBrewsterMADfb.homer',
#  'Utility1dot3MWe30CentsBurlingtonVTDfa.homer',
#  'Utility1dot3MWe30CentsButtonwillowBwk.homer',
#  'Utility1dot3MWe30CentsCarsonCityNVBsk.homer',
#  'Utility1dot3MWe30CentsCheyenneWYBsk.homer',
#  'Utility1dot3MWe30CentsChicagoDfa.homer',
#  'Utility1dot3MWe30CentsCoalvilleUTDfb.homer',
#  'Utility1dot3MWe30CentsColumbiaMOCfa.homer',
#  'Utility1dot3MWe30CentsColumbusOHDfa.homer',
#  'Utility1dot3MWe30CentsCrestedButteCODfc.homer',
#  'Utility1dot3MWe30CentsDesMoinesIADfa.homer',
#  'Utility1dot3MWe30CentsDetroitMIDfa.homer',
#  'Utility1dot3MWe30CentsEielsonAFBDfC.homer',
#  'Utility1dot3MWe30CentsEvergladesAM.homer',
#  'Utility1dot3MWe30CentsFlagstaffDsb.homer',
#  'Utility1dot3MWe30CentsGreatFallsMTBsk.homer',
#  'Utility1dot3MWe30CentsHiloAf.homer',
#  'Utility1dot3MWe30CentsIdahoFallsDfb.homer',
#  'Utility1dot3MWe30CentsJacksonMSCfa.homer',
#  'Utility1dot3MWe30CentsKauaiCfb.homer',
#  'Utility1dot3MWe30CentsKootenaiCountyIDDsb.homer',
#  'Utility1dot3MWe30CentsLancasterPADfa.homer',
#  'Utility1dot3MWe30CentsLaredoTXBSh.homer',
#  'Utility1dot3MWe30CentsLincolnNEDfa.homer',
#  'Utility1dot3MWe30CentsLittleRockARCfa.homer',
#  'Utility1dot3MWe30CentsLongviewCsb.homer',
#  'Utility1dot3MWe30CentsLosAlamosNMDfb.homer',
#  'Utility1dot3MWe30CentsMarlintonWVCfb.homer',
#  'Utility1dot3MWe30CentsMedfordORCsa.homer',
#  'Utility1dot3MWe30CentsMemphisTNCfa.homer',
#  'Utility1dot3MWe30CentsMiamiAf.homer',
#  'Utility1dot3MWe30CentsMobileALCfa.homer',
#  'Utility1dot3MWe30CentsMoscowIDCsb.homer',
#  'Utility1dot3MWe30CentsNeahBayCfb.homer',
#  'Utility1dot3MWe30CentsNOLACfa.homer',
#  'Utility1dot3MWe30CentsOKCityCfa.homer',
#  'Utility1dot3MWe30CentsORNLCfa.homer',
#  'Utility1dot3MWe30CentsPhoenixAZBwh.homer',
#  'Utility1dot3MWe30CentsPrescottAZCsa.homer',
#  'Utility1dot3MWe30CentsPuebloBsk.homer',
#  'Utility1dot3MWe30CentsRaleighNCCfa.homer',
#  'Utility1dot3MWe30CentsRapidCitySDBsk.homer',
#  'Utility1dot3MWe30CentsReddingCACsa.homer',
#  'Utility1dot3MWe30CentsRichmondVACfa.homer',
#  'Utility1dot3MWe30CentsSacramentoCsa.homer',
#  'Utility1dot3MWe30CentsSouthBendINDfa.homer',
#  'Utility1dot3MWe30CentsSyracuseDfb.homer',
#  'Utility1dot3MWe30CentsTexasOilBSh.homer',
#  'Utility1dot3MWe30CentsUPMichDfb.homer',
#  'Utility1dot3MWe30CentsVegasNVBwh.homer',
#  'Utility1dot3MWe30CentsWadenaMNDfa.homer',
#  'Utility1dot3MWe30CentsYumaAZBwh.homer']

# %%
# Unpack zip file (.zip -> normal directory)
files = [f for f in os.listdir(folder) if f.endswith('.zip')]
n_files = np.size(files)
for i in range(len(files)):
    file = files[i]
    base = os.path.splitext(file)[0]
    with zipfile.ZipFile(file, 'r') as zip_ref:
        zip_ref.extractall(base + 'TEMP')
    os.remove(file)
# Opening each individiual 'problem' file after extraction

# %%
# (Within normal directory) Edit the .xml files for each HOMER problem.
files = [f for f in os.listdir(folder) if f.endswith('TEMP')]
display(files)
# paths to change as key, new value as value
new_data = {'/HomerProblem/SimulationParameters/Economics/ProjectLifetimeSensitivity/decimal': '60',
            '/HomerProblem/SimulationParameters/SystemControl/Optimizer/FocusFactor': '2',
            '/HomerProblem/Grid/ConnectionRates/GridConnectionRate/SellbackRateSensitivity/decimal': '0.00',
            '/HomerProblem/Grid/ConnectionRates/GridConnectionRate/GridPowerPriceSensitivity/decimal': '0.30',
            '/HomerProblem/Grid/PurchaseCapacityOptimization/decimal': '2600',
            '/HomerProblem/Grid/SaleCapacitySensitivity/decimal': '0',
            '/HomerProblem/Grid/MaxNetGridPurchasesSensitivity/decimal': '0'}
   
for i in range(len(files)):
    file = files[i]
    problems = etree.parse(file + '/problem')
    #os.remove(file + '/calculated-problem') #deletes old homer savestate
    for path, value in new_data.items():
       # if 'CapacityOptimization' in path:#not necessary currently, but can be used to differentiate values later
       #     problems.xpath(path)[0].text = value
       #     newfile = etree.tostring(problems,encoding='utf-8',method='xml', xml_declaration='<?xml version="1.0" encoding="utf-8"?>')
       #     newfile = str(newfile,'utf-8')#otherwise use utf-8
       # else: 
            #print(path, ' => ', problems.xpath(path)[0].text)
        problems.xpath(path)[0].text = value
        newfile = etree.tostring(problems,encoding='US-ASCII',method='xml', xml_declaration='<?xml version="1.0" encoding="utf-8"?>')
        newfile = str(newfile,'US-ASCII')#otherwise use utf-8
    with open(file + '/problem','w') as f:
    #   # newfile = etree.tostring(new)
         f.write(newfile)
        
        
        
    #display(problem)
       # problem.xpath(j)[0].text = value[j]
# Out:
# ['Utility1dot3MWe30CentsAnchorageDfcTEMP',
#  'Utility1dot3MWe30CentsAshlandDfbTEMP',
#  'Utility1dot3MWe30CentsAtlantaGACfaTEMP',
#  'Utility1dot3MWe30CentsBangorMEDfbTEMP',
#  'Utility1dot3MWe30CentsBendOreBskTEMP',
#  'Utility1dot3MWe30CentsBentonCountyOregonCsbTEMP',
#  'Utility1dot3MWe30CentsBirminghamALCfaTEMP',
#  'Utility1dot3MWe30CentsBismarckNDDfbTEMP',
#  'Utility1dot3MWe30CentsBlaineCountyMontanaBSkTEMP',
#  'Utility1dot3MWe30CentsBoiseIDBSkTEMP',
#  'Utility1dot3MWe30CentsBrewsterMADfbTEMP',
#  'Utility1dot3MWe30CentsBurlingtonVTDfaTEMP',
#  'Utility1dot3MWe30CentsButtonwillowBwkTEMP',
#  'Utility1dot3MWe30CentsCarsonCityNVBskTEMP',
#  'Utility1dot3MWe30CentsCheyenneWYBskTEMP',
#  'Utility1dot3MWe30CentsChicagoDfaTEMP',
#  'Utility1dot3MWe30CentsCoalvilleUTDfbTEMP',
#  'Utility1dot3MWe30CentsColumbiaMOCfaTEMP',
#  'Utility1dot3MWe30CentsColumbusOHDfaTEMP',
#  'Utility1dot3MWe30CentsCrestedButteCODfcTEMP',
#  'Utility1dot3MWe30CentsDesMoinesIADfaTEMP',
#  'Utility1dot3MWe30CentsDetroitMIDfaTEMP',
#  'Utility1dot3MWe30CentsEielsonAFBDfCTEMP',
#  'Utility1dot3MWe30CentsEvergladesAMTEMP',
#  'Utility1dot3MWe30CentsFlagstaffDsbTEMP',
#  'Utility1dot3MWe30CentsGreatFallsMTBskTEMP',
#  'Utility1dot3MWe30CentsHiloAfTEMP',
#  'Utility1dot3MWe30CentsIdahoFallsDfbTEMP',
#  'Utility1dot3MWe30CentsJacksonMSCfaTEMP',
#  'Utility1dot3MWe30CentsKauaiCfbTEMP',
#  'Utility1dot3MWe30CentsKootenaiCountyIDDsbTEMP',
#  'Utility1dot3MWe30CentsLancasterPADfaTEMP',
#  'Utility1dot3MWe30CentsLaredoTXBShTEMP',
#  'Utility1dot3MWe30CentsLincolnNEDfaTEMP',
#  'Utility1dot3MWe30CentsLittleRockARCfaTEMP',
#  'Utility1dot3MWe30CentsLongviewCsbTEMP',
#  'Utility1dot3MWe30CentsLosAlamosNMDfbTEMP',
#  'Utility1dot3MWe30CentsMarlintonWVCfbTEMP',
#  'Utility1dot3MWe30CentsMedfordORCsaTEMP',
#  'Utility1dot3MWe30CentsMemphisTNCfaTEMP',
#  'Utility1dot3MWe30CentsMiamiAfTEMP',
#  'Utility1dot3MWe30CentsMobileALCfaTEMP',
#  'Utility1dot3MWe30CentsMoscowIDCsbTEMP',
#  'Utility1dot3MWe30CentsNeahBayCfbTEMP',
#  'Utility1dot3MWe30CentsNOLACfaTEMP',
#  'Utility1dot3MWe30CentsOKCityCfaTEMP',
#  'Utility1dot3MWe30CentsORNLCfaTEMP',
#  'Utility1dot3MWe30CentsPhoenixAZBwhTEMP',
#  'Utility1dot3MWe30CentsPrescottAZCsaTEMP',
#  'Utility1dot3MWe30CentsPuebloBskTEMP',
#  'Utility1dot3MWe30CentsRaleighNCCfaTEMP',
#  'Utility1dot3MWe30CentsRapidCitySDBskTEMP',
#  'Utility1dot3MWe30CentsReddingCACsaTEMP',
#  'Utility1dot3MWe30CentsRichmondVACfaTEMP',
#  'Utility1dot3MWe30CentsSacramentoCsaTEMP',
#  'Utility1dot3MWe30CentsSouthBendINDfaTEMP',
#  'Utility1dot3MWe30CentsSyracuseDfbTEMP',
#  'Utility1dot3MWe30CentsTexasOilBShTEMP',
#  'Utility1dot3MWe30CentsUPMichDfbTEMP',
#  'Utility1dot3MWe30CentsVegasNVBwhTEMP',
#  'Utility1dot3MWe30CentsWadenaMNDfaTEMP',
#  'Utility1dot3MWe30CentsYumaAZBwhTEMP']

# %%
#Repack zip file (normal directory -> .zip)
## THIS STEP CURRENTLY BREAKS THE HOMER FILE
## Try using zipcode compression 
files = [f for f in os.listdir(folder) if f.endswith('TEMP')]
display(files)
for i in range(len(files)):
    file = files[i]
    directory = pathlib.Path(file)
    basefile = file.replace('TEMP','')
    basefile = basefile.replace('Utility1dot3MWe30Cents','Utility2dot6MWe30Cents')
    subprocess.run(["powershell.exe", "Compress-Archive -Path " + file + "\* -DestinationPath " + basefile + " -Force"])
    shutil.rmtree(file) #deletes old temp folders
# Out:
# ['Utility1dot3MWe30CentsAnchorageDfcTEMP',
#  'Utility1dot3MWe30CentsAshlandDfbTEMP',
#  'Utility1dot3MWe30CentsAtlantaGACfaTEMP',
#  'Utility1dot3MWe30CentsBangorMEDfbTEMP',
#  'Utility1dot3MWe30CentsBendOreBskTEMP',
#  'Utility1dot3MWe30CentsBentonCountyOregonCsbTEMP',
#  'Utility1dot3MWe30CentsBirminghamALCfaTEMP',
#  'Utility1dot3MWe30CentsBismarckNDDfbTEMP',
#  'Utility1dot3MWe30CentsBlaineCountyMontanaBSkTEMP',
#  'Utility1dot3MWe30CentsBoiseIDBSkTEMP',
#  'Utility1dot3MWe30CentsBrewsterMADfbTEMP',
#  'Utility1dot3MWe30CentsBurlingtonVTDfaTEMP',
#  'Utility1dot3MWe30CentsButtonwillowBwkTEMP',
#  'Utility1dot3MWe30CentsCarsonCityNVBskTEMP',
#  'Utility1dot3MWe30CentsCheyenneWYBskTEMP',
#  'Utility1dot3MWe30CentsChicagoDfaTEMP',
#  'Utility1dot3MWe30CentsCoalvilleUTDfbTEMP',
#  'Utility1dot3MWe30CentsColumbiaMOCfaTEMP',
#  'Utility1dot3MWe30CentsColumbusOHDfaTEMP',
#  'Utility1dot3MWe30CentsCrestedButteCODfcTEMP',
#  'Utility1dot3MWe30CentsDesMoinesIADfaTEMP',
#  'Utility1dot3MWe30CentsDetroitMIDfaTEMP',
#  'Utility1dot3MWe30CentsEielsonAFBDfCTEMP',
#  'Utility1dot3MWe30CentsEvergladesAMTEMP',
#  'Utility1dot3MWe30CentsFlagstaffDsbTEMP',
#  'Utility1dot3MWe30CentsGreatFallsMTBskTEMP',
#  'Utility1dot3MWe30CentsHiloAfTEMP',
#  'Utility1dot3MWe30CentsIdahoFallsDfbTEMP',
#  'Utility1dot3MWe30CentsJacksonMSCfaTEMP',
#  'Utility1dot3MWe30CentsKauaiCfbTEMP',
#  'Utility1dot3MWe30CentsKootenaiCountyIDDsbTEMP',
#  'Utility1dot3MWe30CentsLancasterPADfaTEMP',
#  'Utility1dot3MWe30CentsLaredoTXBShTEMP',
#  'Utility1dot3MWe30CentsLincolnNEDfaTEMP',
#  'Utility1dot3MWe30CentsLittleRockARCfaTEMP',
#  'Utility1dot3MWe30CentsLongviewCsbTEMP',
#  'Utility1dot3MWe30CentsLosAlamosNMDfbTEMP',
#  'Utility1dot3MWe30CentsMarlintonWVCfbTEMP',
#  'Utility1dot3MWe30CentsMedfordORCsaTEMP',
#  'Utility1dot3MWe30CentsMemphisTNCfaTEMP',
#  'Utility1dot3MWe30CentsMiamiAfTEMP',
#  'Utility1dot3MWe30CentsMobileALCfaTEMP',
#  'Utility1dot3MWe30CentsMoscowIDCsbTEMP',
#  'Utility1dot3MWe30CentsNeahBayCfbTEMP',
#  'Utility1dot3MWe30CentsNOLACfaTEMP',
#  'Utility1dot3MWe30CentsOKCityCfaTEMP',
#  'Utility1dot3MWe30CentsORNLCfaTEMP',
#  'Utility1dot3MWe30CentsPhoenixAZBwhTEMP',
#  'Utility1dot3MWe30CentsPrescottAZCsaTEMP',
#  'Utility1dot3MWe30CentsPuebloBskTEMP',
#  'Utility1dot3MWe30CentsRaleighNCCfaTEMP',
#  'Utility1dot3MWe30CentsRapidCitySDBskTEMP',
#  'Utility1dot3MWe30CentsReddingCACsaTEMP',
#  'Utility1dot3MWe30CentsRichmondVACfaTEMP',
#  'Utility1dot3MWe30CentsSacramentoCsaTEMP',
#  'Utility1dot3MWe30CentsSouthBendINDfaTEMP',
#  'Utility1dot3MWe30CentsSyracuseDfbTEMP',
#  'Utility1dot3MWe30CentsTexasOilBShTEMP',
#  'Utility1dot3MWe30CentsUPMichDfbTEMP',
#  'Utility1dot3MWe30CentsVegasNVBwhTEMP',
#  'Utility1dot3MWe30CentsWadenaMNDfaTEMP',
#  'Utility1dot3MWe30CentsYumaAZBwhTEMP']

# %%
# Reseal homer file (.zip -> .homer)
files = [f for f in os.listdir(folder) if f.endswith('.zip')]
n_files = np.size(files)
type(files)
for i in range(len(files)):
    file = files[i]
    base = os.path.splitext(file)[0]
    os.rename(file, base + '.homer')
