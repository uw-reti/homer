# %% [markdown]
# # Zip folder unpacking script
# This script will do the following operations in order:
# Scan a folder
# create new calculation folder
# Loop the following actions for each homer script
#
#
#     Unseal homer template file (.homer -> .zip)
#
#
#     Unpack zip file (.zip -> normal directory)
#
#
#     Open 'problem' file
#
#
#     ####### NOT FOR THIS SCRIPT modify 'problem' file
#
#
#     Repack zip file (normal directory -> .zip)
#
#
#     Reseal homer file (.zip -> .homer)
#         ->[FOR THIS STEP TO FUNCTION PROPERLY, THE JUPYTER NOTEBOOK MUST BE EXECUTED ONE DIRECTORY HIGHER]
#
#
#     store updated input file in calculation folder
#
#
#     end

# %%
# Script initialization, make sure to set working directory
import os
import numpy as np 
import zipfile
import shutil
import zlib
import pathlib 
import subprocess
from lxml import etree, objectify
folder = 'd:/repo/homer/ClimateStudies/ProductionCases/UtilityConnection/2dot6MWe/24cents'

# %%
# Unsealing HOMER template files (.homer -> .zip)
files = [f for f in os.listdir(folder) if f.endswith('.homer')]
n_files = np.size(files)
display(files)
for i in range(len(files)):
    file = files[i]
    base = os.path.splitext(file)[0]
    os.rename(file, base + '.zip')
# Out:
# ['Utility1dot3MWe24CentsAnchorageDfc.homer',
#  'Utility1dot3MWe24CentsAshlandDfb.homer',
#  'Utility1dot3MWe24CentsAtlantaGACfa.homer',
#  'Utility1dot3MWe24CentsBangorMEDfb.homer',
#  'Utility1dot3MWe24CentsBendOreBsk.homer',
#  'Utility1dot3MWe24CentsBentonCountyOregonCsb.homer',
#  'Utility1dot3MWe24CentsBirminghamALCfa.homer',
#  'Utility1dot3MWe24CentsBismarckNDDfb.homer',
#  'Utility1dot3MWe24CentsBlaineCountyMontanaBSk.homer',
#  'Utility1dot3MWe24CentsBoiseIDBSk.homer',
#  'Utility1dot3MWe24CentsBrewsterMADfb.homer',
#  'Utility1dot3MWe24CentsBurlingtonVTDfa.homer',
#  'Utility1dot3MWe24CentsButtonwillowBwk.homer',
#  'Utility1dot3MWe24CentsCarsonCityNVBsk.homer',
#  'Utility1dot3MWe24CentsCheyenneWYBsk.homer',
#  'Utility1dot3MWe24CentsChicagoDfa.homer',
#  'Utility1dot3MWe24CentsCoalvilleUTDfb.homer',
#  'Utility1dot3MWe24CentsColumbiaMOCfa.homer',
#  'Utility1dot3MWe24CentsColumbusOHDfa.homer',
#  'Utility1dot3MWe24CentsCrestedButteCODfc.homer',
#  'Utility1dot3MWe24CentsDesMoinesIADfa.homer',
#  'Utility1dot3MWe24CentsDetroitMIDfa.homer',
#  'Utility1dot3MWe24CentsEielsonAFBDfC.homer',
#  'Utility1dot3MWe24CentsEvergladesAM.homer',
#  'Utility1dot3MWe24CentsFlagstaffDsb.homer',
#  'Utility1dot3MWe24CentsGreatFallsMTBsk.homer',
#  'Utility1dot3MWe24CentsHiloAf.homer',
#  'Utility1dot3MWe24CentsIdahoFallsDfb.homer',
#  'Utility1dot3MWe24CentsJacksonMSCfa.homer',
#  'Utility1dot3MWe24CentsKauaiCfb.homer',
#  'Utility1dot3MWe24CentsKootenaiCountyIDDsb.homer',
#  'Utility1dot3MWe24CentsLancasterPADfa.homer',
#  'Utility1dot3MWe24CentsLaredoTXBSh.homer',
#  'Utility1dot3MWe24CentsLincolnNEDfa.homer',
#  'Utility1dot3MWe24CentsLittleRockARCfa.homer',
#  'Utility1dot3MWe24CentsLongviewCsb.homer',
#  'Utility1dot3MWe24CentsLosAlamosNMDfb.homer',
#  'Utility1dot3MWe24CentsMarlintonWVCfb.homer',
#  'Utility1dot3MWe24CentsMedfordORCsa.homer',
#  'Utility1dot3MWe24CentsMemphisTNCfa.homer',
#  'Utility1dot3MWe24CentsMiamiAf.homer',
#  'Utility1dot3MWe24CentsMobileALCfa.homer',
#  'Utility1dot3MWe24CentsMoscowIDCsb.homer',
#  'Utility1dot3MWe24CentsNeahBayCfb.homer',
#  'Utility1dot3MWe24CentsNOLACfa.homer',
#  'Utility1dot3MWe24CentsOKCityCfa.homer',
#  'Utility1dot3MWe24CentsORNLCfa.homer',
#  'Utility1dot3MWe24CentsPhoenixAZBwh.homer',
#  'Utility1dot3MWe24CentsPrescottAZCsa.homer',
#  'Utility1dot3MWe24CentsPuebloBsk.homer',
#  'Utility1dot3MWe24CentsRaleighNCCfa.homer',
#  'Utility1dot3MWe24CentsRapidCitySDBsk.homer',
#  'Utility1dot3MWe24CentsReddingCACsa.homer',
#  'Utility1dot3MWe24CentsRichmondVACfa.homer',
#  'Utility1dot3MWe24CentsSacramentoCsa.homer',
#  'Utility1dot3MWe24CentsSouthBendINDfa.homer',
#  'Utility1dot3MWe24CentsSyracuseDfb.homer',
#  'Utility1dot3MWe24CentsTexasOilBSh.homer',
#  'Utility1dot3MWe24CentsUPMichDfb.homer',
#  'Utility1dot3MWe24CentsVegasNVBwh.homer',
#  'Utility1dot3MWe24CentsWadenaMNDfa.homer',
#  'Utility1dot3MWe24CentsYumaAZBwh.homer']

# %%
# Unpack zip file (.zip -> normal directory)
files = [f for f in os.listdir(folder) if f.endswith('.zip')]
n_files = np.size(files)
for i in range(len(files)):
    file = files[i]
    base = os.path.splitext(file)[0]
    with zipfile.ZipFile(file, 'r') as zip_ref:
        zip_ref.extractall(base + 'TEMP')
    os.remove(file)
# Opening each individiual 'problem' file after extraction

# %%
# (Within normal directory) Edit the .xml files for each HOMER problem.
files = [f for f in os.listdir(folder) if f.endswith('TEMP')]
display(files)
# paths to change as key, new value as value
new_data = {'/HomerProblem/SimulationParameters/Economics/ProjectLifetimeSensitivity/decimal': '60',
            '/HomerProblem/SimulationParameters/SystemControl/Optimizer/FocusFactor': '2',
            '/HomerProblem/Grid/ConnectionRates/GridConnectionRate/SellbackRateSensitivity/decimal': '0.00',
            '/HomerProblem/Grid/ConnectionRates/GridConnectionRate/GridPowerPriceSensitivity/decimal': '0.24',
            '/HomerProblem/Grid/PurchaseCapacityOptimization/decimal': '2600',
            '/HomerProblem/Grid/SaleCapacitySensitivity/decimal': '0',
            '/HomerProblem/Grid/MaxNetGridPurchasesSensitivity/decimal': '0'}
   
for i in range(len(files)):
    file = files[i]
    problems = etree.parse(file + '/problem')
    #os.remove(file + '/calculated-problem') #deletes old homer savestate
    for path, value in new_data.items():
       # if 'CapacityOptimization' in path:#not necessary currently, but can be used to differentiate values later
       #     problems.xpath(path)[0].text = value
       #     newfile = etree.tostring(problems,encoding='utf-8',method='xml', xml_declaration='<?xml version="1.0" encoding="utf-8"?>')
       #     newfile = str(newfile,'utf-8')#otherwise use utf-8
       # else: 
            #print(path, ' => ', problems.xpath(path)[0].text)
        problems.xpath(path)[0].text = value
        newfile = etree.tostring(problems,encoding='US-ASCII',method='xml', xml_declaration='<?xml version="1.0" encoding="utf-8"?>')
        newfile = str(newfile,'US-ASCII')#otherwise use utf-8
    with open(file + '/problem','w') as f:
    #   # newfile = etree.tostring(new)
         f.write(newfile)
        
        
        
    #display(problem)
       # problem.xpath(j)[0].text = value[j]
# Out:
# ['Utility1dot3MWe24CentsAnchorageDfcTEMP',
#  'Utility1dot3MWe24CentsAshlandDfbTEMP',
#  'Utility1dot3MWe24CentsAtlantaGACfaTEMP',
#  'Utility1dot3MWe24CentsBangorMEDfbTEMP',
#  'Utility1dot3MWe24CentsBendOreBskTEMP',
#  'Utility1dot3MWe24CentsBentonCountyOregonCsbTEMP',
#  'Utility1dot3MWe24CentsBirminghamALCfaTEMP',
#  'Utility1dot3MWe24CentsBismarckNDDfbTEMP',
#  'Utility1dot3MWe24CentsBlaineCountyMontanaBSkTEMP',
#  'Utility1dot3MWe24CentsBoiseIDBSkTEMP',
#  'Utility1dot3MWe24CentsBrewsterMADfbTEMP',
#  'Utility1dot3MWe24CentsBurlingtonVTDfaTEMP',
#  'Utility1dot3MWe24CentsButtonwillowBwkTEMP',
#  'Utility1dot3MWe24CentsCarsonCityNVBskTEMP',
#  'Utility1dot3MWe24CentsCheyenneWYBskTEMP',
#  'Utility1dot3MWe24CentsChicagoDfaTEMP',
#  'Utility1dot3MWe24CentsCoalvilleUTDfbTEMP',
#  'Utility1dot3MWe24CentsColumbiaMOCfaTEMP',
#  'Utility1dot3MWe24CentsColumbusOHDfaTEMP',
#  'Utility1dot3MWe24CentsCrestedButteCODfcTEMP',
#  'Utility1dot3MWe24CentsDesMoinesIADfaTEMP',
#  'Utility1dot3MWe24CentsDetroitMIDfaTEMP',
#  'Utility1dot3MWe24CentsEielsonAFBDfCTEMP',
#  'Utility1dot3MWe24CentsEvergladesAMTEMP',
#  'Utility1dot3MWe24CentsFlagstaffDsbTEMP',
#  'Utility1dot3MWe24CentsGreatFallsMTBskTEMP',
#  'Utility1dot3MWe24CentsHiloAfTEMP',
#  'Utility1dot3MWe24CentsIdahoFallsDfbTEMP',
#  'Utility1dot3MWe24CentsJacksonMSCfaTEMP',
#  'Utility1dot3MWe24CentsKauaiCfbTEMP',
#  'Utility1dot3MWe24CentsKootenaiCountyIDDsbTEMP',
#  'Utility1dot3MWe24CentsLancasterPADfaTEMP',
#  'Utility1dot3MWe24CentsLaredoTXBShTEMP',
#  'Utility1dot3MWe24CentsLincolnNEDfaTEMP',
#  'Utility1dot3MWe24CentsLittleRockARCfaTEMP',
#  'Utility1dot3MWe24CentsLongviewCsbTEMP',
#  'Utility1dot3MWe24CentsLosAlamosNMDfbTEMP',
#  'Utility1dot3MWe24CentsMarlintonWVCfbTEMP',
#  'Utility1dot3MWe24CentsMedfordORCsaTEMP',
#  'Utility1dot3MWe24CentsMemphisTNCfaTEMP',
#  'Utility1dot3MWe24CentsMiamiAfTEMP',
#  'Utility1dot3MWe24CentsMobileALCfaTEMP',
#  'Utility1dot3MWe24CentsMoscowIDCsbTEMP',
#  'Utility1dot3MWe24CentsNeahBayCfbTEMP',
#  'Utility1dot3MWe24CentsNOLACfaTEMP',
#  'Utility1dot3MWe24CentsOKCityCfaTEMP',
#  'Utility1dot3MWe24CentsORNLCfaTEMP',
#  'Utility1dot3MWe24CentsPhoenixAZBwhTEMP',
#  'Utility1dot3MWe24CentsPrescottAZCsaTEMP',
#  'Utility1dot3MWe24CentsPuebloBskTEMP',
#  'Utility1dot3MWe24CentsRaleighNCCfaTEMP',
#  'Utility1dot3MWe24CentsRapidCitySDBskTEMP',
#  'Utility1dot3MWe24CentsReddingCACsaTEMP',
#  'Utility1dot3MWe24CentsRichmondVACfaTEMP',
#  'Utility1dot3MWe24CentsSacramentoCsaTEMP',
#  'Utility1dot3MWe24CentsSouthBendINDfaTEMP',
#  'Utility1dot3MWe24CentsSyracuseDfbTEMP',
#  'Utility1dot3MWe24CentsTexasOilBShTEMP',
#  'Utility1dot3MWe24CentsUPMichDfbTEMP',
#  'Utility1dot3MWe24CentsVegasNVBwhTEMP',
#  'Utility1dot3MWe24CentsWadenaMNDfaTEMP',
#  'Utility1dot3MWe24CentsYumaAZBwhTEMP']

# %%
#Repack zip file (normal directory -> .zip)
## THIS STEP CURRENTLY BREAKS THE HOMER FILE
## Try using zipcode compression 
files = [f for f in os.listdir(folder) if f.endswith('TEMP')]
display(files)
for i in range(len(files)):
    file = files[i]
    directory = pathlib.Path(file)
    basefile = file.replace('TEMP','')
    basefile = basefile.replace('Utility1dot3MWe24Cents','Utility2dot6MWe24Cents')
    subprocess.run(["powershell.exe", "Compress-Archive -Path " + file + "\* -DestinationPath " + basefile + " -Force"])
    shutil.rmtree(file) #deletes old temp folders
# Out:
# ['Utility1dot3MWe24CentsAnchorageDfcTEMP',
#  'Utility1dot3MWe24CentsAshlandDfbTEMP',
#  'Utility1dot3MWe24CentsAtlantaGACfaTEMP',
#  'Utility1dot3MWe24CentsBangorMEDfbTEMP',
#  'Utility1dot3MWe24CentsBendOreBskTEMP',
#  'Utility1dot3MWe24CentsBentonCountyOregonCsbTEMP',
#  'Utility1dot3MWe24CentsBirminghamALCfaTEMP',
#  'Utility1dot3MWe24CentsBismarckNDDfbTEMP',
#  'Utility1dot3MWe24CentsBlaineCountyMontanaBSkTEMP',
#  'Utility1dot3MWe24CentsBoiseIDBSkTEMP',
#  'Utility1dot3MWe24CentsBrewsterMADfbTEMP',
#  'Utility1dot3MWe24CentsBurlingtonVTDfaTEMP',
#  'Utility1dot3MWe24CentsButtonwillowBwkTEMP',
#  'Utility1dot3MWe24CentsCarsonCityNVBskTEMP',
#  'Utility1dot3MWe24CentsCheyenneWYBskTEMP',
#  'Utility1dot3MWe24CentsChicagoDfaTEMP',
#  'Utility1dot3MWe24CentsCoalvilleUTDfbTEMP',
#  'Utility1dot3MWe24CentsColumbiaMOCfaTEMP',
#  'Utility1dot3MWe24CentsColumbusOHDfaTEMP',
#  'Utility1dot3MWe24CentsCrestedButteCODfcTEMP',
#  'Utility1dot3MWe24CentsDesMoinesIADfaTEMP',
#  'Utility1dot3MWe24CentsDetroitMIDfaTEMP',
#  'Utility1dot3MWe24CentsEielsonAFBDfCTEMP',
#  'Utility1dot3MWe24CentsEvergladesAMTEMP',
#  'Utility1dot3MWe24CentsFlagstaffDsbTEMP',
#  'Utility1dot3MWe24CentsGreatFallsMTBskTEMP',
#  'Utility1dot3MWe24CentsHiloAfTEMP',
#  'Utility1dot3MWe24CentsIdahoFallsDfbTEMP',
#  'Utility1dot3MWe24CentsJacksonMSCfaTEMP',
#  'Utility1dot3MWe24CentsKauaiCfbTEMP',
#  'Utility1dot3MWe24CentsKootenaiCountyIDDsbTEMP',
#  'Utility1dot3MWe24CentsLancasterPADfaTEMP',
#  'Utility1dot3MWe24CentsLaredoTXBShTEMP',
#  'Utility1dot3MWe24CentsLincolnNEDfaTEMP',
#  'Utility1dot3MWe24CentsLittleRockARCfaTEMP',
#  'Utility1dot3MWe24CentsLongviewCsbTEMP',
#  'Utility1dot3MWe24CentsLosAlamosNMDfbTEMP',
#  'Utility1dot3MWe24CentsMarlintonWVCfbTEMP',
#  'Utility1dot3MWe24CentsMedfordORCsaTEMP',
#  'Utility1dot3MWe24CentsMemphisTNCfaTEMP',
#  'Utility1dot3MWe24CentsMiamiAfTEMP',
#  'Utility1dot3MWe24CentsMobileALCfaTEMP',
#  'Utility1dot3MWe24CentsMoscowIDCsbTEMP',
#  'Utility1dot3MWe24CentsNeahBayCfbTEMP',
#  'Utility1dot3MWe24CentsNOLACfaTEMP',
#  'Utility1dot3MWe24CentsOKCityCfaTEMP',
#  'Utility1dot3MWe24CentsORNLCfaTEMP',
#  'Utility1dot3MWe24CentsPhoenixAZBwhTEMP',
#  'Utility1dot3MWe24CentsPrescottAZCsaTEMP',
#  'Utility1dot3MWe24CentsPuebloBskTEMP',
#  'Utility1dot3MWe24CentsRaleighNCCfaTEMP',
#  'Utility1dot3MWe24CentsRapidCitySDBskTEMP',
#  'Utility1dot3MWe24CentsReddingCACsaTEMP',
#  'Utility1dot3MWe24CentsRichmondVACfaTEMP',
#  'Utility1dot3MWe24CentsSacramentoCsaTEMP',
#  'Utility1dot3MWe24CentsSouthBendINDfaTEMP',
#  'Utility1dot3MWe24CentsSyracuseDfbTEMP',
#  'Utility1dot3MWe24CentsTexasOilBShTEMP',
#  'Utility1dot3MWe24CentsUPMichDfbTEMP',
#  'Utility1dot3MWe24CentsVegasNVBwhTEMP',
#  'Utility1dot3MWe24CentsWadenaMNDfaTEMP',
#  'Utility1dot3MWe24CentsYumaAZBwhTEMP']

# %%
# Reseal homer file (.zip -> .homer)
files = [f for f in os.listdir(folder) if f.endswith('.zip')]
n_files = np.size(files)
type(files)
for i in range(len(files)):
    file = files[i]
    base = os.path.splitext(file)[0]
    os.rename(file, base + '.homer')
