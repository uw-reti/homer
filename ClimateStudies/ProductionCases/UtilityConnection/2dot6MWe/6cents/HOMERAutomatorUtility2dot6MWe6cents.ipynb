# %% [markdown]
# # Zip folder unpacking script
# This script will do the following operations in order:
# Scan a folder
# create new calculation folder
# Loop the following actions for each homer script
#
#
#     Unseal homer template file (.homer -> .zip)
#
#
#     Unpack zip file (.zip -> normal directory)
#
#
#     Open 'problem' file
#
#
#     ####### NOT FOR THIS SCRIPT modify 'problem' file
#
#
#     Repack zip file (normal directory -> .zip)
#
#
#     Reseal homer file (.zip -> .homer)
#         ->[FOR THIS STEP TO FUNCTION PROPERLY, THE JUPYTER NOTEBOOK MUST BE EXECUTED ONE DIRECTORY HIGHER]
#
#
#     store updated input file in calculation folder
#
#
#     end

# %%
# Script initialization, make sure to set working directory
import os
import numpy as np 
import zipfile
import shutil
import zlib
import pathlib 
import subprocess
from lxml import etree, objectify
folder = 'd:/repo/homer/ClimateStudies/ProductionCases/UtilityConnection/2dot6MWe/6cents'

# %%
# Unsealing HOMER template files (.homer -> .zip)
files = [f for f in os.listdir(folder) if f.endswith('.homer')]
n_files = np.size(files)
display(files)
for i in range(len(files)):
    file = files[i]
    base = os.path.splitext(file)[0]
    os.rename(file, base + '.zip')
# Out:
# ['Utility1dot3MWe6CentsAnchorageDfc.homer',
#  'Utility1dot3MWe6CentsAshlandDfb.homer',
#  'Utility1dot3MWe6CentsAtlantaGACfa.homer',
#  'Utility1dot3MWe6CentsBangorMEDfb.homer',
#  'Utility1dot3MWe6CentsBendOreBsk.homer',
#  'Utility1dot3MWe6CentsBentonCountyOregonCsb.homer',
#  'Utility1dot3MWe6CentsBirminghamALCfa.homer',
#  'Utility1dot3MWe6CentsBismarckNDDfb.homer',
#  'Utility1dot3MWe6CentsBlaineCountyMontanaBSk.homer',
#  'Utility1dot3MWe6CentsBoiseIDBSk.homer',
#  'Utility1dot3MWe6CentsBrewsterMADfb.homer',
#  'Utility1dot3MWe6CentsBurlingtonVTDfa.homer',
#  'Utility1dot3MWe6CentsButtonwillowBwk.homer',
#  'Utility1dot3MWe6CentsCarsonCityNVBsk.homer',
#  'Utility1dot3MWe6CentsCheyenneWYBsk.homer',
#  'Utility1dot3MWe6CentsChicagoDfa.homer',
#  'Utility1dot3MWe6CentsCoalvilleUTDfb.homer',
#  'Utility1dot3MWe6CentsColumbiaMOCfa.homer',
#  'Utility1dot3MWe6CentsColumbusOHDfa.homer',
#  'Utility1dot3MWe6CentsCrestedButteCODfc.homer',
#  'Utility1dot3MWe6CentsDesMoinesIADfa.homer',
#  'Utility1dot3MWe6CentsDetroitMIDfa.homer',
#  'Utility1dot3MWe6CentsEielsonAFBDfC.homer',
#  'Utility1dot3MWe6CentsEvergladesAM.homer',
#  'Utility1dot3MWe6CentsFlagstaffDsb.homer',
#  'Utility1dot3MWe6CentsGreatFallsMTBsk.homer',
#  'Utility1dot3MWe6CentsHiloAf.homer',
#  'Utility1dot3MWe6CentsIdahoFallsDfb.homer',
#  'Utility1dot3MWe6CentsJacksonMSCfa.homer',
#  'Utility1dot3MWe6CentsKauaiCfb.homer',
#  'Utility1dot3MWe6CentsKootenaiCountyIDDsb.homer',
#  'Utility1dot3MWe6CentsLancasterPADfa.homer',
#  'Utility1dot3MWe6CentsLaredoTXBSh.homer',
#  'Utility1dot3MWe6CentsLincolnNEDfa.homer',
#  'Utility1dot3MWe6CentsLittleRockARCfa.homer',
#  'Utility1dot3MWe6CentsLongviewCsb.homer',
#  'Utility1dot3MWe6CentsLosAlamosNMDfb.homer',
#  'Utility1dot3MWe6CentsMarlintonWVCfb.homer',
#  'Utility1dot3MWe6CentsMedfordORCsa.homer',
#  'Utility1dot3MWe6CentsMemphisTNCfa.homer',
#  'Utility1dot3MWe6CentsMiamiAf.homer',
#  'Utility1dot3MWe6CentsMobileALCfa.homer',
#  'Utility1dot3MWe6CentsMoscowIDCsb.homer',
#  'Utility1dot3MWe6CentsNeahBayCfb.homer',
#  'Utility1dot3MWe6CentsNOLACfa.homer',
#  'Utility1dot3MWe6CentsOKCityCfa.homer',
#  'Utility1dot3MWe6CentsORNLCfa.homer',
#  'Utility1dot3MWe6CentsPhoenixAZBwh.homer',
#  'Utility1dot3MWe6CentsPrescottAZCsa.homer',
#  'Utility1dot3MWe6CentsPuebloBsk.homer',
#  'Utility1dot3MWe6CentsRaleighNCCfa.homer',
#  'Utility1dot3MWe6CentsRapidCitySDBsk.homer',
#  'Utility1dot3MWe6CentsReddingCACsa.homer',
#  'Utility1dot3MWe6CentsRichmondVACfa.homer',
#  'Utility1dot3MWe6CentsSacramentoCsa.homer',
#  'Utility1dot3MWe6CentsSouthBendINDfa.homer',
#  'Utility1dot3MWe6CentsSyracuseDfb.homer',
#  'Utility1dot3MWe6CentsTexasOilBSh.homer',
#  'Utility1dot3MWe6CentsUPMichDfb.homer',
#  'Utility1dot3MWe6CentsVegasNVBwh.homer',
#  'Utility1dot3MWe6CentsWadenaMNDfa.homer',
#  'Utility1dot3MWe6CentsYumaAZBwh.homer']

# %%
# Unpack zip file (.zip -> normal directory)
files = [f for f in os.listdir(folder) if f.endswith('.zip')]
n_files = np.size(files)
for i in range(len(files)):
    file = files[i]
    base = os.path.splitext(file)[0]
    with zipfile.ZipFile(file, 'r') as zip_ref:
        zip_ref.extractall(base + 'TEMP')
    os.remove(file)
# Opening each individiual 'problem' file after extraction

# %%
# (Within normal directory) Edit the .xml files for each HOMER problem.
files = [f for f in os.listdir(folder) if f.endswith('TEMP')]
display(files)
# paths to change as key, new value as value
new_data = {'/HomerProblem/SimulationParameters/Economics/ProjectLifetimeSensitivity/decimal': '60',
            '/HomerProblem/SimulationParameters/SystemControl/Optimizer/FocusFactor': '2',
            '/HomerProblem/Grid/ConnectionRates/GridConnectionRate/SellbackRateSensitivity/decimal': '0.00',
            '/HomerProblem/Grid/ConnectionRates/GridConnectionRate/GridPowerPriceSensitivity/decimal': '0.06',
            '/HomerProblem/Grid/PurchaseCapacityOptimization/decimal': '2600',
            '/HomerProblem/Grid/SaleCapacitySensitivity/decimal': '0',
            '/HomerProblem/Grid/MaxNetGridPurchasesSensitivity/decimal': '0'}
   
for i in range(len(files)):
    file = files[i]
    problems = etree.parse(file + '/problem')
    #os.remove(file + '/calculated-problem') #deletes old homer savestate
    for path, value in new_data.items():
       # if 'CapacityOptimization' in path:#not necessary currently, but can be used to differentiate values later
       #     problems.xpath(path)[0].text = value
       #     newfile = etree.tostring(problems,encoding='utf-8',method='xml', xml_declaration='<?xml version="1.0" encoding="utf-8"?>')
       #     newfile = str(newfile,'utf-8')#otherwise use utf-8
       # else: 
            #print(path, ' => ', problems.xpath(path)[0].text)
        problems.xpath(path)[0].text = value
        newfile = etree.tostring(problems,encoding='US-ASCII',method='xml', xml_declaration='<?xml version="1.0" encoding="utf-8"?>')
        newfile = str(newfile,'US-ASCII')#otherwise use utf-8
    with open(file + '/problem','w') as f:
    #   # newfile = etree.tostring(new)
         f.write(newfile)
        
        
        
    #display(problem)
       # problem.xpath(j)[0].text = value[j]
# Out:
# ['Utility1dot3MWe6CentsAnchorageDfcTEMP',
#  'Utility1dot3MWe6CentsAshlandDfbTEMP',
#  'Utility1dot3MWe6CentsAtlantaGACfaTEMP',
#  'Utility1dot3MWe6CentsBangorMEDfbTEMP',
#  'Utility1dot3MWe6CentsBendOreBskTEMP',
#  'Utility1dot3MWe6CentsBentonCountyOregonCsbTEMP',
#  'Utility1dot3MWe6CentsBirminghamALCfaTEMP',
#  'Utility1dot3MWe6CentsBismarckNDDfbTEMP',
#  'Utility1dot3MWe6CentsBlaineCountyMontanaBSkTEMP',
#  'Utility1dot3MWe6CentsBoiseIDBSkTEMP',
#  'Utility1dot3MWe6CentsBrewsterMADfbTEMP',
#  'Utility1dot3MWe6CentsBurlingtonVTDfaTEMP',
#  'Utility1dot3MWe6CentsButtonwillowBwkTEMP',
#  'Utility1dot3MWe6CentsCarsonCityNVBskTEMP',
#  'Utility1dot3MWe6CentsCheyenneWYBskTEMP',
#  'Utility1dot3MWe6CentsChicagoDfaTEMP',
#  'Utility1dot3MWe6CentsCoalvilleUTDfbTEMP',
#  'Utility1dot3MWe6CentsColumbiaMOCfaTEMP',
#  'Utility1dot3MWe6CentsColumbusOHDfaTEMP',
#  'Utility1dot3MWe6CentsCrestedButteCODfcTEMP',
#  'Utility1dot3MWe6CentsDesMoinesIADfaTEMP',
#  'Utility1dot3MWe6CentsDetroitMIDfaTEMP',
#  'Utility1dot3MWe6CentsEielsonAFBDfCTEMP',
#  'Utility1dot3MWe6CentsEvergladesAMTEMP',
#  'Utility1dot3MWe6CentsFlagstaffDsbTEMP',
#  'Utility1dot3MWe6CentsGreatFallsMTBskTEMP',
#  'Utility1dot3MWe6CentsHiloAfTEMP',
#  'Utility1dot3MWe6CentsIdahoFallsDfbTEMP',
#  'Utility1dot3MWe6CentsJacksonMSCfaTEMP',
#  'Utility1dot3MWe6CentsKauaiCfbTEMP',
#  'Utility1dot3MWe6CentsKootenaiCountyIDDsbTEMP',
#  'Utility1dot3MWe6CentsLancasterPADfaTEMP',
#  'Utility1dot3MWe6CentsLaredoTXBShTEMP',
#  'Utility1dot3MWe6CentsLincolnNEDfaTEMP',
#  'Utility1dot3MWe6CentsLittleRockARCfaTEMP',
#  'Utility1dot3MWe6CentsLongviewCsbTEMP',
#  'Utility1dot3MWe6CentsLosAlamosNMDfbTEMP',
#  'Utility1dot3MWe6CentsMarlintonWVCfbTEMP',
#  'Utility1dot3MWe6CentsMedfordORCsaTEMP',
#  'Utility1dot3MWe6CentsMemphisTNCfaTEMP',
#  'Utility1dot3MWe6CentsMiamiAfTEMP',
#  'Utility1dot3MWe6CentsMobileALCfaTEMP',
#  'Utility1dot3MWe6CentsMoscowIDCsbTEMP',
#  'Utility1dot3MWe6CentsNeahBayCfbTEMP',
#  'Utility1dot3MWe6CentsNOLACfaTEMP',
#  'Utility1dot3MWe6CentsOKCityCfaTEMP',
#  'Utility1dot3MWe6CentsORNLCfaTEMP',
#  'Utility1dot3MWe6CentsPhoenixAZBwhTEMP',
#  'Utility1dot3MWe6CentsPrescottAZCsaTEMP',
#  'Utility1dot3MWe6CentsPuebloBskTEMP',
#  'Utility1dot3MWe6CentsRaleighNCCfaTEMP',
#  'Utility1dot3MWe6CentsRapidCitySDBskTEMP',
#  'Utility1dot3MWe6CentsReddingCACsaTEMP',
#  'Utility1dot3MWe6CentsRichmondVACfaTEMP',
#  'Utility1dot3MWe6CentsSacramentoCsaTEMP',
#  'Utility1dot3MWe6CentsSouthBendINDfaTEMP',
#  'Utility1dot3MWe6CentsSyracuseDfbTEMP',
#  'Utility1dot3MWe6CentsTexasOilBShTEMP',
#  'Utility1dot3MWe6CentsUPMichDfbTEMP',
#  'Utility1dot3MWe6CentsVegasNVBwhTEMP',
#  'Utility1dot3MWe6CentsWadenaMNDfaTEMP',
#  'Utility1dot3MWe6CentsYumaAZBwhTEMP']

# %%
#Repack zip file (normal directory -> .zip)
## THIS STEP CURRENTLY BREAKS THE HOMER FILE
## Try using zipcode compression 
files = [f for f in os.listdir(folder) if f.endswith('TEMP')]
display(files)
for i in range(len(files)):
    file = files[i]
    directory = pathlib.Path(file)
    basefile = file.replace('TEMP','')
    basefile = basefile.replace('Utility1dot3MWe6Cents','Utility2dot6MWe6Cents')
    subprocess.run(["powershell.exe", "Compress-Archive -Path " + file + "\* -DestinationPath " + basefile + " -Force"])
    shutil.rmtree(file) #deletes old temp folders
# Out:
# ['Utility1dot3MWe6CentsAnchorageDfcTEMP',
#  'Utility1dot3MWe6CentsAshlandDfbTEMP',
#  'Utility1dot3MWe6CentsAtlantaGACfaTEMP',
#  'Utility1dot3MWe6CentsBangorMEDfbTEMP',
#  'Utility1dot3MWe6CentsBendOreBskTEMP',
#  'Utility1dot3MWe6CentsBentonCountyOregonCsbTEMP',
#  'Utility1dot3MWe6CentsBirminghamALCfaTEMP',
#  'Utility1dot3MWe6CentsBismarckNDDfbTEMP',
#  'Utility1dot3MWe6CentsBlaineCountyMontanaBSkTEMP',
#  'Utility1dot3MWe6CentsBoiseIDBSkTEMP',
#  'Utility1dot3MWe6CentsBrewsterMADfbTEMP',
#  'Utility1dot3MWe6CentsBurlingtonVTDfaTEMP',
#  'Utility1dot3MWe6CentsButtonwillowBwkTEMP',
#  'Utility1dot3MWe6CentsCarsonCityNVBskTEMP',
#  'Utility1dot3MWe6CentsCheyenneWYBskTEMP',
#  'Utility1dot3MWe6CentsChicagoDfaTEMP',
#  'Utility1dot3MWe6CentsCoalvilleUTDfbTEMP',
#  'Utility1dot3MWe6CentsColumbiaMOCfaTEMP',
#  'Utility1dot3MWe6CentsColumbusOHDfaTEMP',
#  'Utility1dot3MWe6CentsCrestedButteCODfcTEMP',
#  'Utility1dot3MWe6CentsDesMoinesIADfaTEMP',
#  'Utility1dot3MWe6CentsDetroitMIDfaTEMP',
#  'Utility1dot3MWe6CentsEielsonAFBDfCTEMP',
#  'Utility1dot3MWe6CentsEvergladesAMTEMP',
#  'Utility1dot3MWe6CentsFlagstaffDsbTEMP',
#  'Utility1dot3MWe6CentsGreatFallsMTBskTEMP',
#  'Utility1dot3MWe6CentsHiloAfTEMP',
#  'Utility1dot3MWe6CentsIdahoFallsDfbTEMP',
#  'Utility1dot3MWe6CentsJacksonMSCfaTEMP',
#  'Utility1dot3MWe6CentsKauaiCfbTEMP',
#  'Utility1dot3MWe6CentsKootenaiCountyIDDsbTEMP',
#  'Utility1dot3MWe6CentsLancasterPADfaTEMP',
#  'Utility1dot3MWe6CentsLaredoTXBShTEMP',
#  'Utility1dot3MWe6CentsLincolnNEDfaTEMP',
#  'Utility1dot3MWe6CentsLittleRockARCfaTEMP',
#  'Utility1dot3MWe6CentsLongviewCsbTEMP',
#  'Utility1dot3MWe6CentsLosAlamosNMDfbTEMP',
#  'Utility1dot3MWe6CentsMarlintonWVCfbTEMP',
#  'Utility1dot3MWe6CentsMedfordORCsaTEMP',
#  'Utility1dot3MWe6CentsMemphisTNCfaTEMP',
#  'Utility1dot3MWe6CentsMiamiAfTEMP',
#  'Utility1dot3MWe6CentsMobileALCfaTEMP',
#  'Utility1dot3MWe6CentsMoscowIDCsbTEMP',
#  'Utility1dot3MWe6CentsNeahBayCfbTEMP',
#  'Utility1dot3MWe6CentsNOLACfaTEMP',
#  'Utility1dot3MWe6CentsOKCityCfaTEMP',
#  'Utility1dot3MWe6CentsORNLCfaTEMP',
#  'Utility1dot3MWe6CentsPhoenixAZBwhTEMP',
#  'Utility1dot3MWe6CentsPrescottAZCsaTEMP',
#  'Utility1dot3MWe6CentsPuebloBskTEMP',
#  'Utility1dot3MWe6CentsRaleighNCCfaTEMP',
#  'Utility1dot3MWe6CentsRapidCitySDBskTEMP',
#  'Utility1dot3MWe6CentsReddingCACsaTEMP',
#  'Utility1dot3MWe6CentsRichmondVACfaTEMP',
#  'Utility1dot3MWe6CentsSacramentoCsaTEMP',
#  'Utility1dot3MWe6CentsSouthBendINDfaTEMP',
#  'Utility1dot3MWe6CentsSyracuseDfbTEMP',
#  'Utility1dot3MWe6CentsTexasOilBShTEMP',
#  'Utility1dot3MWe6CentsUPMichDfbTEMP',
#  'Utility1dot3MWe6CentsVegasNVBwhTEMP',
#  'Utility1dot3MWe6CentsWadenaMNDfaTEMP',
#  'Utility1dot3MWe6CentsYumaAZBwhTEMP']

# %%
# Reseal homer file (.zip -> .homer)
files = [f for f in os.listdir(folder) if f.endswith('.zip')]
n_files = np.size(files)
type(files)
for i in range(len(files)):
    file = files[i]
    base = os.path.splitext(file)[0]
    os.rename(file, base + '.homer')
