# %% [markdown]
# # Zip folder unpacking script
# This script will do the following operations in order:
# Scan a folder
# create new calculation folder
# Loop the following actions for each homer script
#
#
#     Unseal homer template file (.homer -> .zip)
#
#
#     Unpack zip file (.zip -> normal directory)
#
#
#     Open 'problem' file
#
#
#     ####### NOT FOR THIS SCRIPT modify 'problem' file
#
#
#     Repack zip file (normal directory -> .zip)
#
#
#     Reseal homer file (.zip -> .homer)
#         ->[FOR THIS STEP TO FUNCTION PROPERLY, THE JUPYTER NOTEBOOK MUST BE EXECUTED ONE DIRECTORY HIGHER]
#
#
#     store updated input file in calculation folder
#
#
#     end

# %%
# Script initialization, make sure to set working directory
import os
import numpy as np 
import zipfile
import shutil
import zlib
import pathlib 
import subprocess
from lxml import etree, objectify
folder = 'd:/repo/homer/ClimateStudies/ProductionCases/UtilityConnection/2dot6MWe/18cents'

# %%
# Unsealing HOMER template files (.homer -> .zip)
files = [f for f in os.listdir(folder) if f.endswith('.homer')]
n_files = np.size(files)
display(files)
for i in range(len(files)):
    file = files[i]
    base = os.path.splitext(file)[0]
    os.rename(file, base + '.zip')
# Out:
# ['Utility1dot3MWe18CentsAnchorageDfc.homer',
#  'Utility1dot3MWe18CentsAshlandDfb.homer',
#  'Utility1dot3MWe18CentsAtlantaGACfa.homer',
#  'Utility1dot3MWe18CentsBangorMEDfb.homer',
#  'Utility1dot3MWe18CentsBendOreBsk.homer',
#  'Utility1dot3MWe18CentsBentonCountyOregonCsb.homer',
#  'Utility1dot3MWe18CentsBirminghamALCfa.homer',
#  'Utility1dot3MWe18CentsBismarckNDDfb.homer',
#  'Utility1dot3MWe18CentsBlaineCountyMontanaBSk.homer',
#  'Utility1dot3MWe18CentsBoiseIDBSk.homer',
#  'Utility1dot3MWe18CentsBrewsterMADfb.homer',
#  'Utility1dot3MWe18CentsBurlingtonVTDfa.homer',
#  'Utility1dot3MWe18CentsButtonwillowBwk.homer',
#  'Utility1dot3MWe18CentsCarsonCityNVBsk.homer',
#  'Utility1dot3MWe18CentsCheyenneWYBsk.homer',
#  'Utility1dot3MWe18CentsChicagoDfa.homer',
#  'Utility1dot3MWe18CentsCoalvilleUTDfb.homer',
#  'Utility1dot3MWe18CentsColumbiaMOCfa.homer',
#  'Utility1dot3MWe18CentsColumbusOHDfa.homer',
#  'Utility1dot3MWe18CentsCrestedButteCODfc.homer',
#  'Utility1dot3MWe18CentsDesMoinesIADfa.homer',
#  'Utility1dot3MWe18CentsDetroitMIDfa.homer',
#  'Utility1dot3MWe18CentsEielsonAFBDfC.homer',
#  'Utility1dot3MWe18CentsEvergladesAM.homer',
#  'Utility1dot3MWe18CentsFlagstaffDsb.homer',
#  'Utility1dot3MWe18CentsGreatFallsMTBsk.homer',
#  'Utility1dot3MWe18CentsHiloAf.homer',
#  'Utility1dot3MWe18CentsIdahoFallsDfb.homer',
#  'Utility1dot3MWe18CentsJacksonMSCfa.homer',
#  'Utility1dot3MWe18CentsKauaiCfb.homer',
#  'Utility1dot3MWe18CentsKootenaiCountyIDDsb.homer',
#  'Utility1dot3MWe18CentsLancasterPADfa.homer',
#  'Utility1dot3MWe18CentsLaredoTXBSh.homer',
#  'Utility1dot3MWe18CentsLincolnNEDfa.homer',
#  'Utility1dot3MWe18CentsLittleRockARCfa.homer',
#  'Utility1dot3MWe18CentsLongviewCsb.homer',
#  'Utility1dot3MWe18CentsLosAlamosNMDfb.homer',
#  'Utility1dot3MWe18CentsMarlintonWVCfb.homer',
#  'Utility1dot3MWe18CentsMedfordORCsa.homer',
#  'Utility1dot3MWe18CentsMemphisTNCfa.homer',
#  'Utility1dot3MWe18CentsMiamiAf.homer',
#  'Utility1dot3MWe18CentsMobileALCfa.homer',
#  'Utility1dot3MWe18CentsMoscowIDCsb.homer',
#  'Utility1dot3MWe18CentsNeahBayCfb.homer',
#  'Utility1dot3MWe18CentsNOLACfa.homer',
#  'Utility1dot3MWe18CentsOKCityCfa.homer',
#  'Utility1dot3MWe18CentsORNLCfa.homer',
#  'Utility1dot3MWe18CentsPhoenixAZBwh.homer',
#  'Utility1dot3MWe18CentsPrescottAZCsa.homer',
#  'Utility1dot3MWe18CentsPuebloBsk.homer',
#  'Utility1dot3MWe18CentsRaleighNCCfa.homer',
#  'Utility1dot3MWe18CentsRapidCitySDBsk.homer',
#  'Utility1dot3MWe18CentsReddingCACsa.homer',
#  'Utility1dot3MWe18CentsRichmondVACfa.homer',
#  'Utility1dot3MWe18CentsSacramentoCsa.homer',
#  'Utility1dot3MWe18CentsSouthBendINDfa.homer',
#  'Utility1dot3MWe18CentsSyracuseDfb.homer',
#  'Utility1dot3MWe18CentsTexasOilBSh.homer',
#  'Utility1dot3MWe18CentsUPMichDfb.homer',
#  'Utility1dot3MWe18CentsVegasNVBwh.homer',
#  'Utility1dot3MWe18CentsWadenaMNDfa.homer',
#  'Utility1dot3MWe18CentsYumaAZBwh.homer']

# %%
# Unpack zip file (.zip -> normal directory)
files = [f for f in os.listdir(folder) if f.endswith('.zip')]
n_files = np.size(files)
for i in range(len(files)):
    file = files[i]
    base = os.path.splitext(file)[0]
    with zipfile.ZipFile(file, 'r') as zip_ref:
        zip_ref.extractall(base + 'TEMP')
    os.remove(file)
# Opening each individiual 'problem' file after extraction

# %%
# (Within normal directory) Edit the .xml files for each HOMER problem.
files = [f for f in os.listdir(folder) if f.endswith('TEMP')]
display(files)
# paths to change as key, new value as value
new_data = {'/HomerProblem/SimulationParameters/Economics/ProjectLifetimeSensitivity/decimal': '60',
            '/HomerProblem/SimulationParameters/SystemControl/Optimizer/FocusFactor': '2',
            '/HomerProblem/Grid/ConnectionRates/GridConnectionRate/SellbackRateSensitivity/decimal': '0.00',
            '/HomerProblem/Grid/ConnectionRates/GridConnectionRate/GridPowerPriceSensitivity/decimal': '0.18',
            '/HomerProblem/Grid/PurchaseCapacityOptimization/decimal': '2600',
            '/HomerProblem/Grid/SaleCapacitySensitivity/decimal': '0',
            '/HomerProblem/Grid/MaxNetGridPurchasesSensitivity/decimal': '0'}
   
for i in range(len(files)):
    file = files[i]
    problems = etree.parse(file + '/problem')
    #os.remove(file + '/calculated-problem') #deletes old homer savestate
    for path, value in new_data.items():
       # if 'CapacityOptimization' in path:#not necessary currently, but can be used to differentiate values later
       #     problems.xpath(path)[0].text = value
       #     newfile = etree.tostring(problems,encoding='utf-8',method='xml', xml_declaration='<?xml version="1.0" encoding="utf-8"?>')
       #     newfile = str(newfile,'utf-8')#otherwise use utf-8
       # else: 
            #print(path, ' => ', problems.xpath(path)[0].text)
        problems.xpath(path)[0].text = value
        newfile = etree.tostring(problems,encoding='US-ASCII',method='xml', xml_declaration='<?xml version="1.0" encoding="utf-8"?>')
        newfile = str(newfile,'US-ASCII')#otherwise use utf-8
    with open(file + '/problem','w') as f:
    #   # newfile = etree.tostring(new)
         f.write(newfile)
        
        
        
    #display(problem)
       # problem.xpath(j)[0].text = value[j]
# Out:
# ['Utility1dot3MWe18CentsAnchorageDfcTEMP',
#  'Utility1dot3MWe18CentsAshlandDfbTEMP',
#  'Utility1dot3MWe18CentsAtlantaGACfaTEMP',
#  'Utility1dot3MWe18CentsBangorMEDfbTEMP',
#  'Utility1dot3MWe18CentsBendOreBskTEMP',
#  'Utility1dot3MWe18CentsBentonCountyOregonCsbTEMP',
#  'Utility1dot3MWe18CentsBirminghamALCfaTEMP',
#  'Utility1dot3MWe18CentsBismarckNDDfbTEMP',
#  'Utility1dot3MWe18CentsBlaineCountyMontanaBSkTEMP',
#  'Utility1dot3MWe18CentsBoiseIDBSkTEMP',
#  'Utility1dot3MWe18CentsBrewsterMADfbTEMP',
#  'Utility1dot3MWe18CentsBurlingtonVTDfaTEMP',
#  'Utility1dot3MWe18CentsButtonwillowBwkTEMP',
#  'Utility1dot3MWe18CentsCarsonCityNVBskTEMP',
#  'Utility1dot3MWe18CentsCheyenneWYBskTEMP',
#  'Utility1dot3MWe18CentsChicagoDfaTEMP',
#  'Utility1dot3MWe18CentsCoalvilleUTDfbTEMP',
#  'Utility1dot3MWe18CentsColumbiaMOCfaTEMP',
#  'Utility1dot3MWe18CentsColumbusOHDfaTEMP',
#  'Utility1dot3MWe18CentsCrestedButteCODfcTEMP',
#  'Utility1dot3MWe18CentsDesMoinesIADfaTEMP',
#  'Utility1dot3MWe18CentsDetroitMIDfaTEMP',
#  'Utility1dot3MWe18CentsEielsonAFBDfCTEMP',
#  'Utility1dot3MWe18CentsEvergladesAMTEMP',
#  'Utility1dot3MWe18CentsFlagstaffDsbTEMP',
#  'Utility1dot3MWe18CentsGreatFallsMTBskTEMP',
#  'Utility1dot3MWe18CentsHiloAfTEMP',
#  'Utility1dot3MWe18CentsIdahoFallsDfbTEMP',
#  'Utility1dot3MWe18CentsJacksonMSCfaTEMP',
#  'Utility1dot3MWe18CentsKauaiCfbTEMP',
#  'Utility1dot3MWe18CentsKootenaiCountyIDDsbTEMP',
#  'Utility1dot3MWe18CentsLancasterPADfaTEMP',
#  'Utility1dot3MWe18CentsLaredoTXBShTEMP',
#  'Utility1dot3MWe18CentsLincolnNEDfaTEMP',
#  'Utility1dot3MWe18CentsLittleRockARCfaTEMP',
#  'Utility1dot3MWe18CentsLongviewCsbTEMP',
#  'Utility1dot3MWe18CentsLosAlamosNMDfbTEMP',
#  'Utility1dot3MWe18CentsMarlintonWVCfbTEMP',
#  'Utility1dot3MWe18CentsMedfordORCsaTEMP',
#  'Utility1dot3MWe18CentsMemphisTNCfaTEMP',
#  'Utility1dot3MWe18CentsMiamiAfTEMP',
#  'Utility1dot3MWe18CentsMobileALCfaTEMP',
#  'Utility1dot3MWe18CentsMoscowIDCsbTEMP',
#  'Utility1dot3MWe18CentsNeahBayCfbTEMP',
#  'Utility1dot3MWe18CentsNOLACfaTEMP',
#  'Utility1dot3MWe18CentsOKCityCfaTEMP',
#  'Utility1dot3MWe18CentsORNLCfaTEMP',
#  'Utility1dot3MWe18CentsPhoenixAZBwhTEMP',
#  'Utility1dot3MWe18CentsPrescottAZCsaTEMP',
#  'Utility1dot3MWe18CentsPuebloBskTEMP',
#  'Utility1dot3MWe18CentsRaleighNCCfaTEMP',
#  'Utility1dot3MWe18CentsRapidCitySDBskTEMP',
#  'Utility1dot3MWe18CentsReddingCACsaTEMP',
#  'Utility1dot3MWe18CentsRichmondVACfaTEMP',
#  'Utility1dot3MWe18CentsSacramentoCsaTEMP',
#  'Utility1dot3MWe18CentsSouthBendINDfaTEMP',
#  'Utility1dot3MWe18CentsSyracuseDfbTEMP',
#  'Utility1dot3MWe18CentsTexasOilBShTEMP',
#  'Utility1dot3MWe18CentsUPMichDfbTEMP',
#  'Utility1dot3MWe18CentsVegasNVBwhTEMP',
#  'Utility1dot3MWe18CentsWadenaMNDfaTEMP',
#  'Utility1dot3MWe18CentsYumaAZBwhTEMP']

# %%
#Repack zip file (normal directory -> .zip)
## THIS STEP CURRENTLY BREAKS THE HOMER FILE
## Try using zipcode compression 
files = [f for f in os.listdir(folder) if f.endswith('TEMP')]
display(files)
for i in range(len(files)):
    file = files[i]
    directory = pathlib.Path(file)
    basefile = file.replace('TEMP','')
    basefile = basefile.replace('Utility1dot3MWe18Cents','Utility2dot6MWe18Cents')
    subprocess.run(["powershell.exe", "Compress-Archive -Path " + file + "\* -DestinationPath " + basefile + " -Force"])
    shutil.rmtree(file) #deletes old temp folders
# Out:
# ['Utility1dot3MWe18CentsAnchorageDfcTEMP',
#  'Utility1dot3MWe18CentsAshlandDfbTEMP',
#  'Utility1dot3MWe18CentsAtlantaGACfaTEMP',
#  'Utility1dot3MWe18CentsBangorMEDfbTEMP',
#  'Utility1dot3MWe18CentsBendOreBskTEMP',
#  'Utility1dot3MWe18CentsBentonCountyOregonCsbTEMP',
#  'Utility1dot3MWe18CentsBirminghamALCfaTEMP',
#  'Utility1dot3MWe18CentsBismarckNDDfbTEMP',
#  'Utility1dot3MWe18CentsBlaineCountyMontanaBSkTEMP',
#  'Utility1dot3MWe18CentsBoiseIDBSkTEMP',
#  'Utility1dot3MWe18CentsBrewsterMADfbTEMP',
#  'Utility1dot3MWe18CentsBurlingtonVTDfaTEMP',
#  'Utility1dot3MWe18CentsButtonwillowBwkTEMP',
#  'Utility1dot3MWe18CentsCarsonCityNVBskTEMP',
#  'Utility1dot3MWe18CentsCheyenneWYBskTEMP',
#  'Utility1dot3MWe18CentsChicagoDfaTEMP',
#  'Utility1dot3MWe18CentsCoalvilleUTDfbTEMP',
#  'Utility1dot3MWe18CentsColumbiaMOCfaTEMP',
#  'Utility1dot3MWe18CentsColumbusOHDfaTEMP',
#  'Utility1dot3MWe18CentsCrestedButteCODfcTEMP',
#  'Utility1dot3MWe18CentsDesMoinesIADfaTEMP',
#  'Utility1dot3MWe18CentsDetroitMIDfaTEMP',
#  'Utility1dot3MWe18CentsEielsonAFBDfCTEMP',
#  'Utility1dot3MWe18CentsEvergladesAMTEMP',
#  'Utility1dot3MWe18CentsFlagstaffDsbTEMP',
#  'Utility1dot3MWe18CentsGreatFallsMTBskTEMP',
#  'Utility1dot3MWe18CentsHiloAfTEMP',
#  'Utility1dot3MWe18CentsIdahoFallsDfbTEMP',
#  'Utility1dot3MWe18CentsJacksonMSCfaTEMP',
#  'Utility1dot3MWe18CentsKauaiCfbTEMP',
#  'Utility1dot3MWe18CentsKootenaiCountyIDDsbTEMP',
#  'Utility1dot3MWe18CentsLancasterPADfaTEMP',
#  'Utility1dot3MWe18CentsLaredoTXBShTEMP',
#  'Utility1dot3MWe18CentsLincolnNEDfaTEMP',
#  'Utility1dot3MWe18CentsLittleRockARCfaTEMP',
#  'Utility1dot3MWe18CentsLongviewCsbTEMP',
#  'Utility1dot3MWe18CentsLosAlamosNMDfbTEMP',
#  'Utility1dot3MWe18CentsMarlintonWVCfbTEMP',
#  'Utility1dot3MWe18CentsMedfordORCsaTEMP',
#  'Utility1dot3MWe18CentsMemphisTNCfaTEMP',
#  'Utility1dot3MWe18CentsMiamiAfTEMP',
#  'Utility1dot3MWe18CentsMobileALCfaTEMP',
#  'Utility1dot3MWe18CentsMoscowIDCsbTEMP',
#  'Utility1dot3MWe18CentsNeahBayCfbTEMP',
#  'Utility1dot3MWe18CentsNOLACfaTEMP',
#  'Utility1dot3MWe18CentsOKCityCfaTEMP',
#  'Utility1dot3MWe18CentsORNLCfaTEMP',
#  'Utility1dot3MWe18CentsPhoenixAZBwhTEMP',
#  'Utility1dot3MWe18CentsPrescottAZCsaTEMP',
#  'Utility1dot3MWe18CentsPuebloBskTEMP',
#  'Utility1dot3MWe18CentsRaleighNCCfaTEMP',
#  'Utility1dot3MWe18CentsRapidCitySDBskTEMP',
#  'Utility1dot3MWe18CentsReddingCACsaTEMP',
#  'Utility1dot3MWe18CentsRichmondVACfaTEMP',
#  'Utility1dot3MWe18CentsSacramentoCsaTEMP',
#  'Utility1dot3MWe18CentsSouthBendINDfaTEMP',
#  'Utility1dot3MWe18CentsSyracuseDfbTEMP',
#  'Utility1dot3MWe18CentsTexasOilBShTEMP',
#  'Utility1dot3MWe18CentsUPMichDfbTEMP',
#  'Utility1dot3MWe18CentsVegasNVBwhTEMP',
#  'Utility1dot3MWe18CentsWadenaMNDfaTEMP',
#  'Utility1dot3MWe18CentsYumaAZBwhTEMP']

# %%
# Reseal homer file (.zip -> .homer)
files = [f for f in os.listdir(folder) if f.endswith('.zip')]
n_files = np.size(files)
type(files)
for i in range(len(files)):
    file = files[i]
    base = os.path.splitext(file)[0]
    os.rename(file, base + '.homer')
