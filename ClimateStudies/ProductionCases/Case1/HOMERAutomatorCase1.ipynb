# %% [markdown]
# # Zip folder unpacking script
# This script will do the following operations in order:
# Scan a folder
# create new calculation folder
# Loop the following actions for each homer script
#
#
#     Unseal homer template file (.homer -> .zip)
#
#
#     Unpack zip file (.zip -> normal directory)
#
#
#     Open 'problem' file
#
#
#     ####### NOT FOR THIS SCRIPT modify 'problem' file
#
#
#     Repack zip file (normal directory -> .zip)
#
#
#     Reseal homer file (.zip -> .homer)
#         ->[FOR THIS STEP TO FUNCTION PROPERLY, THE JUPYTER NOTEBOOK MUST BE EXECUTED ONE DIRECTORY HIGHER]
#
#
#     store updated input file in calculation folder
#
#
#     end

# %%
# Script initialization, make sure to set working directory
import os
import numpy as np 
import zipfile
import shutil
import zlib
import pathlib 
import subprocess
from lxml import etree, objectify
folder = 'd:/repo/homer/ClimateStudies/ProductionCases/Case1'

# %%
# Unsealing HOMER template files (.homer -> .zip)
files = [f for f in os.listdir(folder) if f.endswith('.homer')]
n_files = np.size(files)
display(files)
for i in range(len(files)):
    file = files[i]
    base = os.path.splitext(file)[0]
    os.rename(file, base + '.zip')
# Out:
# ['Case1AnchorageDfc.homer',
#  'Case1AshlandDfb.homer',
#  'Case1AtlantaGACfa.homer',
#  'Case1AZYumaBwh.homer',
#  'Case1BangorMEDfb.homer',
#  'Case1BendOreBsk.homer',
#  'Case1BentonCountyOregonCsb.homer',
#  'Case1BirminghamALCfa.homer',
#  'Case1BismarckNDDfb.homer',
#  'Case1BlaineCountyMontanaBSk.homer',
#  'Case1BoiseIDBSk.homer',
#  'Case1BrewsterMADfb.homer',
#  'Case1BurlingtonVTDfa.homer',
#  'Case1ButtonwillowBwk.homer',
#  'Case1CarsonCityNVBsk.homer',
#  'Case1CheyenneWYBsk.homer',
#  'Case1ChicagoDfa.homer',
#  'Case1CoalvilleUTDfb.homer',
#  'Case1ColumbiaMOCfa.homer',
#  'Case1ColumbusOHDfa.homer',
#  'Case1CrestedButteCODfc.homer',
#  'Case1DesMoinesIADfa.homer',
#  'Case1DetroitMIDfa.homer',
#  'Case1EielsonAFBDfC.homer',
#  'Case1EvergladesAM.homer',
#  'Case1FlagstaffDsb.homer',
#  'Case1GreatFallsMTBsk.homer',
#  'Case1HiloAf.homer',
#  'Case1IdahoFallsDfb.homer',
#  'Case1JacksonMSCfa.homer',
#  'Case1KauaiCfb.homer',
#  'Case1KootenaiCountyIDDsb.homer',
#  'Case1LancasterPADfa.homer',
#  'Case1LaredoTXBSh.homer',
#  'Case1LincolnNEDfa.homer',
#  'Case1LittleRockARCfa.homer',
#  'Case1LongviewCsb.homer',
#  'Case1LosAlamosNMDfb.homer',
#  'Case1MarlintonWVCfb.homer',
#  'Case1MedfordORCsa.homer',
#  'Case1MemphisTNCfa.homer',
#  'Case1MiamiAf.homer',
#  'Case1MobileALCfa.homer',
#  'Case1MoscowIDCsb.homer',
#  'Case1NeahBayCfb.homer',
#  'Case1NOLACfa.homer',
#  'Case1OKCityCfa.homer',
#  'Case1ORNLCfa.homer',
#  'Case1PhoenixAZBwh.homer',
#  'Case1PrescottAZCsa.homer',
#  'Case1PuebloBsk.homer',
#  'Case1RaleighNCCfa.homer',
#  'Case1RapidCitySDBsk.homer',
#  'Case1ReddingCACsa.homer',
#  'Case1RichmondVACfa.homer',
#  'Case1SacramentoCsa.homer',
#  'Case1SouthBendINDfa.homer',
#  'Case1SyracuseDfb.homer',
#  'Case1TexasOilBSh.homer',
#  'Case1UPMichDfb.homer',
#  'Case1VegasNVBwh.homer',
#  'Case1WadenaMNDfa.homer']

# %%
# Unpack zip file (.zip -> normal directory)
files = [f for f in os.listdir(folder) if f.endswith('.zip')]
n_files = np.size(files)
for i in range(len(files)):
    file = files[i]
    base = os.path.splitext(file)[0]
    with zipfile.ZipFile(file, 'r') as zip_ref:
        zip_ref.extractall(base + 'TEMP')
    os.remove(file)
# Opening each individiual 'problem' file after extraction

# %%
# (Within normal directory) Edit the .xml files for each HOMER problem.
files = [f for f in os.listdir(folder) if f.endswith('TEMP')]
display(files)
# paths to change as key, new value as value
new_data = {'/HomerProblem/FuelResources/Fuel/Name': 'CCM FUEL',
            '/HomerProblem/FuelResources/Fuel/FuelCostSensitivity/decimal': '0.00',
            '/HomerProblem/SimulationParameters/Economics/ProjectLifetimeSensitivity/decimal': '60',
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/Quantity': '1000' ,
            '/HomerProblem/SimulationParameters/SystemControl/Optimizer/FocusFactor': '10'}
   
for i in range(len(files)):
    file = files[i]
    problems = etree.parse(file + '/problem')
    #os.remove(file + '/calculated-problem') #deletes old homer savestate
    for path, value in new_data.items():
       # if 'CapacityOptimization' in path:#not necessary currently, but can be used to differentiate values later
       #     problems.xpath(path)[0].text = value
       #     newfile = etree.tostring(problems,encoding='utf-8',method='xml', xml_declaration='<?xml version="1.0" encoding="utf-8"?>')
       #     newfile = str(newfile,'utf-8')#otherwise use utf-8
       # else: 
            #print(path, ' => ', problems.xpath(path)[0].text)
        problems.xpath(path)[0].text = value
        newfile = etree.tostring(problems,encoding='US-ASCII',method='xml', xml_declaration='<?xml version="1.0" encoding="utf-8"?>')
        newfile = str(newfile,'US-ASCII')#otherwise use utf-8
    with open(file + '/problem','w') as f:
    #   # newfile = etree.tostring(new)
         f.write(newfile)
        
        
        
    #display(problem)
       # problem.xpath(j)[0].text = value[j]
# Out:
# ['Case1AnchorageDfcTEMP',
#  'Case1AshlandDfbTEMP',
#  'Case1AtlantaGACfaTEMP',
#  'Case1AZYumaBwhTEMP',
#  'Case1BangorMEDfbTEMP',
#  'Case1BendOreBskTEMP',
#  'Case1BentonCountyOregonCsbTEMP',
#  'Case1BirminghamALCfaTEMP',
#  'Case1BismarckNDDfbTEMP',
#  'Case1BlaineCountyMontanaBSkTEMP',
#  'Case1BoiseIDBSkTEMP',
#  'Case1BrewsterMADfbTEMP',
#  'Case1BurlingtonVTDfaTEMP',
#  'Case1ButtonwillowBwkTEMP',
#  'Case1CarsonCityNVBskTEMP',
#  'Case1CheyenneWYBskTEMP',
#  'Case1ChicagoDfaTEMP',
#  'Case1CoalvilleUTDfbTEMP',
#  'Case1ColumbiaMOCfaTEMP',
#  'Case1ColumbusOHDfaTEMP',
#  'Case1CrestedButteCODfcTEMP',
#  'Case1DesMoinesIADfaTEMP',
#  'Case1DetroitMIDfaTEMP',
#  'Case1EielsonAFBDfCTEMP',
#  'Case1EvergladesAMTEMP',
#  'Case1FlagstaffDsbTEMP',
#  'Case1GreatFallsMTBskTEMP',
#  'Case1HiloAfTEMP',
#  'Case1IdahoFallsDfbTEMP',
#  'Case1JacksonMSCfaTEMP',
#  'Case1KauaiCfbTEMP',
#  'Case1KootenaiCountyIDDsbTEMP',
#  'Case1LancasterPADfaTEMP',
#  'Case1LaredoTXBShTEMP',
#  'Case1LincolnNEDfaTEMP',
#  'Case1LittleRockARCfaTEMP',
#  'Case1LongviewCsbTEMP',
#  'Case1LosAlamosNMDfbTEMP',
#  'Case1MarlintonWVCfbTEMP',
#  'Case1MedfordORCsaTEMP',
#  'Case1MemphisTNCfaTEMP',
#  'Case1MiamiAfTEMP',
#  'Case1MobileALCfaTEMP',
#  'Case1MoscowIDCsbTEMP',
#  'Case1NeahBayCfbTEMP',
#  'Case1NOLACfaTEMP',
#  'Case1OKCityCfaTEMP',
#  'Case1ORNLCfaTEMP',
#  'Case1PhoenixAZBwhTEMP',
#  'Case1PrescottAZCsaTEMP',
#  'Case1PuebloBskTEMP',
#  'Case1RaleighNCCfaTEMP',
#  'Case1RapidCitySDBskTEMP',
#  'Case1ReddingCACsaTEMP',
#  'Case1RichmondVACfaTEMP',
#  'Case1SacramentoCsaTEMP',
#  'Case1SouthBendINDfaTEMP',
#  'Case1SyracuseDfbTEMP',
#  'Case1TexasOilBShTEMP',
#  'Case1UPMichDfbTEMP',
#  'Case1VegasNVBwhTEMP',
#  'Case1WadenaMNDfaTEMP']

# %%
#Repack zip file (normal directory -> .zip)
## THIS STEP CURRENTLY BREAKS THE HOMER FILE
## Try using zipcode compression 
files = [f for f in os.listdir(folder) if f.endswith('TEMP')]
display(files)
for i in range(len(files)):
    file = files[i]
    directory = pathlib.Path(file)
    basefile = file.replace('TEMP','')
    subprocess.run(["powershell.exe", "Compress-Archive -Path " + file + "\* -DestinationPath " + basefile + " -Force"])
    shutil.rmtree(file) #deletes old temp folders
# Out:
# ['Case1AnchorageDfcTEMP',
#  'Case1AshlandDfbTEMP',
#  'Case1AtlantaGACfaTEMP',
#  'Case1AZYumaBwhTEMP',
#  'Case1BangorMEDfbTEMP',
#  'Case1BendOreBskTEMP',
#  'Case1BentonCountyOregonCsbTEMP',
#  'Case1BirminghamALCfaTEMP',
#  'Case1BismarckNDDfbTEMP',
#  'Case1BlaineCountyMontanaBSkTEMP',
#  'Case1BoiseIDBSkTEMP',
#  'Case1BrewsterMADfbTEMP',
#  'Case1BurlingtonVTDfaTEMP',
#  'Case1ButtonwillowBwkTEMP',
#  'Case1CarsonCityNVBskTEMP',
#  'Case1CheyenneWYBskTEMP',
#  'Case1ChicagoDfaTEMP',
#  'Case1CoalvilleUTDfbTEMP',
#  'Case1ColumbiaMOCfaTEMP',
#  'Case1ColumbusOHDfaTEMP',
#  'Case1CrestedButteCODfcTEMP',
#  'Case1DesMoinesIADfaTEMP',
#  'Case1DetroitMIDfaTEMP',
#  'Case1EielsonAFBDfCTEMP',
#  'Case1EvergladesAMTEMP',
#  'Case1FlagstaffDsbTEMP',
#  'Case1GreatFallsMTBskTEMP',
#  'Case1HiloAfTEMP',
#  'Case1IdahoFallsDfbTEMP',
#  'Case1JacksonMSCfaTEMP',
#  'Case1KauaiCfbTEMP',
#  'Case1KootenaiCountyIDDsbTEMP',
#  'Case1LancasterPADfaTEMP',
#  'Case1LaredoTXBShTEMP',
#  'Case1LincolnNEDfaTEMP',
#  'Case1LittleRockARCfaTEMP',
#  'Case1LongviewCsbTEMP',
#  'Case1LosAlamosNMDfbTEMP',
#  'Case1MarlintonWVCfbTEMP',
#  'Case1MedfordORCsaTEMP',
#  'Case1MemphisTNCfaTEMP',
#  'Case1MiamiAfTEMP',
#  'Case1MobileALCfaTEMP',
#  'Case1MoscowIDCsbTEMP',
#  'Case1NeahBayCfbTEMP',
#  'Case1NOLACfaTEMP',
#  'Case1OKCityCfaTEMP',
#  'Case1ORNLCfaTEMP',
#  'Case1PhoenixAZBwhTEMP',
#  'Case1PrescottAZCsaTEMP',
#  'Case1PuebloBskTEMP',
#  'Case1RaleighNCCfaTEMP',
#  'Case1RapidCitySDBskTEMP',
#  'Case1ReddingCACsaTEMP',
#  'Case1RichmondVACfaTEMP',
#  'Case1SacramentoCsaTEMP',
#  'Case1SouthBendINDfaTEMP',
#  'Case1SyracuseDfbTEMP',
#  'Case1TexasOilBShTEMP',
#  'Case1UPMichDfbTEMP',
#  'Case1VegasNVBwhTEMP',
#  'Case1WadenaMNDfaTEMP']

# %%
# Reseal homer file (.zip -> .homer)
files = [f for f in os.listdir(folder) if f.endswith('.zip')]
n_files = np.size(files)
type(files)
for i in range(len(files)):
    file = files[i]
    base = os.path.splitext(file)[0]
    os.rename(file, base + '.homer')
