# %% [markdown]
# # Zip folder unpacking script
# This script will do the following operations in order:
# Scan a folder
# create new calculation folder
# Loop the following actions for each homer script
#
#
#     Unseal homer template file (.homer -> .zip)
#
#
#     Unpack zip file (.zip -> normal directory)
#
#
#     Open 'problem' file
#
#
#     ####### NOT FOR THIS SCRIPT modify 'problem' file
#
#
#     Repack zip file (normal directory -> .zip)
#
#
#     Reseal homer file (.zip -> .homer)
#         ->[FOR THIS STEP TO FUNCTION PROPERLY, THE JUPYTER NOTEBOOK MUST BE EXECUTED ONE DIRECTORY HIGHER]
#
#
#     store updated input file in calculation folder
#
#
#     end

# %%
# Script initialization, make sure to set working directory
import os
import numpy as np 
import zipfile
import shutil
import zlib
import pathlib 
import subprocess
from lxml import etree, objectify
folder = 'd:/repo/homer/ClimateStudies/ProductionCases/Case5'

# %%
# Unsealing HOMER template files (.homer -> .zip)
files = [f for f in os.listdir(folder) if f.endswith('.homer')]
n_files = np.size(files)
display(files)
for i in range(len(files)):
    file = files[i]
    base = os.path.splitext(file)[0]
    os.rename(file, base + '.zip')
# Out:
# ['Case4AnchorageDfc.homer',
#  'Case4AshlandDfb.homer',
#  'Case4AtlantaGACfa.homer',
#  'Case4AZYumaBwh.homer',
#  'Case4BangorMEDfb.homer',
#  'Case4BendOreBsk.homer',
#  'Case4BentonCountyOregonCsb.homer',
#  'Case4BirminghamALCfa.homer',
#  'Case4BismarckNDDfb.homer',
#  'Case4BlaineCountyMontanaBSk.homer',
#  'Case4BoiseIDBSk.homer',
#  'Case4BrewsterMADfb.homer',
#  'Case4BurlingtonVTDfa.homer',
#  'Case4ButtonwillowBwk.homer',
#  'Case4CarsonCityNVBsk.homer',
#  'Case4CheyenneWYBsk.homer',
#  'Case4ChicagoDfa.homer',
#  'Case4CoalvilleUTDfb.homer',
#  'Case4ColumbiaMOCfa.homer',
#  'Case4ColumbusOHDfa.homer',
#  'Case4CrestedButteCODfc.homer',
#  'Case4DesMoinesIADfa.homer',
#  'Case4DetroitMIDfa.homer',
#  'Case4EielsonAFBDfC.homer',
#  'Case4EvergladesAM.homer',
#  'Case4FlagstaffDsb.homer',
#  'Case4GreatFallsMTBsk.homer',
#  'Case4HiloAf.homer',
#  'Case4IdahoFallsDfb.homer',
#  'Case4JacksonMSCfa.homer',
#  'Case4KauaiCfb.homer',
#  'Case4KootenaiCountyIDDsb.homer',
#  'Case4LancasterPADfa.homer',
#  'Case4LaredoTXBSh.homer',
#  'Case4LincolnNEDfa.homer',
#  'Case4LittleRockARCfa.homer',
#  'Case4LongviewCsb.homer',
#  'Case4LosAlamosNMDfb.homer',
#  'Case4MarlintonWVCfb.homer',
#  'Case4MedfordORCsa.homer',
#  'Case4MemphisTNCfa.homer',
#  'Case4MiamiAf.homer',
#  'Case4MobileALCfa.homer',
#  'Case4MoscowIDCsb.homer',
#  'Case4NeahBayCfb.homer',
#  'Case4NOLACfa.homer',
#  'Case4OKCityCfa.homer',
#  'Case4ORNLCfa.homer',
#  'Case4PhoenixAZBwh.homer',
#  'Case4PrescottAZCsa.homer',
#  'Case4PuebloBsk.homer',
#  'Case4RaleighNCCfa.homer',
#  'Case4RapidCitySDBsk.homer',
#  'Case4ReddingCACsa.homer',
#  'Case4RichmondVACfa.homer',
#  'Case4SacramentoCsa.homer',
#  'Case4SouthBendINDfa.homer',
#  'Case4SyracuseDfb.homer',
#  'Case4TexasOilBSh.homer',
#  'Case4UPMichDfb.homer',
#  'Case4VegasNVBwh.homer',
#  'Case4WadenaMNDfa.homer']

# %%
# Unpack zip file (.zip -> normal directory)
files = [f for f in os.listdir(folder) if f.endswith('.zip')]
n_files = np.size(files)
for i in range(len(files)):
    file = files[i]
    base = os.path.splitext(file)[0]
    with zipfile.ZipFile(file, 'r') as zip_ref:
        zip_ref.extractall(base + 'TEMP')
    os.remove(file)
# Opening each individiual 'problem' file after extraction

# %%
# (Within normal directory) Edit the .xml files for each HOMER problem.
files = [f for f in os.listdir(folder) if f.endswith('TEMP')]
display(files)
# paths to change as key, new value as value
new_data = {'/HomerProblem/FuelResources/Fuel/Name': 'CCM FUEL',
            '/HomerProblem/FuelResources/Fuel/FuelCostSensitivity/decimal': '0.00',
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/Initial': '30000000',
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/Quantity': '1000' ,
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/CapitalCostDetail/CostCalculatorItem/UnitCost': '30000' ,
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/Replacement': '3550000',
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/ReplacementCostDetail/CostCalculatorItem/Quantity': '1000' ,
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/ReplacementCostDetail/CostCalculatorItem/UnitCost': '3550000' ,
            '/HomerProblem/Generators/Generator/LifetimeSensitivity/decimal': '43830' ,
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/Operating': '58.33',
            '/HomerProblem/SimulationParameters/Economics/ProjectLifetimeSensitivity/decimal': '60',
            '/HomerProblem/SimulationParameters/SystemControl/Optimizer/FocusFactor': '2'}
   
for i in range(len(files)):
    file = files[i]
    problems = etree.parse(file + '/problem')
    #os.remove(file + '/calculated-problem') #deletes old homer savestate
    for path, value in new_data.items():
       # if 'CapacityOptimization' in path:#not necessary currently, but can be used to differentiate values later
       #     problems.xpath(path)[0].text = value
       #     newfile = etree.tostring(problems,encoding='utf-8',method='xml', xml_declaration='<?xml version="1.0" encoding="utf-8"?>')
       #     newfile = str(newfile,'utf-8')#otherwise use utf-8
       # else: 
            #print(path, ' => ', problems.xpath(path)[0].text)
        problems.xpath(path)[0].text = value
        newfile = etree.tostring(problems,encoding='US-ASCII',method='xml', xml_declaration='<?xml version="1.0" encoding="utf-8"?>')
        newfile = str(newfile,'US-ASCII')#otherwise use utf-8
    with open(file + '/problem','w') as f:
    #   # newfile = etree.tostring(new)
         f.write(newfile)
        
        
        
    #display(problem)
       # problem.xpath(j)[0].text = value[j]
# Out:
# ['Case4AnchorageDfcTEMP',
#  'Case4AshlandDfbTEMP',
#  'Case4AtlantaGACfaTEMP',
#  'Case4AZYumaBwhTEMP',
#  'Case4BangorMEDfbTEMP',
#  'Case4BendOreBskTEMP',
#  'Case4BentonCountyOregonCsbTEMP',
#  'Case4BirminghamALCfaTEMP',
#  'Case4BismarckNDDfbTEMP',
#  'Case4BlaineCountyMontanaBSkTEMP',
#  'Case4BoiseIDBSkTEMP',
#  'Case4BrewsterMADfbTEMP',
#  'Case4BurlingtonVTDfaTEMP',
#  'Case4ButtonwillowBwkTEMP',
#  'Case4CarsonCityNVBskTEMP',
#  'Case4CheyenneWYBskTEMP',
#  'Case4ChicagoDfaTEMP',
#  'Case4CoalvilleUTDfbTEMP',
#  'Case4ColumbiaMOCfaTEMP',
#  'Case4ColumbusOHDfaTEMP',
#  'Case4CrestedButteCODfcTEMP',
#  'Case4DesMoinesIADfaTEMP',
#  'Case4DetroitMIDfaTEMP',
#  'Case4EielsonAFBDfCTEMP',
#  'Case4EvergladesAMTEMP',
#  'Case4FlagstaffDsbTEMP',
#  'Case4GreatFallsMTBskTEMP',
#  'Case4HiloAfTEMP',
#  'Case4IdahoFallsDfbTEMP',
#  'Case4JacksonMSCfaTEMP',
#  'Case4KauaiCfbTEMP',
#  'Case4KootenaiCountyIDDsbTEMP',
#  'Case4LancasterPADfaTEMP',
#  'Case4LaredoTXBShTEMP',
#  'Case4LincolnNEDfaTEMP',
#  'Case4LittleRockARCfaTEMP',
#  'Case4LongviewCsbTEMP',
#  'Case4LosAlamosNMDfbTEMP',
#  'Case4MarlintonWVCfbTEMP',
#  'Case4MedfordORCsaTEMP',
#  'Case4MemphisTNCfaTEMP',
#  'Case4MiamiAfTEMP',
#  'Case4MobileALCfaTEMP',
#  'Case4MoscowIDCsbTEMP',
#  'Case4NeahBayCfbTEMP',
#  'Case4NOLACfaTEMP',
#  'Case4OKCityCfaTEMP',
#  'Case4ORNLCfaTEMP',
#  'Case4PhoenixAZBwhTEMP',
#  'Case4PrescottAZCsaTEMP',
#  'Case4PuebloBskTEMP',
#  'Case4RaleighNCCfaTEMP',
#  'Case4RapidCitySDBskTEMP',
#  'Case4ReddingCACsaTEMP',
#  'Case4RichmondVACfaTEMP',
#  'Case4SacramentoCsaTEMP',
#  'Case4SouthBendINDfaTEMP',
#  'Case4SyracuseDfbTEMP',
#  'Case4TexasOilBShTEMP',
#  'Case4UPMichDfbTEMP',
#  'Case4VegasNVBwhTEMP',
#  'Case4WadenaMNDfaTEMP']

# %%
#Repack zip file (normal directory -> .zip)
## THIS STEP CURRENTLY BREAKS THE HOMER FILE
## Try using zipcode compression 
files = [f for f in os.listdir(folder) if f.endswith('TEMP')]
display(files)
for i in range(len(files)):
    file = files[i]
    directory = pathlib.Path(file)
    basefile = file.replace('TEMP','')
    basefile = basefile.replace('Case4','Case5')
    subprocess.run(["powershell.exe", "Compress-Archive -Path " + file + "\* -DestinationPath " + basefile + " -Force"])
    shutil.rmtree(file) #deletes old temp folders
# Out:
# ['Case4AnchorageDfcTEMP',
#  'Case4AshlandDfbTEMP',
#  'Case4AtlantaGACfaTEMP',
#  'Case4AZYumaBwhTEMP',
#  'Case4BangorMEDfbTEMP',
#  'Case4BendOreBskTEMP',
#  'Case4BentonCountyOregonCsbTEMP',
#  'Case4BirminghamALCfaTEMP',
#  'Case4BismarckNDDfbTEMP',
#  'Case4BlaineCountyMontanaBSkTEMP',
#  'Case4BoiseIDBSkTEMP',
#  'Case4BrewsterMADfbTEMP',
#  'Case4BurlingtonVTDfaTEMP',
#  'Case4ButtonwillowBwkTEMP',
#  'Case4CarsonCityNVBskTEMP',
#  'Case4CheyenneWYBskTEMP',
#  'Case4ChicagoDfaTEMP',
#  'Case4CoalvilleUTDfbTEMP',
#  'Case4ColumbiaMOCfaTEMP',
#  'Case4ColumbusOHDfaTEMP',
#  'Case4CrestedButteCODfcTEMP',
#  'Case4DesMoinesIADfaTEMP',
#  'Case4DetroitMIDfaTEMP',
#  'Case4EielsonAFBDfCTEMP',
#  'Case4EvergladesAMTEMP',
#  'Case4FlagstaffDsbTEMP',
#  'Case4GreatFallsMTBskTEMP',
#  'Case4HiloAfTEMP',
#  'Case4IdahoFallsDfbTEMP',
#  'Case4JacksonMSCfaTEMP',
#  'Case4KauaiCfbTEMP',
#  'Case4KootenaiCountyIDDsbTEMP',
#  'Case4LancasterPADfaTEMP',
#  'Case4LaredoTXBShTEMP',
#  'Case4LincolnNEDfaTEMP',
#  'Case4LittleRockARCfaTEMP',
#  'Case4LongviewCsbTEMP',
#  'Case4LosAlamosNMDfbTEMP',
#  'Case4MarlintonWVCfbTEMP',
#  'Case4MedfordORCsaTEMP',
#  'Case4MemphisTNCfaTEMP',
#  'Case4MiamiAfTEMP',
#  'Case4MobileALCfaTEMP',
#  'Case4MoscowIDCsbTEMP',
#  'Case4NeahBayCfbTEMP',
#  'Case4NOLACfaTEMP',
#  'Case4OKCityCfaTEMP',
#  'Case4ORNLCfaTEMP',
#  'Case4PhoenixAZBwhTEMP',
#  'Case4PrescottAZCsaTEMP',
#  'Case4PuebloBskTEMP',
#  'Case4RaleighNCCfaTEMP',
#  'Case4RapidCitySDBskTEMP',
#  'Case4ReddingCACsaTEMP',
#  'Case4RichmondVACfaTEMP',
#  'Case4SacramentoCsaTEMP',
#  'Case4SouthBendINDfaTEMP',
#  'Case4SyracuseDfbTEMP',
#  'Case4TexasOilBShTEMP',
#  'Case4UPMichDfbTEMP',
#  'Case4VegasNVBwhTEMP',
#  'Case4WadenaMNDfaTEMP']

# %%
# Reseal homer file (.zip -> .homer)
files = [f for f in os.listdir(folder) if f.endswith('.zip')]
n_files = np.size(files)
type(files)
for i in range(len(files)):
    file = files[i]
    base = os.path.splitext(file)[0]
    os.rename(file, base + '.homer')
