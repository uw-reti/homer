# %% [markdown]
# # Zip folder unpacking script
# This script will do the following operations in order:
# Scan a folder
# create new calculation folder
# Loop the following actions for each homer script
#
#
#     Unseal homer template file (.homer -> .zip)
#
#
#     Unpack zip file (.zip -> normal directory)
#
#
#     Open 'problem' file
#
#
#     ####### NOT FOR THIS SCRIPT modify 'problem' file
#
#
#     Repack zip file (normal directory -> .zip)
#
#
#     Reseal homer file (.zip -> .homer)
#         ->[FOR THIS STEP TO FUNCTION PROPERLY, THE JUPYTER NOTEBOOK MUST BE EXECUTED ONE DIRECTORY HIGHER]
#
#
#     store updated input file in calculation folder
#
#
#     end

# %%
# Script initialization, make sure to set working directory
import os
import numpy as np 
import zipfile
import shutil
import zlib
import pathlib 
import subprocess
from lxml import etree, objectify
folder = 'd:/repo/homer/ClimateStudies/ProductionCases/Case4'

# %%
# Unsealing HOMER template files (.homer -> .zip)
files = [f for f in os.listdir(folder) if f.endswith('.homer')]
n_files = np.size(files)
display(files)
for i in range(len(files)):
    file = files[i]
    base = os.path.splitext(file)[0]
    os.rename(file, base + '.zip')
# Out:
# ['Case2AnchorageDfc.homer',
#  'Case2AshlandDfb.homer',
#  'Case2AtlantaGACfa.homer',
#  'Case2AZYumaBwh.homer',
#  'Case2BangorMEDfb.homer',
#  'Case2BendOreBsk.homer',
#  'Case2BentonCountyOregonCsb.homer',
#  'Case2BirminghamALCfa.homer',
#  'Case2BismarckNDDfb.homer',
#  'Case2BlaineCountyMontanaBSk.homer',
#  'Case2BoiseIDBSk.homer',
#  'Case2BrewsterMADfb.homer',
#  'Case2BurlingtonVTDfa.homer',
#  'Case2ButtonwillowBwk.homer',
#  'Case2CarsonCityNVBsk.homer',
#  'Case2CheyenneWYBsk.homer',
#  'Case2ChicagoDfa.homer',
#  'Case2CoalvilleUTDfb.homer',
#  'Case2ColumbiaMOCfa.homer',
#  'Case2ColumbusOHDfa.homer',
#  'Case2CrestedButteCODfc.homer',
#  'Case2DesMoinesIADfa.homer',
#  'Case2DetroitMIDfa.homer',
#  'Case2EielsonAFBDfC.homer',
#  'Case2EvergladesAM.homer',
#  'Case2FlagstaffDsb.homer',
#  'Case2GreatFallsMTBsk.homer',
#  'Case2HiloAf.homer',
#  'Case2IdahoFallsDfb.homer',
#  'Case2JacksonMSCfa.homer',
#  'Case2KauaiCfb.homer',
#  'Case2KootenaiCountyIDDsb.homer',
#  'Case2LancasterPADfa.homer',
#  'Case2LaredoTXBSh.homer',
#  'Case2LincolnNEDfa.homer',
#  'Case2LittleRockARCfa.homer',
#  'Case2LongviewCsb.homer',
#  'Case2LosAlamosNMDfb.homer',
#  'Case2MarlintonWVCfb.homer',
#  'Case2MedfordORCsa.homer',
#  'Case2MemphisTNCfa.homer',
#  'Case2MiamiAf.homer',
#  'Case2MobileALCfa.homer',
#  'Case2MoscowIDCsb.homer',
#  'Case2NeahBayCfb.homer',
#  'Case2NOLACfa.homer',
#  'Case2OKCityCfa.homer',
#  'Case2ORNLCfa.homer',
#  'Case2PhoenixAZBwh.homer',
#  'Case2PrescottAZCsa.homer',
#  'Case2PuebloBsk.homer',
#  'Case2RaleighNCCfa.homer',
#  'Case2RapidCitySDBsk.homer',
#  'Case2ReddingCACsa.homer',
#  'Case2RichmondVACfa.homer',
#  'Case2SacramentoCsa.homer',
#  'Case2SouthBendINDfa.homer',
#  'Case2SyracuseDfb.homer',
#  'Case2TexasOilBSh.homer',
#  'Case2UPMichDfb.homer',
#  'Case2VegasNVBwh.homer',
#  'Case2WadenaMNDfa.homer']

# %%
# Unpack zip file (.zip -> normal directory)
files = [f for f in os.listdir(folder) if f.endswith('.zip')]
n_files = np.size(files)
for i in range(len(files)):
    file = files[i]
    base = os.path.splitext(file)[0]
    with zipfile.ZipFile(file, 'r') as zip_ref:
        zip_ref.extractall(base + 'TEMP')
    os.remove(file)
# Opening each individiual 'problem' file after extraction

# %%
# (Within normal directory) Edit the .xml files for each HOMER problem.
files = [f for f in os.listdir(folder) if f.endswith('TEMP')]
display(files)
# paths to change as key, new value as value
new_data = {'/HomerProblem/FuelResources/Fuel/Name': 'CCM FUEL',
            '/HomerProblem/FuelResources/Fuel/FuelCostSensitivity/decimal': '0.00',
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/Initial': '24000000',
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/Quantity': '1000' ,
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/CapitalCostDetail/CostCalculatorItem/UnitCost': '24000' ,
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/Replacement': '3550000',
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/ReplacementCostDetail/CostCalculatorItem/Quantity': '1000' ,
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/ReplacementCostDetail/CostCalculatorItem/UnitCost': '3550000' ,
            '/HomerProblem/Generators/Generator/LifetimeSensitivity/decimal': '43830' ,
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/Operating': '58.33',
            '/HomerProblem/SimulationParameters/Economics/ProjectLifetimeSensitivity/decimal': '60',
            '/HomerProblem/SimulationParameters/SystemControl/Optimizer/FocusFactor': '2'}
   
for i in range(len(files)):
    file = files[i]
    problems = etree.parse(file + '/problem')
    #os.remove(file + '/calculated-problem') #deletes old homer savestate
    for path, value in new_data.items():
       # if 'CapacityOptimization' in path:#not necessary currently, but can be used to differentiate values later
       #     problems.xpath(path)[0].text = value
       #     newfile = etree.tostring(problems,encoding='utf-8',method='xml', xml_declaration='<?xml version="1.0" encoding="utf-8"?>')
       #     newfile = str(newfile,'utf-8')#otherwise use utf-8
       # else: 
            #print(path, ' => ', problems.xpath(path)[0].text)
        problems.xpath(path)[0].text = value
        newfile = etree.tostring(problems,encoding='US-ASCII',method='xml', xml_declaration='<?xml version="1.0" encoding="utf-8"?>')
        newfile = str(newfile,'US-ASCII')#otherwise use utf-8
    with open(file + '/problem','w') as f:
    #   # newfile = etree.tostring(new)
         f.write(newfile)
        
        
        
    #display(problem)
       # problem.xpath(j)[0].text = value[j]
# Out:
# ['Case2AnchorageDfcTEMP',
#  'Case2AshlandDfbTEMP',
#  'Case2AtlantaGACfaTEMP',
#  'Case2AZYumaBwhTEMP',
#  'Case2BangorMEDfbTEMP',
#  'Case2BendOreBskTEMP',
#  'Case2BentonCountyOregonCsbTEMP',
#  'Case2BirminghamALCfaTEMP',
#  'Case2BismarckNDDfbTEMP',
#  'Case2BlaineCountyMontanaBSkTEMP',
#  'Case2BoiseIDBSkTEMP',
#  'Case2BrewsterMADfbTEMP',
#  'Case2BurlingtonVTDfaTEMP',
#  'Case2ButtonwillowBwkTEMP',
#  'Case2CarsonCityNVBskTEMP',
#  'Case2CheyenneWYBskTEMP',
#  'Case2ChicagoDfaTEMP',
#  'Case2CoalvilleUTDfbTEMP',
#  'Case2ColumbiaMOCfaTEMP',
#  'Case2ColumbusOHDfaTEMP',
#  'Case2CrestedButteCODfcTEMP',
#  'Case2DesMoinesIADfaTEMP',
#  'Case2DetroitMIDfaTEMP',
#  'Case2EielsonAFBDfCTEMP',
#  'Case2EvergladesAMTEMP',
#  'Case2FlagstaffDsbTEMP',
#  'Case2GreatFallsMTBskTEMP',
#  'Case2HiloAfTEMP',
#  'Case2IdahoFallsDfbTEMP',
#  'Case2JacksonMSCfaTEMP',
#  'Case2KauaiCfbTEMP',
#  'Case2KootenaiCountyIDDsbTEMP',
#  'Case2LancasterPADfaTEMP',
#  'Case2LaredoTXBShTEMP',
#  'Case2LincolnNEDfaTEMP',
#  'Case2LittleRockARCfaTEMP',
#  'Case2LongviewCsbTEMP',
#  'Case2LosAlamosNMDfbTEMP',
#  'Case2MarlintonWVCfbTEMP',
#  'Case2MedfordORCsaTEMP',
#  'Case2MemphisTNCfaTEMP',
#  'Case2MiamiAfTEMP',
#  'Case2MobileALCfaTEMP',
#  'Case2MoscowIDCsbTEMP',
#  'Case2NeahBayCfbTEMP',
#  'Case2NOLACfaTEMP',
#  'Case2OKCityCfaTEMP',
#  'Case2ORNLCfaTEMP',
#  'Case2PhoenixAZBwhTEMP',
#  'Case2PrescottAZCsaTEMP',
#  'Case2PuebloBskTEMP',
#  'Case2RaleighNCCfaTEMP',
#  'Case2RapidCitySDBskTEMP',
#  'Case2ReddingCACsaTEMP',
#  'Case2RichmondVACfaTEMP',
#  'Case2SacramentoCsaTEMP',
#  'Case2SouthBendINDfaTEMP',
#  'Case2SyracuseDfbTEMP',
#  'Case2TexasOilBShTEMP',
#  'Case2UPMichDfbTEMP',
#  'Case2VegasNVBwhTEMP',
#  'Case2WadenaMNDfaTEMP']

# %%
#Repack zip file (normal directory -> .zip)
## THIS STEP CURRENTLY BREAKS THE HOMER FILE
## Try using zipcode compression 
files = [f for f in os.listdir(folder) if f.endswith('TEMP')]
display(files)
for i in range(len(files)):
    file = files[i]
    directory = pathlib.Path(file)
    basefile = file.replace('TEMP','')
    basefile = basefile.replace('Case2','Case4')
    subprocess.run(["powershell.exe", "Compress-Archive -Path " + file + "\* -DestinationPath " + basefile + " -Force"])
    shutil.rmtree(file) #deletes old temp folders
# Out:
# ['Case2AnchorageDfcTEMP',
#  'Case2AshlandDfbTEMP',
#  'Case2AtlantaGACfaTEMP',
#  'Case2AZYumaBwhTEMP',
#  'Case2BangorMEDfbTEMP',
#  'Case2BendOreBskTEMP',
#  'Case2BentonCountyOregonCsbTEMP',
#  'Case2BirminghamALCfaTEMP',
#  'Case2BismarckNDDfbTEMP',
#  'Case2BlaineCountyMontanaBSkTEMP',
#  'Case2BoiseIDBSkTEMP',
#  'Case2BrewsterMADfbTEMP',
#  'Case2BurlingtonVTDfaTEMP',
#  'Case2ButtonwillowBwkTEMP',
#  'Case2CarsonCityNVBskTEMP',
#  'Case2CheyenneWYBskTEMP',
#  'Case2ChicagoDfaTEMP',
#  'Case2CoalvilleUTDfbTEMP',
#  'Case2ColumbiaMOCfaTEMP',
#  'Case2ColumbusOHDfaTEMP',
#  'Case2CrestedButteCODfcTEMP',
#  'Case2DesMoinesIADfaTEMP',
#  'Case2DetroitMIDfaTEMP',
#  'Case2EielsonAFBDfCTEMP',
#  'Case2EvergladesAMTEMP',
#  'Case2FlagstaffDsbTEMP',
#  'Case2GreatFallsMTBskTEMP',
#  'Case2HiloAfTEMP',
#  'Case2IdahoFallsDfbTEMP',
#  'Case2JacksonMSCfaTEMP',
#  'Case2KauaiCfbTEMP',
#  'Case2KootenaiCountyIDDsbTEMP',
#  'Case2LancasterPADfaTEMP',
#  'Case2LaredoTXBShTEMP',
#  'Case2LincolnNEDfaTEMP',
#  'Case2LittleRockARCfaTEMP',
#  'Case2LongviewCsbTEMP',
#  'Case2LosAlamosNMDfbTEMP',
#  'Case2MarlintonWVCfbTEMP',
#  'Case2MedfordORCsaTEMP',
#  'Case2MemphisTNCfaTEMP',
#  'Case2MiamiAfTEMP',
#  'Case2MobileALCfaTEMP',
#  'Case2MoscowIDCsbTEMP',
#  'Case2NeahBayCfbTEMP',
#  'Case2NOLACfaTEMP',
#  'Case2OKCityCfaTEMP',
#  'Case2ORNLCfaTEMP',
#  'Case2PhoenixAZBwhTEMP',
#  'Case2PrescottAZCsaTEMP',
#  'Case2PuebloBskTEMP',
#  'Case2RaleighNCCfaTEMP',
#  'Case2RapidCitySDBskTEMP',
#  'Case2ReddingCACsaTEMP',
#  'Case2RichmondVACfaTEMP',
#  'Case2SacramentoCsaTEMP',
#  'Case2SouthBendINDfaTEMP',
#  'Case2SyracuseDfbTEMP',
#  'Case2TexasOilBShTEMP',
#  'Case2UPMichDfbTEMP',
#  'Case2VegasNVBwhTEMP',
#  'Case2WadenaMNDfaTEMP']

# %%
# Reseal homer file (.zip -> .homer)
files = [f for f in os.listdir(folder) if f.endswith('.zip')]
n_files = np.size(files)
type(files)
for i in range(len(files)):
    file = files[i]
    base = os.path.splitext(file)[0]
    os.rename(file, base + '.homer')
