# %% [markdown]
# # Zip folder unpacking script
# This script will do the following operations in order:
# Scan a folder
# create new calculation folder
# Loop the following actions for each homer script
#
#
#     Unseal homer template file (.homer -> .zip)
#
#
#     Unpack zip file (.zip -> normal directory)
#
#
#     Open 'problem' file
#
#
#     ####### NOT FOR THIS SCRIPT modify 'problem' file
#
#
#     Repack zip file (normal directory -> .zip)
#
#
#     Reseal homer file (.zip -> .homer)
#         ->[FOR THIS STEP TO FUNCTION PROPERLY, THE JUPYTER NOTEBOOK MUST BE EXECUTED ONE DIRECTORY HIGHER]
#
#
#     store updated input file in calculation folder
#
#
#     end

# %%
# Script initialization, make sure to set working directory
import os
import numpy as np 
import zipfile
import shutil
import zlib
import pathlib 
import subprocess
from lxml import etree, objectify
folder = 'd:/repo/homer/ClimateStudies/ProductionCases/Case3'

# %%
# Unsealing HOMER template files (.homer -> .zip)
files = [f for f in os.listdir(folder) if f.endswith('.homer')]
n_files = np.size(files)
display(files)
for i in range(len(files)):
    file = files[i]
    base = os.path.splitext(file)[0]
    os.rename(file, base + '.zip')
# Out:
# ['Case3AnchorageDfc.homer',
#  'Case3AshlandDfb.homer',
#  'Case3AtlantaGACfa.homer',
#  'Case3AZYumaBwh.homer',
#  'Case3BangorMEDfb.homer',
#  'Case3BendOreBsk.homer',
#  'Case3BentonCountyOregonCsb.homer',
#  'Case3BirminghamALCfa.homer',
#  'Case3BismarckNDDfb.homer',
#  'Case3BlaineCountyMontanaBSk.homer',
#  'Case3BoiseIDBSk.homer',
#  'Case3BrewsterMADfb.homer',
#  'Case3BurlingtonVTDfa.homer',
#  'Case3ButtonwillowBwk.homer',
#  'Case3CarsonCityNVBsk.homer',
#  'Case3CheyenneWYBsk.homer',
#  'Case3ChicagoDfa.homer',
#  'Case3CoalvilleUTDfb.homer',
#  'Case3ColumbiaMOCfa.homer',
#  'Case3ColumbusOHDfa.homer',
#  'Case3CrestedButteCODfc.homer',
#  'Case3DesMoinesIADfa.homer',
#  'Case3DetroitMIDfa.homer',
#  'Case3EielsonAFBDfC.homer',
#  'Case3EvergladesAM.homer',
#  'Case3FlagstaffDsb.homer',
#  'Case3GreatFallsMTBsk.homer',
#  'Case3HiloAf.homer',
#  'Case3IdahoFallsDfb.homer',
#  'Case3JacksonMSCfa.homer',
#  'Case3KauaiCfb.homer',
#  'Case3KootenaiCountyIDDsb.homer',
#  'Case3LancasterPADfa.homer',
#  'Case3LaredoTXBSh.homer',
#  'Case3LincolnNEDfa.homer',
#  'Case3LittleRockARCfa.homer',
#  'Case3LongviewCsb.homer',
#  'Case3LosAlamosNMDfb.homer',
#  'Case3MarlintonWVCfb.homer',
#  'Case3MedfordORCsa.homer',
#  'Case3MemphisTNCfa.homer',
#  'Case3MiamiAf.homer',
#  'Case3MobileALCfa.homer',
#  'Case3MoscowIDCsb.homer',
#  'Case3NeahBayCfb.homer',
#  'Case3NOLACfa.homer',
#  'Case3OKCityCfa.homer',
#  'Case3ORNLCfa.homer',
#  'Case3PhoenixAZBwh.homer',
#  'Case3PrescottAZCsa.homer',
#  'Case3PuebloBsk.homer',
#  'Case3RaleighNCCfa.homer',
#  'Case3RapidCitySDBsk.homer',
#  'Case3ReddingCACsa.homer',
#  'Case3RichmondVACfa.homer',
#  'Case3SacramentoCsa.homer',
#  'Case3SouthBendINDfa.homer',
#  'Case3SyracuseDfb.homer',
#  'Case3TexasOilBSh.homer',
#  'Case3UPMichDfb.homer',
#  'Case3VegasNVBwh.homer',
#  'Case3WadenaMNDfa.homer']

# %%
# Unpack zip file (.zip -> normal directory)
files = [f for f in os.listdir(folder) if f.endswith('.zip')]
n_files = np.size(files)
for i in range(len(files)):
    file = files[i]
    base = os.path.splitext(file)[0]
    with zipfile.ZipFile(file, 'r') as zip_ref:
        zip_ref.extractall(base + 'TEMP')
    os.remove(file)
# Opening each individiual 'problem' file after extraction

# %%
# (Within normal directory) Edit the .xml files for each HOMER problem.
files = [f for f in os.listdir(folder) if f.endswith('TEMP')]
display(files)
# paths to change as key, new value as value
new_data = {'/HomerProblem/FuelResources/Fuel/Name': 'CCM FUEL',
            '/HomerProblem/FuelResources/Fuel/FuelCostSensitivity/decimal': '0.00',
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/Initial': '16000000',
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/Quantity': '1000' ,
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/CapitalCostDetail/CostCalculatorItem/UnitCost': '16000' ,
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/Replacement': '3550000',
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/ReplacementCostDetail/CostCalculatorItem/Quantity': '1000' ,
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/ReplacementCostDetail/CostCalculatorItem/UnitCost': '3550' ,
            '/HomerProblem/Generators/Generator/LifetimeSensitivity/decimal': '87660' ,
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/Operating': '33.42',
            '/HomerProblem/SimulationParameters/Economics/ProjectLifetimeSensitivity/decimal': '60',
            '/HomerProblem/SimulationParameters/SystemControl/Optimizer/FocusFactor': '10'}
   
for i in range(len(files)):
    file = files[i]
    problems = etree.parse(file + '/problem')
    #os.remove(file + '/calculated-problem') #deletes old homer savestate
    for path, value in new_data.items():
       # if 'CapacityOptimization' in path:#not necessary currently, but can be used to differentiate values later
       #     problems.xpath(path)[0].text = value
       #     newfile = etree.tostring(problems,encoding='utf-8',method='xml', xml_declaration='<?xml version="1.0" encoding="utf-8"?>')
       #     newfile = str(newfile,'utf-8')#otherwise use utf-8
       # else: 
            #print(path, ' => ', problems.xpath(path)[0].text)
        problems.xpath(path)[0].text = value
        newfile = etree.tostring(problems,encoding='US-ASCII',method='xml', xml_declaration='<?xml version="1.0" encoding="utf-8"?>')
        newfile = str(newfile,'US-ASCII')#otherwise use utf-8
    with open(file + '/problem','w') as f:
    #   # newfile = etree.tostring(new)
         f.write(newfile)
        
        
        
    #display(problem)
       # problem.xpath(j)[0].text = value[j]
# Out:
# ['Case3AnchorageDfcTEMP',
#  'Case3AshlandDfbTEMP',
#  'Case3AtlantaGACfaTEMP',
#  'Case3AZYumaBwhTEMP',
#  'Case3BangorMEDfbTEMP',
#  'Case3BendOreBskTEMP',
#  'Case3BentonCountyOregonCsbTEMP',
#  'Case3BirminghamALCfaTEMP',
#  'Case3BismarckNDDfbTEMP',
#  'Case3BlaineCountyMontanaBSkTEMP',
#  'Case3BoiseIDBSkTEMP',
#  'Case3BrewsterMADfbTEMP',
#  'Case3BurlingtonVTDfaTEMP',
#  'Case3ButtonwillowBwkTEMP',
#  'Case3CarsonCityNVBskTEMP',
#  'Case3CheyenneWYBskTEMP',
#  'Case3ChicagoDfaTEMP',
#  'Case3CoalvilleUTDfbTEMP',
#  'Case3ColumbiaMOCfaTEMP',
#  'Case3ColumbusOHDfaTEMP',
#  'Case3CrestedButteCODfcTEMP',
#  'Case3DesMoinesIADfaTEMP',
#  'Case3DetroitMIDfaTEMP',
#  'Case3EielsonAFBDfCTEMP',
#  'Case3EvergladesAMTEMP',
#  'Case3FlagstaffDsbTEMP',
#  'Case3GreatFallsMTBskTEMP',
#  'Case3HiloAfTEMP',
#  'Case3IdahoFallsDfbTEMP',
#  'Case3JacksonMSCfaTEMP',
#  'Case3KauaiCfbTEMP',
#  'Case3KootenaiCountyIDDsbTEMP',
#  'Case3LancasterPADfaTEMP',
#  'Case3LaredoTXBShTEMP',
#  'Case3LincolnNEDfaTEMP',
#  'Case3LittleRockARCfaTEMP',
#  'Case3LongviewCsbTEMP',
#  'Case3LosAlamosNMDfbTEMP',
#  'Case3MarlintonWVCfbTEMP',
#  'Case3MedfordORCsaTEMP',
#  'Case3MemphisTNCfaTEMP',
#  'Case3MiamiAfTEMP',
#  'Case3MobileALCfaTEMP',
#  'Case3MoscowIDCsbTEMP',
#  'Case3NeahBayCfbTEMP',
#  'Case3NOLACfaTEMP',
#  'Case3OKCityCfaTEMP',
#  'Case3ORNLCfaTEMP',
#  'Case3PhoenixAZBwhTEMP',
#  'Case3PrescottAZCsaTEMP',
#  'Case3PuebloBskTEMP',
#  'Case3RaleighNCCfaTEMP',
#  'Case3RapidCitySDBskTEMP',
#  'Case3ReddingCACsaTEMP',
#  'Case3RichmondVACfaTEMP',
#  'Case3SacramentoCsaTEMP',
#  'Case3SouthBendINDfaTEMP',
#  'Case3SyracuseDfbTEMP',
#  'Case3TexasOilBShTEMP',
#  'Case3UPMichDfbTEMP',
#  'Case3VegasNVBwhTEMP',
#  'Case3WadenaMNDfaTEMP']

# %%
#Repack zip file (normal directory -> .zip)
## THIS STEP CURRENTLY BREAKS THE HOMER FILE
## Try using zipcode compression 
files = [f for f in os.listdir(folder) if f.endswith('TEMP')]
display(files)
for i in range(len(files)):
    file = files[i]
    directory = pathlib.Path(file)
    basefile = file.replace('TEMP','')
    basefile = basefile.replace('Case2','Case3')
    subprocess.run(["powershell.exe", "Compress-Archive -Path " + file + "\* -DestinationPath " + basefile + " -Force"])
    shutil.rmtree(file) #deletes old temp folders
# Out:
# ['Case3AnchorageDfcTEMP',
#  'Case3AshlandDfbTEMP',
#  'Case3AtlantaGACfaTEMP',
#  'Case3AZYumaBwhTEMP',
#  'Case3BangorMEDfbTEMP',
#  'Case3BendOreBskTEMP',
#  'Case3BentonCountyOregonCsbTEMP',
#  'Case3BirminghamALCfaTEMP',
#  'Case3BismarckNDDfbTEMP',
#  'Case3BlaineCountyMontanaBSkTEMP',
#  'Case3BoiseIDBSkTEMP',
#  'Case3BrewsterMADfbTEMP',
#  'Case3BurlingtonVTDfaTEMP',
#  'Case3ButtonwillowBwkTEMP',
#  'Case3CarsonCityNVBskTEMP',
#  'Case3CheyenneWYBskTEMP',
#  'Case3ChicagoDfaTEMP',
#  'Case3CoalvilleUTDfbTEMP',
#  'Case3ColumbiaMOCfaTEMP',
#  'Case3ColumbusOHDfaTEMP',
#  'Case3CrestedButteCODfcTEMP',
#  'Case3DesMoinesIADfaTEMP',
#  'Case3DetroitMIDfaTEMP',
#  'Case3EielsonAFBDfCTEMP',
#  'Case3EvergladesAMTEMP',
#  'Case3FlagstaffDsbTEMP',
#  'Case3GreatFallsMTBskTEMP',
#  'Case3HiloAfTEMP',
#  'Case3IdahoFallsDfbTEMP',
#  'Case3JacksonMSCfaTEMP',
#  'Case3KauaiCfbTEMP',
#  'Case3KootenaiCountyIDDsbTEMP',
#  'Case3LancasterPADfaTEMP',
#  'Case3LaredoTXBShTEMP',
#  'Case3LincolnNEDfaTEMP',
#  'Case3LittleRockARCfaTEMP',
#  'Case3LongviewCsbTEMP',
#  'Case3LosAlamosNMDfbTEMP',
#  'Case3MarlintonWVCfbTEMP',
#  'Case3MedfordORCsaTEMP',
#  'Case3MemphisTNCfaTEMP',
#  'Case3MiamiAfTEMP',
#  'Case3MobileALCfaTEMP',
#  'Case3MoscowIDCsbTEMP',
#  'Case3NeahBayCfbTEMP',
#  'Case3NOLACfaTEMP',
#  'Case3OKCityCfaTEMP',
#  'Case3ORNLCfaTEMP',
#  'Case3PhoenixAZBwhTEMP',
#  'Case3PrescottAZCsaTEMP',
#  'Case3PuebloBskTEMP',
#  'Case3RaleighNCCfaTEMP',
#  'Case3RapidCitySDBskTEMP',
#  'Case3ReddingCACsaTEMP',
#  'Case3RichmondVACfaTEMP',
#  'Case3SacramentoCsaTEMP',
#  'Case3SouthBendINDfaTEMP',
#  'Case3SyracuseDfbTEMP',
#  'Case3TexasOilBShTEMP',
#  'Case3UPMichDfbTEMP',
#  'Case3VegasNVBwhTEMP',
#  'Case3WadenaMNDfaTEMP']

# %%
# Reseal homer file (.zip -> .homer)
files = [f for f in os.listdir(folder) if f.endswith('.zip')]
n_files = np.size(files)
type(files)
for i in range(len(files)):
    file = files[i]
    base = os.path.splitext(file)[0]
    os.rename(file, base + '.homer')
