# %% [markdown]
# # Zip folder unpacking script
# This script will do the following operations in order:
# Scan a folder
# create new calculation folder
# Loop the following actions for each homer script
#
#
#     Unseal homer template file (.homer -> .zip)
#
#
#     Unpack zip file (.zip -> normal directory)
#
#
#     Open 'problem' file
#
#
#     ####### NOT FOR THIS SCRIPT modify 'problem' file
#
#
#     Repack zip file (normal directory -> .zip)
#
#
#     Reseal homer file (.zip -> .homer)
#         ->[FOR THIS STEP TO FUNCTION PROPERLY, THE JUPYTER NOTEBOOK MUST BE EXECUTED ONE DIRECTORY HIGHER]
#
#
#     store updated input file in calculation folder
#
#
#     end

# %%
# Script initialization, make sure to set working directory
import os
import numpy as np 
import zipfile
import shutil
import zlib
import pathlib 
import subprocess
from lxml import etree, objectify
folder = 'd:/repo/homer/ClimateStudies/ProductionCases/MinimumLoadRatio/70/8000/'

# %%
# Unsealing HOMER template files (.homer -> .zip)
files = [f for f in os.listdir(folder) if f.endswith('.homer')]
n_files = np.size(files)
display(files)
for i in range(len(files)):
    file = files[i]
    base = os.path.splitext(file)[0]
    os.rename(file, base + '.zip')
# Out:
# ['Case2MLR50AnchorageDfc.homer',
#  'Case2MLR50AshlandDfb.homer',
#  'Case2MLR50AtlantaGACfa.homer',
#  'Case2MLR50AZYumaBwh.homer',
#  'Case2MLR50BangorMEDfb.homer',
#  'Case2MLR50BendOreBsk.homer',
#  'Case2MLR50BentonCountyOregonCsb.homer',
#  'Case2MLR50BirminghamALCfa.homer',
#  'Case2MLR50BismarckNDDfb.homer',
#  'Case2MLR50BlaineCountyMontanaBSk.homer',
#  'Case2MLR50BoiseIDBSk.homer',
#  'Case2MLR50BrewsterMADfb.homer',
#  'Case2MLR50BurlingtonVTDfa.homer',
#  'Case2MLR50ButtonwillowBwk.homer',
#  'Case2MLR50CarsonCityNVBsk.homer',
#  'Case2MLR50CheyenneWYBsk.homer',
#  'Case2MLR50ChicagoDfa.homer',
#  'Case2MLR50CoalvilleUTDfb.homer',
#  'Case2MLR50ColumbiaMOCfa.homer',
#  'Case2MLR50ColumbusOHDfa.homer',
#  'Case2MLR50CrestedButteCODfc.homer',
#  'Case2MLR50DesMoinesIADfa.homer',
#  'Case2MLR50DetroitMIDfa.homer',
#  'Case2MLR50EielsonAFBDfC.homer',
#  'Case2MLR50EvergladesAM.homer',
#  'Case2MLR50FlagstaffDsb.homer',
#  'Case2MLR50GreatFallsMTBsk.homer',
#  'Case2MLR50HiloAf.homer',
#  'Case2MLR50IdahoFallsDfb.homer',
#  'Case2MLR50JacksonMSCfa.homer',
#  'Case2MLR50KauaiCfb.homer',
#  'Case2MLR50KootenaiCountyIDDsb.homer',
#  'Case2MLR50LancasterPADfa.homer',
#  'Case2MLR50LaredoTXBSh.homer',
#  'Case2MLR50LincolnNEDfa.homer',
#  'Case2MLR50LittleRockARCfa.homer',
#  'Case2MLR50LongviewCsb.homer',
#  'Case2MLR50LosAlamosNMDfb.homer',
#  'Case2MLR50MarlintonWVCfb.homer',
#  'Case2MLR50MedfordORCsa.homer',
#  'Case2MLR50MemphisTNCfa.homer',
#  'Case2MLR50MiamiAf.homer',
#  'Case2MLR50MobileALCfa.homer',
#  'Case2MLR50MoscowIDCsb.homer',
#  'Case2MLR50NeahBayCfb.homer',
#  'Case2MLR50NOLACfa.homer',
#  'Case2MLR50OKCityCfa.homer',
#  'Case2MLR50ORNLCfa.homer',
#  'Case2MLR50PhoenixAZBwh.homer',
#  'Case2MLR50PrescottAZCsa.homer',
#  'Case2MLR50PuebloBsk.homer',
#  'Case2MLR50RaleighNCCfa.homer',
#  'Case2MLR50RapidCitySDBsk.homer',
#  'Case2MLR50ReddingCACsa.homer',
#  'Case2MLR50RichmondVACfa.homer',
#  'Case2MLR50SacramentoCsa.homer',
#  'Case2MLR50SouthBendINDfa.homer',
#  'Case2MLR50SyracuseDfb.homer',
#  'Case2MLR50TexasOilBSh.homer',
#  'Case2MLR50UPMichDfb.homer',
#  'Case2MLR50VegasNVBwh.homer',
#  'Case2MLR50WadenaMNDfa.homer']

# %%
# Unpack zip file (.zip -> normal directory)
files = [f for f in os.listdir(folder) if f.endswith('.zip')]
n_files = np.size(files)
for i in range(len(files)):
    file = files[i]
    base = os.path.splitext(file)[0]
    with zipfile.ZipFile(file, 'r') as zip_ref:
        zip_ref.extractall(base + 'TEMP')
    os.remove(file)
# Opening each individiual 'problem' file after extraction

# %%
# (Within normal directory) Edit the .xml files for each HOMER problem.
files = [f for f in os.listdir(folder) if f.endswith('TEMP')]
display(files)
# paths to change as key, new value as value
new_data = {'/HomerProblem/FuelResources/Fuel/Name': 'CCM FUEL',
            '/HomerProblem/FuelResources/Fuel/FuelCostSensitivity/decimal': '0.00',
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/Initial': '8000000',
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/Quantity': '1000' ,
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/CapitalCostDetail/CostCalculatorItem/UnitCost': '8000' ,
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/Replacement': '3550000',
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/ReplacementCostDetail/CostCalculatorItem/Quantity': '1000' ,
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/ReplacementCostDetail/CostCalculatorItem/UnitCost': '3550000' ,
            '/HomerProblem/Generators/Generator/LifetimeSensitivity/decimal': '175320' ,
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/Operating': '14.60',
            '/HomerProblem/SimulationParameters/Economics/ProjectLifetimeSensitivity/decimal': '60',
            '/HomerProblem/SimulationParameters/SystemControl/Optimizer/FocusFactor': '2',
            '/HomerProblem/Generators/Generator/MinimumLoadRatioSensitivity/decimal':'70'}
   
for i in range(len(files)):
    file = files[i]
    problems = etree.parse(file + '/problem')
    #os.remove(file + '/calculated-problem') #deletes old homer savestate
    for path, value in new_data.items():
       # if 'CapacityOptimization' in path:#not necessary currently, but can be used to differentiate values later
       #     problems.xpath(path)[0].text = value
       #     newfile = etree.tostring(problems,encoding='utf-8',method='xml', xml_declaration='<?xml version="1.0" encoding="utf-8"?>')
       #     newfile = str(newfile,'utf-8')#otherwise use utf-8
       # else: 
            #print(path, ' => ', problems.xpath(path)[0].text)
        problems.xpath(path)[0].text = value
        newfile = etree.tostring(problems,encoding='US-ASCII',method='xml', xml_declaration='<?xml version="1.0" encoding="utf-8"?>')
        newfile = str(newfile,'US-ASCII')#otherwise use utf-8
    with open(file + '/problem','w') as f:
    #   # newfile = etree.tostring(new)
         f.write(newfile)
        
        
        
    #display(problem)
       # problem.xpath(j)[0].text = value[j]
# Out:
# ['Case2MLR50AnchorageDfcTEMP',
#  'Case2MLR50AshlandDfbTEMP',
#  'Case2MLR50AtlantaGACfaTEMP',
#  'Case2MLR50AZYumaBwhTEMP',
#  'Case2MLR50BangorMEDfbTEMP',
#  'Case2MLR50BendOreBskTEMP',
#  'Case2MLR50BentonCountyOregonCsbTEMP',
#  'Case2MLR50BirminghamALCfaTEMP',
#  'Case2MLR50BismarckNDDfbTEMP',
#  'Case2MLR50BlaineCountyMontanaBSkTEMP',
#  'Case2MLR50BoiseIDBSkTEMP',
#  'Case2MLR50BrewsterMADfbTEMP',
#  'Case2MLR50BurlingtonVTDfaTEMP',
#  'Case2MLR50ButtonwillowBwkTEMP',
#  'Case2MLR50CarsonCityNVBskTEMP',
#  'Case2MLR50CheyenneWYBskTEMP',
#  'Case2MLR50ChicagoDfaTEMP',
#  'Case2MLR50CoalvilleUTDfbTEMP',
#  'Case2MLR50ColumbiaMOCfaTEMP',
#  'Case2MLR50ColumbusOHDfaTEMP',
#  'Case2MLR50CrestedButteCODfcTEMP',
#  'Case2MLR50DesMoinesIADfaTEMP',
#  'Case2MLR50DetroitMIDfaTEMP',
#  'Case2MLR50EielsonAFBDfCTEMP',
#  'Case2MLR50EvergladesAMTEMP',
#  'Case2MLR50FlagstaffDsbTEMP',
#  'Case2MLR50GreatFallsMTBskTEMP',
#  'Case2MLR50HiloAfTEMP',
#  'Case2MLR50IdahoFallsDfbTEMP',
#  'Case2MLR50JacksonMSCfaTEMP',
#  'Case2MLR50KauaiCfbTEMP',
#  'Case2MLR50KootenaiCountyIDDsbTEMP',
#  'Case2MLR50LancasterPADfaTEMP',
#  'Case2MLR50LaredoTXBShTEMP',
#  'Case2MLR50LincolnNEDfaTEMP',
#  'Case2MLR50LittleRockARCfaTEMP',
#  'Case2MLR50LongviewCsbTEMP',
#  'Case2MLR50LosAlamosNMDfbTEMP',
#  'Case2MLR50MarlintonWVCfbTEMP',
#  'Case2MLR50MedfordORCsaTEMP',
#  'Case2MLR50MemphisTNCfaTEMP',
#  'Case2MLR50MiamiAfTEMP',
#  'Case2MLR50MobileALCfaTEMP',
#  'Case2MLR50MoscowIDCsbTEMP',
#  'Case2MLR50NeahBayCfbTEMP',
#  'Case2MLR50NOLACfaTEMP',
#  'Case2MLR50OKCityCfaTEMP',
#  'Case2MLR50ORNLCfaTEMP',
#  'Case2MLR50PhoenixAZBwhTEMP',
#  'Case2MLR50PrescottAZCsaTEMP',
#  'Case2MLR50PuebloBskTEMP',
#  'Case2MLR50RaleighNCCfaTEMP',
#  'Case2MLR50RapidCitySDBskTEMP',
#  'Case2MLR50ReddingCACsaTEMP',
#  'Case2MLR50RichmondVACfaTEMP',
#  'Case2MLR50SacramentoCsaTEMP',
#  'Case2MLR50SouthBendINDfaTEMP',
#  'Case2MLR50SyracuseDfbTEMP',
#  'Case2MLR50TexasOilBShTEMP',
#  'Case2MLR50UPMichDfbTEMP',
#  'Case2MLR50VegasNVBwhTEMP',
#  'Case2MLR50WadenaMNDfaTEMP']

# %%
#Repack zip file (normal directory -> .zip)
## THIS STEP CURRENTLY BREAKS THE HOMER FILE
## Try using zipcode compression 
files = [f for f in os.listdir(folder) if f.endswith('TEMP')]
display(files)
for i in range(len(files)):
    file = files[i]
    directory = pathlib.Path(file)
    basefile = file.replace('TEMP','')
    basefile = basefile.replace('Case2MLR50','Case2MLR70')
    subprocess.run(["powershell.exe", "Compress-Archive -Path " + file + "\* -DestinationPath " + basefile + " -Force"])
    shutil.rmtree(file) #deletes old temp folders
# Out:
# ['Case2MLR50AnchorageDfcTEMP',
#  'Case2MLR50AshlandDfbTEMP',
#  'Case2MLR50AtlantaGACfaTEMP',
#  'Case2MLR50AZYumaBwhTEMP',
#  'Case2MLR50BangorMEDfbTEMP',
#  'Case2MLR50BendOreBskTEMP',
#  'Case2MLR50BentonCountyOregonCsbTEMP',
#  'Case2MLR50BirminghamALCfaTEMP',
#  'Case2MLR50BismarckNDDfbTEMP',
#  'Case2MLR50BlaineCountyMontanaBSkTEMP',
#  'Case2MLR50BoiseIDBSkTEMP',
#  'Case2MLR50BrewsterMADfbTEMP',
#  'Case2MLR50BurlingtonVTDfaTEMP',
#  'Case2MLR50ButtonwillowBwkTEMP',
#  'Case2MLR50CarsonCityNVBskTEMP',
#  'Case2MLR50CheyenneWYBskTEMP',
#  'Case2MLR50ChicagoDfaTEMP',
#  'Case2MLR50CoalvilleUTDfbTEMP',
#  'Case2MLR50ColumbiaMOCfaTEMP',
#  'Case2MLR50ColumbusOHDfaTEMP',
#  'Case2MLR50CrestedButteCODfcTEMP',
#  'Case2MLR50DesMoinesIADfaTEMP',
#  'Case2MLR50DetroitMIDfaTEMP',
#  'Case2MLR50EielsonAFBDfCTEMP',
#  'Case2MLR50EvergladesAMTEMP',
#  'Case2MLR50FlagstaffDsbTEMP',
#  'Case2MLR50GreatFallsMTBskTEMP',
#  'Case2MLR50HiloAfTEMP',
#  'Case2MLR50IdahoFallsDfbTEMP',
#  'Case2MLR50JacksonMSCfaTEMP',
#  'Case2MLR50KauaiCfbTEMP',
#  'Case2MLR50KootenaiCountyIDDsbTEMP',
#  'Case2MLR50LancasterPADfaTEMP',
#  'Case2MLR50LaredoTXBShTEMP',
#  'Case2MLR50LincolnNEDfaTEMP',
#  'Case2MLR50LittleRockARCfaTEMP',
#  'Case2MLR50LongviewCsbTEMP',
#  'Case2MLR50LosAlamosNMDfbTEMP',
#  'Case2MLR50MarlintonWVCfbTEMP',
#  'Case2MLR50MedfordORCsaTEMP',
#  'Case2MLR50MemphisTNCfaTEMP',
#  'Case2MLR50MiamiAfTEMP',
#  'Case2MLR50MobileALCfaTEMP',
#  'Case2MLR50MoscowIDCsbTEMP',
#  'Case2MLR50NeahBayCfbTEMP',
#  'Case2MLR50NOLACfaTEMP',
#  'Case2MLR50OKCityCfaTEMP',
#  'Case2MLR50ORNLCfaTEMP',
#  'Case2MLR50PhoenixAZBwhTEMP',
#  'Case2MLR50PrescottAZCsaTEMP',
#  'Case2MLR50PuebloBskTEMP',
#  'Case2MLR50RaleighNCCfaTEMP',
#  'Case2MLR50RapidCitySDBskTEMP',
#  'Case2MLR50ReddingCACsaTEMP',
#  'Case2MLR50RichmondVACfaTEMP',
#  'Case2MLR50SacramentoCsaTEMP',
#  'Case2MLR50SouthBendINDfaTEMP',
#  'Case2MLR50SyracuseDfbTEMP',
#  'Case2MLR50TexasOilBShTEMP',
#  'Case2MLR50UPMichDfbTEMP',
#  'Case2MLR50VegasNVBwhTEMP',
#  'Case2MLR50WadenaMNDfaTEMP']

# %%
# Reseal homer file (.zip -> .homer)
files = [f for f in os.listdir(folder) if f.endswith('.zip')]
n_files = np.size(files)
type(files)
for i in range(len(files)):
    file = files[i]
    base = os.path.splitext(file)[0]
    os.rename(file, base + '.homer')
