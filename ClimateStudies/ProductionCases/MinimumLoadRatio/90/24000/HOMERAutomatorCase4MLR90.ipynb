# %% [markdown]
# # Zip folder unpacking script
# This script will do the following operations in order:
# Scan a folder
# create new calculation folder
# Loop the following actions for each homer script
#
#
#     Unseal homer template file (.homer -> .zip)
#
#
#     Unpack zip file (.zip -> normal directory)
#
#
#     Open 'problem' file
#
#
#     ####### NOT FOR THIS SCRIPT modify 'problem' file
#
#
#     Repack zip file (normal directory -> .zip)
#
#
#     Reseal homer file (.zip -> .homer)
#         ->[FOR THIS STEP TO FUNCTION PROPERLY, THE JUPYTER NOTEBOOK MUST BE EXECUTED ONE DIRECTORY HIGHER]
#
#
#     store updated input file in calculation folder
#
#
#     end

# %%
# Script initialization, make sure to set working directory
import os
import numpy as np 
import zipfile
import shutil
import zlib
import pathlib 
import subprocess
from lxml import etree, objectify
folder = 'd:/repo/homer/ClimateStudies/ProductionCases/MinimumLoadRatio/90/24000'

# %%
# Unsealing HOMER template files (.homer -> .zip)
files = [f for f in os.listdir(folder) if f.endswith('.homer')]
n_files = np.size(files)
display(files)
for i in range(len(files)):
    file = files[i]
    base = os.path.splitext(file)[0]
    os.rename(file, base + '.zip')
# Out:
# ['Case4MLR50AnchorageDfc.homer',
#  'Case4MLR50AshlandDfb.homer',
#  'Case4MLR50AtlantaGACfa.homer',
#  'Case4MLR50BangorMEDfb.homer',
#  'Case4MLR50BendOreBsk.homer',
#  'Case4MLR50BentonCountyOregonCsb.homer',
#  'Case4MLR50BirminghamALCfa.homer',
#  'Case4MLR50BismarckNDDfb.homer',
#  'Case4MLR50BlaineCountyMontanaBSk.homer',
#  'Case4MLR50BoiseIDBSk.homer',
#  'Case4MLR50BrewsterMADfb.homer',
#  'Case4MLR50BurlingtonVTDfa.homer',
#  'Case4MLR50ButtonwillowBwk.homer',
#  'Case4MLR50CarsonCityNVBsk.homer',
#  'Case4MLR50CheyenneWYBsk.homer',
#  'Case4MLR50ChicagoDfa.homer',
#  'Case4MLR50CoalvilleUTDfb.homer',
#  'Case4MLR50ColumbiaMOCfa.homer',
#  'Case4MLR50ColumbusOHDfa.homer',
#  'Case4MLR50CrestedButteCODfc.homer',
#  'Case4MLR50DesMoinesIADfa.homer',
#  'Case4MLR50DetroitMIDfa.homer',
#  'Case4MLR50EielsonAFBDfC.homer',
#  'Case4MLR50EvergladesAM.homer',
#  'Case4MLR50FlagstaffDsb.homer',
#  'Case4MLR50GreatFallsMTBsk.homer',
#  'Case4MLR50HiloAf.homer',
#  'Case4MLR50IdahoFallsDfb.homer',
#  'Case4MLR50JacksonMSCfa.homer',
#  'Case4MLR50KauaiCfb.homer',
#  'Case4MLR50KootenaiCountyIDDsb.homer',
#  'Case4MLR50LancasterPADfa.homer',
#  'Case4MLR50LaredoTXBSh.homer',
#  'Case4MLR50LincolnNEDfa.homer',
#  'Case4MLR50LittleRockARCfa.homer',
#  'Case4MLR50LongviewCsb.homer',
#  'Case4MLR50LosAlamosNMDfb.homer',
#  'Case4MLR50MarlintonWVCfb.homer',
#  'Case4MLR50MedfordORCsa.homer',
#  'Case4MLR50MemphisTNCfa.homer',
#  'Case4MLR50MiamiAf.homer',
#  'Case4MLR50MobileALCfa.homer',
#  'Case4MLR50MoscowIDCsb.homer',
#  'Case4MLR50NeahBayCfb.homer',
#  'Case4MLR50NOLACfa.homer',
#  'Case4MLR50OKCityCfa.homer',
#  'Case4MLR50ORNLCfa.homer',
#  'Case4MLR50PhoenixAZBwh.homer',
#  'Case4MLR50PrescottAZCsa.homer',
#  'Case4MLR50PuebloBsk.homer',
#  'Case4MLR50RaleighNCCfa.homer',
#  'Case4MLR50RapidCitySDBsk.homer',
#  'Case4MLR50ReddingCACsa.homer',
#  'Case4MLR50RichmondVACfa.homer',
#  'Case4MLR50SacramentoCsa.homer',
#  'Case4MLR50SouthBendINDfa.homer',
#  'Case4MLR50SyracuseDfb.homer',
#  'Case4MLR50TexasOilBSh.homer',
#  'Case4MLR50UPMichDfb.homer',
#  'Case4MLR50VegasNVBwh.homer',
#  'Case4MLR50WadenaMNDfa.homer',
#  'Case4MLR50YumaAZBwh.homer']

# %%
# Unpack zip file (.zip -> normal directory)
files = [f for f in os.listdir(folder) if f.endswith('.zip')]
n_files = np.size(files)
for i in range(len(files)):
    file = files[i]
    base = os.path.splitext(file)[0]
    with zipfile.ZipFile(file, 'r') as zip_ref:
        zip_ref.extractall(base + 'TEMP')
    os.remove(file)
# Opening each individiual 'problem' file after extraction

# %%
# (Within normal directory) Edit the .xml files for each HOMER problem.
files = [f for f in os.listdir(folder) if f.endswith('TEMP')]
display(files)
# paths to change as key, new value as value
new_data = {'/HomerProblem/FuelResources/Fuel/Name': 'CCM FUEL',
            '/HomerProblem/FuelResources/Fuel/FuelCostSensitivity/decimal': '0.00',
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/Initial': '24000000',
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/Quantity': '1000' ,
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/CapitalCostDetail/CostCalculatorItem/UnitCost': '24000' ,
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/Replacement': '3550000',
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/ReplacementCostDetail/CostCalculatorItem/Quantity': '1000' ,
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/ReplacementCostDetail/CostCalculatorItem/UnitCost': '3550000' ,
            '/HomerProblem/Generators/Generator/LifetimeSensitivity/decimal': '43830' ,
            '/HomerProblem/Generators/Generator/CostMatrix/Cost/Operating': '58.33',
            '/HomerProblem/SimulationParameters/Economics/ProjectLifetimeSensitivity/decimal': '60',
            '/HomerProblem/SimulationParameters/SystemControl/Optimizer/FocusFactor': '2',
            '/HomerProblem/Generators/Generator/MinimumLoadRatioSensitivity/decimal': '90'}
   
for i in range(len(files)):
    file = files[i]
    problems = etree.parse(file + '/problem')
    #os.remove(file + '/calculated-problem') #deletes old homer savestate
    for path, value in new_data.items():
       # if 'CapacityOptimization' in path:#not necessary currently, but can be used to differentiate values later
       #     problems.xpath(path)[0].text = value
       #     newfile = etree.tostring(problems,encoding='utf-8',method='xml', xml_declaration='<?xml version="1.0" encoding="utf-8"?>')
       #     newfile = str(newfile,'utf-8')#otherwise use utf-8
       # else: 
            #print(path, ' => ', problems.xpath(path)[0].text)
        problems.xpath(path)[0].text = value
        newfile = etree.tostring(problems,encoding='US-ASCII',method='xml', xml_declaration='<?xml version="1.0" encoding="utf-8"?>')
        newfile = str(newfile,'US-ASCII')#otherwise use utf-8
    with open(file + '/problem','w') as f:
    #   # newfile = etree.tostring(new)
         f.write(newfile)
        
        
        
    #display(problem)
       # problem.xpath(j)[0].text = value[j]
# Out:
# ['Case4MLR50AnchorageDfcTEMP',
#  'Case4MLR50AshlandDfbTEMP',
#  'Case4MLR50AtlantaGACfaTEMP',
#  'Case4MLR50BangorMEDfbTEMP',
#  'Case4MLR50BendOreBskTEMP',
#  'Case4MLR50BentonCountyOregonCsbTEMP',
#  'Case4MLR50BirminghamALCfaTEMP',
#  'Case4MLR50BismarckNDDfbTEMP',
#  'Case4MLR50BlaineCountyMontanaBSkTEMP',
#  'Case4MLR50BoiseIDBSkTEMP',
#  'Case4MLR50BrewsterMADfbTEMP',
#  'Case4MLR50BurlingtonVTDfaTEMP',
#  'Case4MLR50ButtonwillowBwkTEMP',
#  'Case4MLR50CarsonCityNVBskTEMP',
#  'Case4MLR50CheyenneWYBskTEMP',
#  'Case4MLR50ChicagoDfaTEMP',
#  'Case4MLR50CoalvilleUTDfbTEMP',
#  'Case4MLR50ColumbiaMOCfaTEMP',
#  'Case4MLR50ColumbusOHDfaTEMP',
#  'Case4MLR50CrestedButteCODfcTEMP',
#  'Case4MLR50DesMoinesIADfaTEMP',
#  'Case4MLR50DetroitMIDfaTEMP',
#  'Case4MLR50EielsonAFBDfCTEMP',
#  'Case4MLR50EvergladesAMTEMP',
#  'Case4MLR50FlagstaffDsbTEMP',
#  'Case4MLR50GreatFallsMTBskTEMP',
#  'Case4MLR50HiloAfTEMP',
#  'Case4MLR50IdahoFallsDfbTEMP',
#  'Case4MLR50JacksonMSCfaTEMP',
#  'Case4MLR50KauaiCfbTEMP',
#  'Case4MLR50KootenaiCountyIDDsbTEMP',
#  'Case4MLR50LancasterPADfaTEMP',
#  'Case4MLR50LaredoTXBShTEMP',
#  'Case4MLR50LincolnNEDfaTEMP',
#  'Case4MLR50LittleRockARCfaTEMP',
#  'Case4MLR50LongviewCsbTEMP',
#  'Case4MLR50LosAlamosNMDfbTEMP',
#  'Case4MLR50MarlintonWVCfbTEMP',
#  'Case4MLR50MedfordORCsaTEMP',
#  'Case4MLR50MemphisTNCfaTEMP',
#  'Case4MLR50MiamiAfTEMP',
#  'Case4MLR50MobileALCfaTEMP',
#  'Case4MLR50MoscowIDCsbTEMP',
#  'Case4MLR50NeahBayCfbTEMP',
#  'Case4MLR50NOLACfaTEMP',
#  'Case4MLR50OKCityCfaTEMP',
#  'Case4MLR50ORNLCfaTEMP',
#  'Case4MLR50PhoenixAZBwhTEMP',
#  'Case4MLR50PrescottAZCsaTEMP',
#  'Case4MLR50PuebloBskTEMP',
#  'Case4MLR50RaleighNCCfaTEMP',
#  'Case4MLR50RapidCitySDBskTEMP',
#  'Case4MLR50ReddingCACsaTEMP',
#  'Case4MLR50RichmondVACfaTEMP',
#  'Case4MLR50SacramentoCsaTEMP',
#  'Case4MLR50SouthBendINDfaTEMP',
#  'Case4MLR50SyracuseDfbTEMP',
#  'Case4MLR50TexasOilBShTEMP',
#  'Case4MLR50UPMichDfbTEMP',
#  'Case4MLR50VegasNVBwhTEMP',
#  'Case4MLR50WadenaMNDfaTEMP',
#  'Case4MLR50YumaAZBwhTEMP']

# %%
#Repack zip file (normal directory -> .zip)
## THIS STEP CURRENTLY BREAKS THE HOMER FILE
## Try using zipcode compression 
files = [f for f in os.listdir(folder) if f.endswith('TEMP')]
display(files)
for i in range(len(files)):
    file = files[i]
    directory = pathlib.Path(file)
    basefile = file.replace('TEMP','')
    basefile = basefile.replace('Case4MLR50','Case4MLR90')
    subprocess.run(["powershell.exe", "Compress-Archive -Path " + file + "\* -DestinationPath " + basefile + " -Force"])
    shutil.rmtree(file) #deletes old temp folders
# Out:
# ['Case4MLR50AnchorageDfcTEMP',
#  'Case4MLR50AshlandDfbTEMP',
#  'Case4MLR50AtlantaGACfaTEMP',
#  'Case4MLR50BangorMEDfbTEMP',
#  'Case4MLR50BendOreBskTEMP',
#  'Case4MLR50BentonCountyOregonCsbTEMP',
#  'Case4MLR50BirminghamALCfaTEMP',
#  'Case4MLR50BismarckNDDfbTEMP',
#  'Case4MLR50BlaineCountyMontanaBSkTEMP',
#  'Case4MLR50BoiseIDBSkTEMP',
#  'Case4MLR50BrewsterMADfbTEMP',
#  'Case4MLR50BurlingtonVTDfaTEMP',
#  'Case4MLR50ButtonwillowBwkTEMP',
#  'Case4MLR50CarsonCityNVBskTEMP',
#  'Case4MLR50CheyenneWYBskTEMP',
#  'Case4MLR50ChicagoDfaTEMP',
#  'Case4MLR50CoalvilleUTDfbTEMP',
#  'Case4MLR50ColumbiaMOCfaTEMP',
#  'Case4MLR50ColumbusOHDfaTEMP',
#  'Case4MLR50CrestedButteCODfcTEMP',
#  'Case4MLR50DesMoinesIADfaTEMP',
#  'Case4MLR50DetroitMIDfaTEMP',
#  'Case4MLR50EielsonAFBDfCTEMP',
#  'Case4MLR50EvergladesAMTEMP',
#  'Case4MLR50FlagstaffDsbTEMP',
#  'Case4MLR50GreatFallsMTBskTEMP',
#  'Case4MLR50HiloAfTEMP',
#  'Case4MLR50IdahoFallsDfbTEMP',
#  'Case4MLR50JacksonMSCfaTEMP',
#  'Case4MLR50KauaiCfbTEMP',
#  'Case4MLR50KootenaiCountyIDDsbTEMP',
#  'Case4MLR50LancasterPADfaTEMP',
#  'Case4MLR50LaredoTXBShTEMP',
#  'Case4MLR50LincolnNEDfaTEMP',
#  'Case4MLR50LittleRockARCfaTEMP',
#  'Case4MLR50LongviewCsbTEMP',
#  'Case4MLR50LosAlamosNMDfbTEMP',
#  'Case4MLR50MarlintonWVCfbTEMP',
#  'Case4MLR50MedfordORCsaTEMP',
#  'Case4MLR50MemphisTNCfaTEMP',
#  'Case4MLR50MiamiAfTEMP',
#  'Case4MLR50MobileALCfaTEMP',
#  'Case4MLR50MoscowIDCsbTEMP',
#  'Case4MLR50NeahBayCfbTEMP',
#  'Case4MLR50NOLACfaTEMP',
#  'Case4MLR50OKCityCfaTEMP',
#  'Case4MLR50ORNLCfaTEMP',
#  'Case4MLR50PhoenixAZBwhTEMP',
#  'Case4MLR50PrescottAZCsaTEMP',
#  'Case4MLR50PuebloBskTEMP',
#  'Case4MLR50RaleighNCCfaTEMP',
#  'Case4MLR50RapidCitySDBskTEMP',
#  'Case4MLR50ReddingCACsaTEMP',
#  'Case4MLR50RichmondVACfaTEMP',
#  'Case4MLR50SacramentoCsaTEMP',
#  'Case4MLR50SouthBendINDfaTEMP',
#  'Case4MLR50SyracuseDfbTEMP',
#  'Case4MLR50TexasOilBShTEMP',
#  'Case4MLR50UPMichDfbTEMP',
#  'Case4MLR50VegasNVBwhTEMP',
#  'Case4MLR50WadenaMNDfaTEMP',
#  'Case4MLR50YumaAZBwhTEMP']

# %%
# Reseal homer file (.zip -> .homer)
files = [f for f in os.listdir(folder) if f.endswith('.zip')]
n_files = np.size(files)
type(files)
for i in range(len(files)):
    file = files[i]
    base = os.path.splitext(file)[0]
    os.rename(file, base + '.homer')
